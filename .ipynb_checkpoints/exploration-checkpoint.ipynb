# %%
import numpy as np
import timeit
import random
import pickle, gzip

# %%
from IO import Reader, Writer, Data, Sentence, Token
from feature import FeatureMapping
from eisner import Eisner
from model import Model

# %% [markdown]
# # Decoder (Eisner's Algorithm)

# %%
test_matrix = np.array([[-10000, 9, 10, 9], 
               [-10000, -10000, 20, 3], 
               [-10000, 30, -10000, 30],
               [-10000, 11, 0, -10000]])
test_matrix[0, 2]
# Out:
# 10

# %%
test_decoder = Eisner()
test_decoder.decode(test_matrix)
# Out:
# {'1': '2', '2': '0', '3': '2'}

# %% [markdown]
# # Main

# %%
train_path_en_1k = "Treebanks/english/train/wsj_train.only-projective.first-1k.conll06"
reader_en_1k = Reader(train_path_en_1k)
train_data_en_1k = Data(reader_en_1k.read_file())
train_data_en_1k.sentences
# Out:
# [<IO.Sentence at 0x104394400>,
#  <IO.Sentence at 0x1043947c0>,
#  <IO.Sentence at 0x10438dcd0>,
#  <IO.Sentence at 0x10438da00>,
#  <IO.Sentence at 0x10438d400>,
#  <IO.Sentence at 0x104300ac0>,
#  <IO.Sentence at 0x104300eb0>,
#  <IO.Sentence at 0x1043b7040>,
#  <IO.Sentence at 0x1043b7400>,
#  <IO.Sentence at 0x1043b7940>,
#  <IO.Sentence at 0x1043c20a0>,
#  <IO.Sentence at 0x1043c2820>,
#  <IO.Sentence at 0x1043c2be0>,
#  <IO.Sentence at 0x1043ce4f0>,
#  <IO.Sentence at 0x1043ce7f0>,
#  <IO.Sentence at 0x1043cee20>,
#  <IO.Sentence at 0x1043d8250>,
#  <IO.Sentence at 0x1043d8b80>,
#  <IO.Sentence at 0x1043e32e0>,
#  <IO.Sentence at 0x1043e3640>,
#  <IO.Sentence at 0x1043e3880>,
#  <IO.Sentence at 0x1043ee250>,
#  <IO.Sentence at 0x1043ee640>,
#  <IO.Sentence at 0x1043ee8b0>,
#  <IO.Sentence at 0x1043eee20>,
#  <IO.Sentence at 0x1043f8280>,
#  <IO.Sentence at 0x1043f8730>,
#  <IO.Sentence at 0x1043f8e50>,
#  <IO.Sentence at 0x104403760>,
#  <IO.Sentence at 0x104403c10>,
#  <IO.Sentence at 0x10440f040>,
#  <IO.Sentence at 0x10440f520>,
#  <IO.Sentence at 0x10440fb50>,
#  <IO.Sentence at 0x1044192b0>,
#  <IO.Sentence at 0x1044196d0>,
#  <IO.Sentence at 0x104419ac0>,
#  <IO.Sentence at 0x104419d30>,
#  <IO.Sentence at 0x1044244c0>,
#  <IO.Sentence at 0x104424a60>,
#  <IO.Sentence at 0x104424f40>,
#  <IO.Sentence at 0x10442f610>,
#  <IO.Sentence at 0x10442faf0>,
#  <IO.Sentence at 0x10443a220>,
#  <IO.Sentence at 0x10443a760>,
#  <IO.Sentence at 0x10443ae20>,
#  <IO.Sentence at 0x10452d2e0>,
#  <IO.Sentence at 0x10452d8e0>,
#  <IO.Sentence at 0x10452ddf0>,
#  <IO.Sentence at 0x104537700>,
#  <IO.Sentence at 0x104537a00>,
#  <IO.Sentence at 0x1045432e0>,
#  <IO.Sentence at 0x104543eb0>,
#  <IO.Sentence at 0x10454e490>,
#  <IO.Sentence at 0x10454e880>,
#  <IO.Sentence at 0x10454eb50>,
#  <IO.Sentence at 0x10454efd0>,
#  <IO.Sentence at 0x1045584f0>,
#  <IO.Sentence at 0x104564100>,
#  <IO.Sentence at 0x104564820>,
#  <IO.Sentence at 0x10456f100>,
#  <IO.Sentence at 0x10456f760>,
#  <IO.Sentence at 0x10456fd00>,
#  <IO.Sentence at 0x10457a790>,
#  <IO.Sentence at 0x10457a970>,
#  <IO.Sentence at 0x104584340>,
#  <IO.Sentence at 0x104584df0>,
#  <IO.Sentence at 0x1045908e0>,
#  <IO.Sentence at 0x104590e20>,
#  <IO.Sentence at 0x10459d700>,
#  <IO.Sentence at 0x10459d9d0>,
#  <IO.Sentence at 0x10459dd30>,
#  <IO.Sentence at 0x10459df70>,
#  <IO.Sentence at 0x1045a73a0>,
#  <IO.Sentence at 0x1045a7a30>,
#  <IO.Sentence at 0x1045b3430>,
#  <IO.Sentence at 0x1045b3af0>,
#  <IO.Sentence at 0x1045be250>,
#  <IO.Sentence at 0x1045be460>,
#  <IO.Sentence at 0x1045beca0>,
#  <IO.Sentence at 0x1045bedf0>,
#  <IO.Sentence at 0x1045befa0>,
#  <IO.Sentence at 0x1045c8730>,
#  <IO.Sentence at 0x1045c8b80>,
#  <IO.Sentence at 0x1045c8e80>,
#  <IO.Sentence at 0x1045d24c0>,
#  <IO.Sentence at 0x1045d28e0>,
#  <IO.Sentence at 0x1045d2d30>,
#  <IO.Sentence at 0x1045dd190>,
#  <IO.Sentence at 0x1045dd550>,
#  <IO.Sentence at 0x1045dd940>,
#  <IO.Sentence at 0x1045ddee0>,
#  <IO.Sentence at 0x1045e8520>,
#  <IO.Sentence at 0x1045e8eb0>,
#  <IO.Sentence at 0x1045f4310>,
#  <IO.Sentence at 0x1045f4910>,
#  <IO.Sentence at 0x1045f4ee0>,
#  <IO.Sentence at 0x1045ff610>,
#  <IO.Sentence at 0x1045ff8b0>,
#  <IO.Sentence at 0x10460a160>,
#  <IO.Sentence at 0x10460a6a0>,
#  <IO.Sentence at 0x10460ab50>,
#  <IO.Sentence at 0x1046152b0>,
#  <IO.Sentence at 0x1046159a0>,
#  <IO.Sentence at 0x104615d30>,
#  <IO.Sentence at 0x1046200d0>,
#  <IO.Sentence at 0x104620640>,
#  <IO.Sentence at 0x104620e20>,
#  <IO.Sentence at 0x10462c100>,
#  <IO.Sentence at 0x10462c6a0>,
#  <IO.Sentence at 0x10462ca30>,
#  <IO.Sentence at 0x10462cfd0>,
#  <IO.Sentence at 0x1046353a0>,
#  <IO.Sentence at 0x104635640>,
#  <IO.Sentence at 0x104635bb0>,
#  <IO.Sentence at 0x104640220>,
#  <IO.Sentence at 0x104640b20>,
#  <IO.Sentence at 0x10464c0a0>,
#  <IO.Sentence at 0x10464c610>,
#  <IO.Sentence at 0x10464caf0>,
#  <IO.Sentence at 0x104656160>,
#  <IO.Sentence at 0x104656580>,
#  <IO.Sentence at 0x1046569d0>,
#  <IO.Sentence at 0x104662130>,
#  <IO.Sentence at 0x1046623d0>,
#  <IO.Sentence at 0x104662b80>,
#  <IO.Sentence at 0x10466c100>,
#  <IO.Sentence at 0x10466cac0>,
#  <IO.Sentence at 0x104678040>,
#  <IO.Sentence at 0x1046783a0>,
#  <IO.Sentence at 0x1046789d0>,
#  <IO.Sentence at 0x104678d90>,
#  <IO.Sentence at 0x1046832b0>,
#  <IO.Sentence at 0x1046839a0>,
#  <IO.Sentence at 0x10468e040>,
#  <IO.Sentence at 0x10468e5b0>,
#  <IO.Sentence at 0x10468eca0>,
#  <IO.Sentence at 0x10469a1f0>,
#  <IO.Sentence at 0x10469a9a0>,
#  <IO.Sentence at 0x1046a50a0>,
#  <IO.Sentence at 0x1046a5520>,
#  <IO.Sentence at 0x1046a5b80>,
#  <IO.Sentence at 0x1046b0220>,
#  <IO.Sentence at 0x1046b08e0>,
#  <IO.Sentence at 0x1046b0df0>,
#  <IO.Sentence at 0x1046ba400>,
#  <IO.Sentence at 0x1046ba7c0>,
#  <IO.Sentence at 0x1046c5040>,
#  <IO.Sentence at 0x1046c5640>,
#  <IO.Sentence at 0x1046c5b50>,
#  <IO.Sentence at 0x1046c5fd0>,
#  <IO.Sentence at 0x1046cf5e0>,
#  <IO.Sentence at 0x1046cfa30>,
#  <IO.Sentence at 0x1046cffd0>,
#  <IO.Sentence at 0x1046da400>,
#  <IO.Sentence at 0x1046da820>,
#  <IO.Sentence at 0x1046dafd0>,
#  <IO.Sentence at 0x1046e5310>,
#  <IO.Sentence at 0x1046e5730>,
#  <IO.Sentence at 0x1046f0280>,
#  <IO.Sentence at 0x1046f06a0>,
#  <IO.Sentence at 0x1046f0e20>,
#  <IO.Sentence at 0x1046fc1c0>,
#  <IO.Sentence at 0x1046fc9d0>,
#  <IO.Sentence at 0x1046fcdf0>,
#  <IO.Sentence at 0x104706370>,
#  <IO.Sentence at 0x1047069d0>,
#  <IO.Sentence at 0x104706f70>,
#  <IO.Sentence at 0x1047113a0>,
#  <IO.Sentence at 0x1047116d0>,
#  <IO.Sentence at 0x104711e80>,
#  <IO.Sentence at 0x10471c6d0>,
#  <IO.Sentence at 0x10471c910>,
#  <IO.Sentence at 0x10471cca0>,
#  <IO.Sentence at 0x104728370>,
#  <IO.Sentence at 0x104728730>,
#  <IO.Sentence at 0x104728df0>,
#  <IO.Sentence at 0x1047323d0>,
#  <IO.Sentence at 0x104732d00>,
#  <IO.Sentence at 0x10473f160>,
#  <IO.Sentence at 0x10473f5b0>,
#  <IO.Sentence at 0x10473fa30>,
#  <IO.Sentence at 0x10473fd60>,
#  <IO.Sentence at 0x10474a2b0>,
#  <IO.Sentence at 0x10474a760>,
#  <IO.Sentence at 0x10474aca0>,
#  <IO.Sentence at 0x104753430>,
#  <IO.Sentence at 0x1047536a0>,
#  <IO.Sentence at 0x104753790>,
#  <IO.Sentence at 0x104753d00>,
#  <IO.Sentence at 0x10475e1f0>,
#  <IO.Sentence at 0x10475eaf0>,
#  <IO.Sentence at 0x104769250>,
#  <IO.Sentence at 0x104769610>,
#  <IO.Sentence at 0x104769ac0>,
#  <IO.Sentence at 0x104769fa0>,
#  <IO.Sentence at 0x104774430>,
#  <IO.Sentence at 0x104774610>,
#  <IO.Sentence at 0x104774fd0>,
#  <IO.Sentence at 0x10477f490>,
#  <IO.Sentence at 0x10477f880>,
#  <IO.Sentence at 0x10477fd90>,
#  <IO.Sentence at 0x1047891f0>,
#  <IO.Sentence at 0x104789790>,
#  <IO.Sentence at 0x104789ee0>,
#  <IO.Sentence at 0x104794310>,
#  <IO.Sentence at 0x1047946a0>,
#  <IO.Sentence at 0x104794c70>,
#  <IO.Sentence at 0x10479e040>,
#  <IO.Sentence at 0x10479e520>,
#  <IO.Sentence at 0x1047aa0d0>,
#  <IO.Sentence at 0x1047aa280>,
#  <IO.Sentence at 0x1047aa760>,
#  <IO.Sentence at 0x1047aad60>,
#  <IO.Sentence at 0x1047b30d0>,
#  <IO.Sentence at 0x1047b3400>,
#  <IO.Sentence at 0x1047b3580>,
#  <IO.Sentence at 0x1047b3df0>,
#  <IO.Sentence at 0x1047be4f0>,
#  <IO.Sentence at 0x1047beca0>,
#  <IO.Sentence at 0x1047c9040>,
#  <IO.Sentence at 0x1047c9310>,
#  <IO.Sentence at 0x1047c9880>,
#  <IO.Sentence at 0x1047c9c10>,
#  <IO.Sentence at 0x1047d40d0>,
#  <IO.Sentence at 0x1047d48e0>,
#  <IO.Sentence at 0x1047d4d90>,
#  <IO.Sentence at 0x1047df580>,
#  <IO.Sentence at 0x1047df8e0>,
#  <IO.Sentence at 0x1047dfe80>,
#  <IO.Sentence at 0x1047ea040>,
#  <IO.Sentence at 0x1047ea190>,
#  <IO.Sentence at 0x1047ea4c0>,
#  <IO.Sentence at 0x1047ea9a0>,
#  <IO.Sentence at 0x1047eab20>,
#  <IO.Sentence at 0x1047f31c0>,
#  <IO.Sentence at 0x1047f3640>,
#  <IO.Sentence at 0x1047f38b0>,
#  <IO.Sentence at 0x1047f3cd0>,
#  <IO.Sentence at 0x1047fd100>,
#  <IO.Sentence at 0x1047fd250>,
#  <IO.Sentence at 0x1047fd430>,
#  <IO.Sentence at 0x1047fd730>,
#  <IO.Sentence at 0x1047fdd90>,
#  <IO.Sentence at 0x104807310>,
#  <IO.Sentence at 0x104807670>,
#  <IO.Sentence at 0x1048078e0>,
#  <IO.Sentence at 0x104807a60>,
#  <IO.Sentence at 0x104807f40>,
#  <IO.Sentence at 0x104810400>,
#  <IO.Sentence at 0x1048109d0>,
#  <IO.Sentence at 0x104810f40>,
#  <IO.Sentence at 0x10481a160>,
#  <IO.Sentence at 0x10481a310>,
#  <IO.Sentence at 0x10481a640>,
#  <IO.Sentence at 0x10481a7c0>,
#  <IO.Sentence at 0x10481aa60>,
#  <IO.Sentence at 0x10481adf0>,
#  <IO.Sentence at 0x10481af70>,
#  <IO.Sentence at 0x104824430>,
#  <IO.Sentence at 0x104824b80>,
#  <IO.Sentence at 0x10482f040>,
#  <IO.Sentence at 0x10482f670>,
#  <IO.Sentence at 0x10482f940>,
#  <IO.Sentence at 0x10482ffd0>,
#  <IO.Sentence at 0x10483a460>,
#  <IO.Sentence at 0x10483a7c0>,
#  <IO.Sentence at 0x10483adf0>,
#  <IO.Sentence at 0x104844550>,
#  <IO.Sentence at 0x104844700>,
#  <IO.Sentence at 0x104844be0>,
#  <IO.Sentence at 0x104844dc0>,
#  <IO.Sentence at 0x10484f130>,
#  <IO.Sentence at 0x10484f640>,
#  <IO.Sentence at 0x10484fa00>,
#  <IO.Sentence at 0x10484fc70>,
#  <IO.Sentence at 0x10484fe20>,
#  <IO.Sentence at 0x1048581c0>,
#  <IO.Sentence at 0x104858430>,
#  <IO.Sentence at 0x1048586d0>,
#  <IO.Sentence at 0x1048622b0>,
#  <IO.Sentence at 0x1048629d0>,
#  <IO.Sentence at 0x104862fd0>,
#  <IO.Sentence at 0x10486d5e0>,
#  <IO.Sentence at 0x10486d7c0>,
#  <IO.Sentence at 0x10486dc70>,
#  <IO.Sentence at 0x104877370>,
#  <IO.Sentence at 0x1048776a0>,
#  <IO.Sentence at 0x104882370>,
#  <IO.Sentence at 0x104882a00>,
#  <IO.Sentence at 0x104882e80>,
#  <IO.Sentence at 0x10488c3d0>,
#  <IO.Sentence at 0x10488c730>,
#  <IO.Sentence at 0x104897130>,
#  <IO.Sentence at 0x104897670>,
#  <IO.Sentence at 0x104897b80>,
#  <IO.Sentence at 0x104897d30>,
#  <IO.Sentence at 0x1048a0730>,
#  <IO.Sentence at 0x1048a08e0>,
#  <IO.Sentence at 0x1048a0b20>,
#  <IO.Sentence at 0x1048a0f70>,
#  <IO.Sentence at 0x1048aa6a0>,
#  <IO.Sentence at 0x1048aa9d0>,
#  <IO.Sentence at 0x1048aad30>,
#  <IO.Sentence at 0x1048b50d0>,
#  <IO.Sentence at 0x1048b5340>,
#  <IO.Sentence at 0x1048b5850>,
#  <IO.Sentence at 0x1048b5c10>,
#  <IO.Sentence at 0x1048be1c0>,
#  <IO.Sentence at 0x1048be520>,
#  <IO.Sentence at 0x1048beac0>,
#  <IO.Sentence at 0x1048c90a0>,
#  <IO.Sentence at 0x1048c97c0>,
#  <IO.Sentence at 0x1048c9c70>,
#  <IO.Sentence at 0x1048c9f70>,
#  <IO.Sentence at 0x1048d38b0>,
#  <IO.Sentence at 0x1048d3eb0>,
#  <IO.Sentence at 0x1048de280>,
#  <IO.Sentence at 0x1048de490>,
#  <IO.Sentence at 0x1048def40>,
#  <IO.Sentence at 0x1048e85b0>,
#  <IO.Sentence at 0x1048e8ac0>,
#  <IO.Sentence at 0x1048e8fa0>,
#  <IO.Sentence at 0x1048f3220>,
#  <IO.Sentence at 0x1048f3520>,
#  <IO.Sentence at 0x1048f3a60>,
#  <IO.Sentence at 0x1048fe040>,
#  <IO.Sentence at 0x1048fe490>,
#  <IO.Sentence at 0x1048fe9a0>,
#  <IO.Sentence at 0x1048fef10>,
#  <IO.Sentence at 0x104909280>,
#  <IO.Sentence at 0x104909460>,
#  <IO.Sentence at 0x104909820>,
#  <IO.Sentence at 0x104909d30>,
#  <IO.Sentence at 0x104912250>,
#  <IO.Sentence at 0x104912760>,
#  <IO.Sentence at 0x104912d60>,
#  <IO.Sentence at 0x10491d460>,
#  <IO.Sentence at 0x10491dca0>,
#  <IO.Sentence at 0x10492a370>,
#  <IO.Sentence at 0x10492a8e0>,
#  <IO.Sentence at 0x10492ab20>,
#  <IO.Sentence at 0x10492af70>,
#  <IO.Sentence at 0x1049332e0>,
#  <IO.Sentence at 0x1049337f0>,
#  <IO.Sentence at 0x104933e50>,
#  <IO.Sentence at 0x10493f100>,
#  <IO.Sentence at 0x10493f5b0>,
#  <IO.Sentence at 0x10493fc40>,
#  <IO.Sentence at 0x10494a2e0>,
#  <IO.Sentence at 0x10494a7c0>,
#  <IO.Sentence at 0x10494af70>,
#  <IO.Sentence at 0x104954550>,
#  <IO.Sentence at 0x104954a60>,
#  <IO.Sentence at 0x104954e50>,
#  <IO.Sentence at 0x10495f430>,
#  <IO.Sentence at 0x10495f9a0>,
#  <IO.Sentence at 0x10496a3a0>,
#  <IO.Sentence at 0x10496a910>,
#  <IO.Sentence at 0x10496acd0>,
#  <IO.Sentence at 0x1049760a0>,
#  <IO.Sentence at 0x104976610>,
#  <IO.Sentence at 0x104976d00>,
#  <IO.Sentence at 0x104980160>,
#  <IO.Sentence at 0x1049806d0>,
#  <IO.Sentence at 0x104980af0>,
#  <IO.Sentence at 0x104980f70>,
#  <IO.Sentence at 0x10498c400>,
#  <IO.Sentence at 0x10498c730>,
#  <IO.Sentence at 0x10498cdf0>,
#  <IO.Sentence at 0x1049951f0>,
#  <IO.Sentence at 0x104995790>,
#  <IO.Sentence at 0x104995c70>,
#  <IO.Sentence at 0x104995ee0>,
#  <IO.Sentence at 0x1049a0490>,
#  <IO.Sentence at 0x1049a0880>,
#  <IO.Sentence at 0x1049a0cd0>,
#  <IO.Sentence at 0x1049a0fa0>,
#  <IO.Sentence at 0x1049a9490>,
#  <IO.Sentence at 0x1049a9940>,
#  <IO.Sentence at 0x1049a9dc0>,
#  <IO.Sentence at 0x1049b41c0>,
#  <IO.Sentence at 0x1049b4610>,
#  <IO.Sentence at 0x1049b4910>,
#  <IO.Sentence at 0x1049be040>,
#  <IO.Sentence at 0x1049be7c0>,
#  <IO.Sentence at 0x1049bec10>,
#  <IO.Sentence at 0x1049ca3a0>,
#  <IO.Sentence at 0x1049cadc0>,
#  <IO.Sentence at 0x1049d61c0>,
#  <IO.Sentence at 0x1049d6460>,
#  <IO.Sentence at 0x1049d6640>,
#  <IO.Sentence at 0x1049d6ac0>,
#  <IO.Sentence at 0x1049df400>,
#  <IO.Sentence at 0x1049ec070>,
#  <IO.Sentence at 0x1049ec370>,
#  <IO.Sentence at 0x1049ec760>,
#  <IO.Sentence at 0x1049eca60>,
#  <IO.Sentence at 0x1049f50d0>,
#  <IO.Sentence at 0x1049f5370>,
#  <IO.Sentence at 0x1049f5730>,
#  <IO.Sentence at 0x1049f5970>,
#  <IO.Sentence at 0x1049f5dc0>,
#  <IO.Sentence at 0x1049fe040>,
#  <IO.Sentence at 0x1049fe1f0>,
#  <IO.Sentence at 0x1049fe400>,
#  <IO.Sentence at 0x1049feac0>,
#  <IO.Sentence at 0x1049feeb0>,
#  <IO.Sentence at 0x104a076d0>,
#  <IO.Sentence at 0x104a07d30>,
#  <IO.Sentence at 0x104a134c0>,
#  <IO.Sentence at 0x104a13d90>,
#  <IO.Sentence at 0x104a1e3a0>,
#  <IO.Sentence at 0x104a1e4c0>,
#  <IO.Sentence at 0x104a1e700>,
#  <IO.Sentence at 0x104a1ea90>,
#  <IO.Sentence at 0x104a1ec40>,
#  <IO.Sentence at 0x104a293d0>,
#  <IO.Sentence at 0x104a295b0>,
#  <IO.Sentence at 0x104a29a00>,
#  <IO.Sentence at 0x104a29d60>,
#  <IO.Sentence at 0x104a322b0>,
#  <IO.Sentence at 0x104a328e0>,
#  <IO.Sentence at 0x104a32c70>,
#  <IO.Sentence at 0x104a3e460>,
#  <IO.Sentence at 0x104a3e610>,
#  <IO.Sentence at 0x104a3e820>,
#  <IO.Sentence at 0x104a48040>,
#  <IO.Sentence at 0x104a48e50>,
#  <IO.Sentence at 0x104a533a0>,
#  <IO.Sentence at 0x104a53a90>,
#  <IO.Sentence at 0x104a53e20>,
#  <IO.Sentence at 0x104a5f250>,
#  <IO.Sentence at 0x104a5f760>,
#  <IO.Sentence at 0x104a5fac0>,
#  <IO.Sentence at 0x104a5ff40>,
#  <IO.Sentence at 0x104a691f0>,
#  <IO.Sentence at 0x104a699a0>,
#  <IO.Sentence at 0x104a75520>,
#  <IO.Sentence at 0x104a75c70>,
#  <IO.Sentence at 0x104a80190>,
#  <IO.Sentence at 0x104a80a30>,
#  <IO.Sentence at 0x104a80ee0>,
#  <IO.Sentence at 0x104a8b5e0>,
#  <IO.Sentence at 0x104a8b820>,
#  <IO.Sentence at 0x104a8bd00>,
#  <IO.Sentence at 0x104a97130>,
#  <IO.Sentence at 0x104a97670>,
#  <IO.Sentence at 0x104a97a00>,
#  <IO.Sentence at 0x104aa11f0>,
#  <IO.Sentence at 0x104aa1640>,
#  <IO.Sentence at 0x104aa1af0>,
#  <IO.Sentence at 0x104aa1d30>,
#  <IO.Sentence at 0x104aac0d0>,
#  <IO.Sentence at 0x104aac820>,
#  <IO.Sentence at 0x104ab70a0>,
#  <IO.Sentence at 0x104ab73d0>,
#  <IO.Sentence at 0x104ab79a0>,
#  <IO.Sentence at 0x104ac22e0>,
#  <IO.Sentence at 0x104ac2a90>,
#  <IO.Sentence at 0x104acd430>,
#  <IO.Sentence at 0x104acdca0>,
#  <IO.Sentence at 0x104ada370>,
#  <IO.Sentence at 0x104ada6d0>,
#  <IO.Sentence at 0x104adaa90>,
#  <IO.Sentence at 0x104adaee0>,
#  <IO.Sentence at 0x104ae5820>,
#  <IO.Sentence at 0x104ae5a60>,
#  <IO.Sentence at 0x104ae5e80>,
#  <IO.Sentence at 0x104aef4c0>,
#  <IO.Sentence at 0x104aef6a0>,
#  <IO.Sentence at 0x104aefc40>,
#  <IO.Sentence at 0x104afb040>,
#  <IO.Sentence at 0x104afb790>,
#  <IO.Sentence at 0x104afb970>,
#  <IO.Sentence at 0x104b050a0>,
#  <IO.Sentence at 0x104b05400>,
#  <IO.Sentence at 0x104b059d0>,
#  <IO.Sentence at 0x104b05fa0>,
#  <IO.Sentence at 0x104b106d0>,
#  <IO.Sentence at 0x104b10d60>,
#  <IO.Sentence at 0x104b1b340>,
#  <IO.Sentence at 0x104b1b700>,
#  <IO.Sentence at 0x104b1bd60>,
#  <IO.Sentence at 0x104b26190>,
#  <IO.Sentence at 0x104b26610>,
#  <IO.Sentence at 0x104b26b50>,
#  <IO.Sentence at 0x104b26f70>,
#  <IO.Sentence at 0x104b2f400>,
#  <IO.Sentence at 0x104b2f8b0>,
#  <IO.Sentence at 0x104b2fbb0>,
#  <IO.Sentence at 0x104b3a310>,
#  <IO.Sentence at 0x104b3a670>,
#  <IO.Sentence at 0x104b3ab50>,
#  <IO.Sentence at 0x104b45070>,
#  <IO.Sentence at 0x104b454c0>,
#  <IO.Sentence at 0x104b45880>,
#  <IO.Sentence at 0x104b45ee0>,
#  <IO.Sentence at 0x104b502b0>,
#  <IO.Sentence at 0x104b50a90>,
#  <IO.Sentence at 0x104b50e50>,
#  <IO.Sentence at 0x104b5b520>,
#  <IO.Sentence at 0x104b5bcd0>,
#  <IO.Sentence at 0x104b670d0>,
#  <IO.Sentence at 0x104b67490>,
#  <IO.Sentence at 0x104b679a0>,
#  <IO.Sentence at 0x104b72070>,
#  <IO.Sentence at 0x104b72490>,
#  <IO.Sentence at 0x104b72790>,
#  <IO.Sentence at 0x104b72df0>,
#  <IO.Sentence at 0x104b7b7f0>,
#  <IO.Sentence at 0x104b88130>,
#  <IO.Sentence at 0x104b88880>,
#  <IO.Sentence at 0x104b88df0>,
#  <IO.Sentence at 0x104b921f0>,
#  <IO.Sentence at 0x104b928e0>,
#  <IO.Sentence at 0x104b92d90>,
#  <IO.Sentence at 0x104b9c160>,
#  <IO.Sentence at 0x104b9c5e0>,
#  <IO.Sentence at 0x104b9cd30>,
#  <IO.Sentence at 0x104ba8430>,
#  <IO.Sentence at 0x104ba8a00>,
#  <IO.Sentence at 0x104bb2370>,
#  <IO.Sentence at 0x104bb2b80>,
#  <IO.Sentence at 0x104bbe040>,
#  <IO.Sentence at 0x104bbe5b0>,
#  <IO.Sentence at 0x104bbea60>,
#  <IO.Sentence at 0x104bbeb50>,
#  <IO.Sentence at 0x104bbec40>,
#  <IO.Sentence at 0x104bbed30>,
#  <IO.Sentence at 0x104bbedf0>,
#  <IO.Sentence at 0x104bc7550>,
#  <IO.Sentence at 0x104bc7bb0>,
#  <IO.Sentence at 0x104bc7fd0>,
#  <IO.Sentence at 0x104bd3790>,
#  <IO.Sentence at 0x104bd3df0>,
#  <IO.Sentence at 0x104bdd6a0>,
#  <IO.Sentence at 0x104bdde80>,
#  <IO.Sentence at 0x104be95b0>,
#  <IO.Sentence at 0x104be9dc0>,
#  <IO.Sentence at 0x104bf5490>,
#  <IO.Sentence at 0x104bf5be0>,
#  <IO.Sentence at 0x104bf5f10>,
#  <IO.Sentence at 0x104bff280>,
#  <IO.Sentence at 0x104c0b040>,
#  <IO.Sentence at 0x104c0b670>,
#  <IO.Sentence at 0x104c0b8b0>,
#  <IO.Sentence at 0x104c0bb20>,
#  <IO.Sentence at 0x104c14280>,
#  <IO.Sentence at 0x104c14a90>,
#  <IO.Sentence at 0x104c21370>,
#  <IO.Sentence at 0x104c21ac0>,
#  <IO.Sentence at 0x104c21cd0>,
#  <IO.Sentence at 0x104c2c4c0>,
#  <IO.Sentence at 0x104c2c880>,
#  <IO.Sentence at 0x104c432b0>,
#  <IO.Sentence at 0x104c43a90>,
#  <IO.Sentence at 0x104c43f10>,
#  <IO.Sentence at 0x104c4e490>,
#  <IO.Sentence at 0x104c4e790>,
#  <IO.Sentence at 0x104c4eee0>,
#  <IO.Sentence at 0x104c5a370>,
#  <IO.Sentence at 0x104c5a8e0>,
#  <IO.Sentence at 0x104c5aeb0>,
#  <IO.Sentence at 0x104c64580>,
#  <IO.Sentence at 0x104c649d0>,
#  <IO.Sentence at 0x104c701c0>,
#  <IO.Sentence at 0x104c70850>,
#  <IO.Sentence at 0x104c70fa0>,
#  <IO.Sentence at 0x104c7b2e0>,
#  <IO.Sentence at 0x104c7b820>,
#  <IO.Sentence at 0x104c7ba30>,
#  <IO.Sentence at 0x104c850a0>,
#  <IO.Sentence at 0x104c85490>,
#  <IO.Sentence at 0x104c85ac0>,
#  <IO.Sentence at 0x104c901f0>,
#  <IO.Sentence at 0x104c90430>,
#  <IO.Sentence at 0x104c90c10>,
#  <IO.Sentence at 0x104c9c070>,
#  <IO.Sentence at 0x104c9c310>,
#  <IO.Sentence at 0x104c9c700>,
#  <IO.Sentence at 0x104c9cbe0>,
#  <IO.Sentence at 0x104c9cfa0>,
#  <IO.Sentence at 0x104ca7460>,
#  <IO.Sentence at 0x104ca77f0>,
#  <IO.Sentence at 0x104ca7e80>,
#  <IO.Sentence at 0x104cb14f0>,
#  <IO.Sentence at 0x104cb1700>,
#  <IO.Sentence at 0x104cb1e50>,
#  <IO.Sentence at 0x104cbd0a0>,
#  <IO.Sentence at 0x104cbd310>,
#  <IO.Sentence at 0x104cbd9a0>,
#  <IO.Sentence at 0x104cbdbb0>,
#  <IO.Sentence at 0x104cbde20>,
#  <IO.Sentence at 0x104cc51f0>,
#  <IO.Sentence at 0x104cc56a0>,
#  <IO.Sentence at 0x104cc5820>,
#  <IO.Sentence at 0x104cc5d00>,
#  <IO.Sentence at 0x104cd01f0>,
#  <IO.Sentence at 0x104cd06a0>,
#  <IO.Sentence at 0x104cd0d90>,
#  <IO.Sentence at 0x104cda520>,
#  <IO.Sentence at 0x104cdacd0>,
#  <IO.Sentence at 0x104ce5580>,
#  <IO.Sentence at 0x104ce57c0>,
#  <IO.Sentence at 0x104ce5d00>,
#  <IO.Sentence at 0x104cf13a0>,
#  <IO.Sentence at 0x104cf19a0>,
#  <IO.Sentence at 0x104cf1eb0>,
#  <IO.Sentence at 0x104cfb640>,
#  <IO.Sentence at 0x104cfbd60>,
#  <IO.Sentence at 0x104d07190>,
#  <IO.Sentence at 0x104d077c0>,
#  <IO.Sentence at 0x104d07a00>,
#  <IO.Sentence at 0x104d11070>,
#  <IO.Sentence at 0x104d118b0>,
#  <IO.Sentence at 0x104d11ac0>,
#  <IO.Sentence at 0x104d11d00>,
#  <IO.Sentence at 0x104d1c430>,
#  <IO.Sentence at 0x104d1c790>,
#  <IO.Sentence at 0x104d1cd90>,
#  <IO.Sentence at 0x104d264c0>,
#  <IO.Sentence at 0x104d269d0>,
#  <IO.Sentence at 0x104d26c70>,
#  <IO.Sentence at 0x104d32250>,
#  <IO.Sentence at 0x104d32400>,
#  <IO.Sentence at 0x104d32610>,
#  <IO.Sentence at 0x104d32bb0>,
#  <IO.Sentence at 0x104d32e80>,
#  <IO.Sentence at 0x104d3c370>,
#  <IO.Sentence at 0x104d3c6d0>,
#  <IO.Sentence at 0x104d3cb50>,
#  <IO.Sentence at 0x104d3cd00>,
#  <IO.Sentence at 0x104d46280>,
#  <IO.Sentence at 0x104d46520>,
#  <IO.Sentence at 0x104d46760>,
#  <IO.Sentence at 0x104d46df0>,
#  <IO.Sentence at 0x104d51490>,
#  <IO.Sentence at 0x104d51880>,
#  <IO.Sentence at 0x104d51d90>,
#  <IO.Sentence at 0x104d5b100>,
#  <IO.Sentence at 0x104d5b640>,
#  <IO.Sentence at 0x104d5bc40>,
#  <IO.Sentence at 0x104d661f0>,
#  <IO.Sentence at 0x104d66850>,
#  <IO.Sentence at 0x104d66d90>,
#  <IO.Sentence at 0x104d70820>,
#  <IO.Sentence at 0x104d70af0>,
#  <IO.Sentence at 0x104d7c220>,
#  <IO.Sentence at 0x104d7c730>,
#  <IO.Sentence at 0x104d7ca00>,
#  <IO.Sentence at 0x104d7cf40>,
#  <IO.Sentence at 0x104d86730>,
#  <IO.Sentence at 0x104d86e80>,
#  <IO.Sentence at 0x104d93160>,
#  <IO.Sentence at 0x104d93760>,
#  <IO.Sentence at 0x104d93f10>,
#  <IO.Sentence at 0x104d9d370>,
#  <IO.Sentence at 0x104d9d730>,
#  <IO.Sentence at 0x104d9db80>,
#  <IO.Sentence at 0x104d9dee0>,
#  <IO.Sentence at 0x104da7280>,
#  <IO.Sentence at 0x104da7df0>,
#  <IO.Sentence at 0x104db4400>,
#  <IO.Sentence at 0x104db4a30>,
#  <IO.Sentence at 0x104db4e50>,
#  <IO.Sentence at 0x104dbe310>,
#  <IO.Sentence at 0x104dbe700>,
#  <IO.Sentence at 0x104dbec40>,
#  <IO.Sentence at 0x104dca340>,
#  <IO.Sentence at 0x104dcac10>,
#  <IO.Sentence at 0x104dd5040>,
#  <IO.Sentence at 0x104dd5640>,
#  <IO.Sentence at 0x104dd5b50>,
#  <IO.Sentence at 0x104dd5f10>,
#  <IO.Sentence at 0x104de19a0>,
#  <IO.Sentence at 0x104de1cd0>,
#  <IO.Sentence at 0x104deb3a0>,
#  <IO.Sentence at 0x104debcd0>,
#  <IO.Sentence at 0x104df74c0>,
#  <IO.Sentence at 0x104df7940>,
#  <IO.Sentence at 0x104df7be0>,
#  <IO.Sentence at 0x104e02220>,
#  <IO.Sentence at 0x104e02610>,
#  <IO.Sentence at 0x104e02a60>,
#  <IO.Sentence at 0x104e0c0d0>,
#  <IO.Sentence at 0x104e0c9d0>,
#  <IO.Sentence at 0x104e18490>,
#  <IO.Sentence at 0x104e188e0>,
#  <IO.Sentence at 0x104e18f40>,
#  <IO.Sentence at 0x104e22280>,
#  <IO.Sentence at 0x104e227c0>,
#  <IO.Sentence at 0x104e22a60>,
#  <IO.Sentence at 0x104e22f40>,
#  <IO.Sentence at 0x104e2d4c0>,
#  <IO.Sentence at 0x104e2d8e0>,
#  <IO.Sentence at 0x104e2ddf0>,
#  <IO.Sentence at 0x104e37250>,
#  <IO.Sentence at 0x104e37790>,
#  <IO.Sentence at 0x104e37c40>,
#  <IO.Sentence at 0x104e421c0>,
#  <IO.Sentence at 0x104e42460>,
#  <IO.Sentence at 0x104e42b80>,
#  <IO.Sentence at 0x104e4d100>,
#  <IO.Sentence at 0x104e4d880>,
#  <IO.Sentence at 0x104e570d0>,
#  <IO.Sentence at 0x104e579a0>,
#  <IO.Sentence at 0x104e57e80>,
#  <IO.Sentence at 0x104e63610>,
#  <IO.Sentence at 0x104e63a60>,
#  <IO.Sentence at 0x104e6d160>,
#  <IO.Sentence at 0x104e6d7f0>,
#  <IO.Sentence at 0x104e6dd60>,
#  <IO.Sentence at 0x104e786d0>,
#  <IO.Sentence at 0x104e78ac0>,
#  <IO.Sentence at 0x104e83310>,
#  <IO.Sentence at 0x104e83580>,
#  <IO.Sentence at 0x104e837f0>,
#  <IO.Sentence at 0x104e83ca0>,
#  <IO.Sentence at 0x104e8e220>,
#  <IO.Sentence at 0x104e8e640>,
#  <IO.Sentence at 0x104e9b0a0>,
#  <IO.Sentence at 0x104e9b490>,
#  <IO.Sentence at 0x104e9bd60>,
#  <IO.Sentence at 0x104ea5d90>,
#  <IO.Sentence at 0x104eb1550>,
#  <IO.Sentence at 0x104eb1d90>,
#  <IO.Sentence at 0x104ebc3a0>,
#  <IO.Sentence at 0x104ebc5b0>,
#  <IO.Sentence at 0x104ebcc40>,
#  <IO.Sentence at 0x104ec5070>,
#  <IO.Sentence at 0x104ec57f0>,
#  <IO.Sentence at 0x104ec5f70>,
#  <IO.Sentence at 0x104ed33a0>,
#  <IO.Sentence at 0x104ed3910>,
#  <IO.Sentence at 0x104ed3ee0>,
#  <IO.Sentence at 0x104edf430>,
#  <IO.Sentence at 0x104edfb50>,
#  <IO.Sentence at 0x104ee84f0>,
#  <IO.Sentence at 0x104ee8a60>,
#  <IO.Sentence at 0x104ef51f0>,
#  <IO.Sentence at 0x104ef5910>,
#  <IO.Sentence at 0x104ef5d60>,
#  <IO.Sentence at 0x104f01160>,
#  <IO.Sentence at 0x104f01790>,
#  <IO.Sentence at 0x104f01a30>,
#  <IO.Sentence at 0x104f0b040>,
#  <IO.Sentence at 0x104f0b550>,
#  <IO.Sentence at 0x104f0b940>,
#  <IO.Sentence at 0x104f17040>,
#  <IO.Sentence at 0x104f17970>,
#  <IO.Sentence at 0x104f17b80>,
#  <IO.Sentence at 0x104f17e80>,
#  <IO.Sentence at 0x104f201f0>,
#  <IO.Sentence at 0x104f20b20>,
#  <IO.Sentence at 0x104f2c130>,
#  <IO.Sentence at 0x104f2c7c0>,
#  <IO.Sentence at 0x104f2ccd0>,
#  <IO.Sentence at 0x104f2cf10>,
#  <IO.Sentence at 0x104f370d0>,
#  <IO.Sentence at 0x104f376a0>,
#  <IO.Sentence at 0x104f37a60>,
#  <IO.Sentence at 0x104f37f10>,
#  <IO.Sentence at 0x104f415e0>,
#  <IO.Sentence at 0x104f41c10>,
#  <IO.Sentence at 0x104f41ee0>,
#  <IO.Sentence at 0x104f4c430>,
#  <IO.Sentence at 0x104f4c790>,
#  <IO.Sentence at 0x104f4cd00>,
#  <IO.Sentence at 0x104f56100>,
#  <IO.Sentence at 0x104f56640>,
#  <IO.Sentence at 0x104f56a60>,
#  <IO.Sentence at 0x104f56e20>,
#  <IO.Sentence at 0x104f61580>,
#  <IO.Sentence at 0x104f61e20>,
#  <IO.Sentence at 0x104f6c790>,
#  <IO.Sentence at 0x104f6caf0>,
#  <IO.Sentence at 0x104f78250>,
#  <IO.Sentence at 0x104f78580>,
#  <IO.Sentence at 0x104f78c70>,
#  <IO.Sentence at 0x104f832b0>,
#  <IO.Sentence at 0x104f83790>,
#  <IO.Sentence at 0x104f83c10>,
#  <IO.Sentence at 0x104f8d1c0>,
#  <IO.Sentence at 0x104f8d3d0>,
#  <IO.Sentence at 0x104f8d730>,
#  <IO.Sentence at 0x104f8df70>,
#  <IO.Sentence at 0x104f994f0>,
#  <IO.Sentence at 0x104f99820>,
#  <IO.Sentence at 0x104f99f10>,
#  <IO.Sentence at 0x104fa4190>,
#  <IO.Sentence at 0x104fa4700>,
#  <IO.Sentence at 0x104fa4880>,
#  <IO.Sentence at 0x104faf190>,
#  <IO.Sentence at 0x104faf760>,
#  <IO.Sentence at 0x104fafd60>,
#  <IO.Sentence at 0x104fafeb0>,
#  <IO.Sentence at 0x104fb97c0>,
#  <IO.Sentence at 0x104fb9b80>,
#  <IO.Sentence at 0x104fc5130>,
#  <IO.Sentence at 0x104fc5460>,
#  <IO.Sentence at 0x104fc59d0>,
#  <IO.Sentence at 0x104fc5e50>,
#  <IO.Sentence at 0x104fce1c0>,
#  <IO.Sentence at 0x104fce5b0>,
#  <IO.Sentence at 0x104fcea30>,
#  <IO.Sentence at 0x104fced60>,
#  <IO.Sentence at 0x104fd8340>,
#  <IO.Sentence at 0x104fd8610>,
#  <IO.Sentence at 0x104fd8c40>,
#  <IO.Sentence at 0x104fe2580>,
#  <IO.Sentence at 0x104fe2730>,
#  <IO.Sentence at 0x104fe2850>,
#  <IO.Sentence at 0x104fee250>,
#  <IO.Sentence at 0x104fee610>,
#  <IO.Sentence at 0x104feef40>,
#  <IO.Sentence at 0x104ff9700>,
#  <IO.Sentence at 0x104ff9820>,
#  <IO.Sentence at 0x105005250>,
#  <IO.Sentence at 0x105005610>,
#  <IO.Sentence at 0x105005790>,
#  <IO.Sentence at 0x105005eb0>,
#  <IO.Sentence at 0x105010280>,
#  <IO.Sentence at 0x105010b20>,
#  <IO.Sentence at 0x10501b0a0>,
#  <IO.Sentence at 0x10501b6a0>,
#  <IO.Sentence at 0x10501bc10>,
#  <IO.Sentence at 0x1050250d0>,
#  <IO.Sentence at 0x105025400>,
#  <IO.Sentence at 0x1050258e0>,
#  <IO.Sentence at 0x105025e80>,
#  <IO.Sentence at 0x10502f910>,
#  <IO.Sentence at 0x10502fcd0>,
#  <IO.Sentence at 0x10503b400>,
#  <IO.Sentence at 0x10503b7c0>,
#  <IO.Sentence at 0x10503bcd0>,
#  <IO.Sentence at 0x105046040>,
#  <IO.Sentence at 0x105046940>,
#  <IO.Sentence at 0x105046d90>,
#  <IO.Sentence at 0x1050506d0>,
#  <IO.Sentence at 0x105050b50>,
#  <IO.Sentence at 0x105050eb0>,
#  <IO.Sentence at 0x10505c1f0>,
#  <IO.Sentence at 0x10505c520>,
#  <IO.Sentence at 0x10505cbe0>,
#  <IO.Sentence at 0x105066400>,
#  <IO.Sentence at 0x105066a30>,
#  <IO.Sentence at 0x106496070>,
#  <IO.Sentence at 0x106496af0>,
#  <IO.Sentence at 0x106496e50>,
#  <IO.Sentence at 0x1064a1370>,
#  <IO.Sentence at 0x1064a1610>,
#  <IO.Sentence at 0x1064a1cd0>,
#  <IO.Sentence at 0x1064ac520>,
#  <IO.Sentence at 0x1064acc40>,
#  <IO.Sentence at 0x1064b82e0>,
#  <IO.Sentence at 0x1064b8670>,
#  <IO.Sentence at 0x1064b8a60>,
#  <IO.Sentence at 0x1064b8f10>,
#  <IO.Sentence at 0x1064c33a0>,
#  <IO.Sentence at 0x1064c3640>,
#  <IO.Sentence at 0x1064c37f0>,
#  <IO.Sentence at 0x1064c3ee0>,
#  <IO.Sentence at 0x1064ce3a0>,
#  <IO.Sentence at 0x1064ce550>,
#  <IO.Sentence at 0x1064ceb20>,
#  <IO.Sentence at 0x1064ced00>,
#  <IO.Sentence at 0x1064d71c0>,
#  <IO.Sentence at 0x1064d76d0>,
#  <IO.Sentence at 0x1064d7c70>,
#  <IO.Sentence at 0x1064e22e0>,
#  <IO.Sentence at 0x1064e2850>,
#  <IO.Sentence at 0x1064e2b20>,
#  <IO.Sentence at 0x1064ec040>,
#  <IO.Sentence at 0x1064ec550>,
#  <IO.Sentence at 0x1064ec850>,
#  <IO.Sentence at 0x1064ecaf0>,
#  <IO.Sentence at 0x1064f7250>,
#  <IO.Sentence at 0x1064f7910>,
#  <IO.Sentence at 0x1065020a0>,
#  <IO.Sentence at 0x1065026d0>,
#  <IO.Sentence at 0x106502c10>,
#  <IO.Sentence at 0x10650d100>,
#  <IO.Sentence at 0x10650db20>,
#  <IO.Sentence at 0x1065180d0>,
#  <IO.Sentence at 0x106518850>,
#  <IO.Sentence at 0x106518e80>,
#  <IO.Sentence at 0x106523520>,
#  <IO.Sentence at 0x106523b80>,
#  <IO.Sentence at 0x106523f10>,
#  <IO.Sentence at 0x10652f430>,
#  <IO.Sentence at 0x10652f910>,
#  <IO.Sentence at 0x10652fe20>,
#  <IO.Sentence at 0x106539220>,
#  <IO.Sentence at 0x106539610>,
#  <IO.Sentence at 0x106539a30>,
#  <IO.Sentence at 0x106539d30>,
#  <IO.Sentence at 0x106543310>,
#  <IO.Sentence at 0x106543c70>,
#  <IO.Sentence at 0x1065502e0>,
#  <IO.Sentence at 0x106550850>,
#  <IO.Sentence at 0x106550d00>,
#  <IO.Sentence at 0x10655b3a0>,
#  <IO.Sentence at 0x10655b730>,
#  <IO.Sentence at 0x106566190>,
#  <IO.Sentence at 0x106566730>,
#  <IO.Sentence at 0x106566c10>,
#  <IO.Sentence at 0x106566fa0>,
#  <IO.Sentence at 0x1065715b0>,
#  <IO.Sentence at 0x106571a00>,
#  <IO.Sentence at 0x106571c70>,
#  <IO.Sentence at 0x10657c1f0>,
#  <IO.Sentence at 0x10657c460>,
#  <IO.Sentence at 0x10657c9a0>,
#  <IO.Sentence at 0x10657cf70>,
#  <IO.Sentence at 0x106586370>,
#  <IO.Sentence at 0x106586640>,
#  <IO.Sentence at 0x1065868e0>,
#  <IO.Sentence at 0x106586be0>,
#  <IO.Sentence at 0x106586f10>,
#  <IO.Sentence at 0x106590160>,
#  <IO.Sentence at 0x106590a00>,
#  <IO.Sentence at 0x106590df0>,
#  <IO.Sentence at 0x10659a610>,
#  <IO.Sentence at 0x10659ab80>,
#  <IO.Sentence at 0x1065a71c0>,
#  <IO.Sentence at 0x1065a7490>,
#  <IO.Sentence at 0x1065a7a30>,
#  <IO.Sentence at 0x1065a7fd0>,
#  <IO.Sentence at 0x1065b1490>,
#  <IO.Sentence at 0x1065b1790>,
#  <IO.Sentence at 0x1065b1cd0>,
#  <IO.Sentence at 0x1065bd910>,
#  <IO.Sentence at 0x1065c8070>,
#  <IO.Sentence at 0x1065c85e0>,
#  <IO.Sentence at 0x1065c8ac0>,
#  <IO.Sentence at 0x1065d43d0>,
#  <IO.Sentence at 0x1065d47f0>,
#  <IO.Sentence at 0x1065d4d30>,
#  <IO.Sentence at 0x1065e0370>,
#  <IO.Sentence at 0x1065e07f0>,
#  <IO.Sentence at 0x1065e0f40>,
#  <IO.Sentence at 0x1065ea490>,
#  <IO.Sentence at 0x1065ea7f0>,
#  <IO.Sentence at 0x1065eaee0>,
#  <IO.Sentence at 0x1065f58e0>,
#  <IO.Sentence at 0x1065f5eb0>,
#  <IO.Sentence at 0x106600490>,
#  <IO.Sentence at 0x106600fa0>,
#  <IO.Sentence at 0x10660c340>,
#  <IO.Sentence at 0x10660caf0>,
#  <IO.Sentence at 0x106619250>,
#  <IO.Sentence at 0x1066197c0>,
#  <IO.Sentence at 0x106619dc0>,
#  <IO.Sentence at 0x106623370>,
#  <IO.Sentence at 0x106623580>,
#  <IO.Sentence at 0x106623940>,
#  <IO.Sentence at 0x106623f70>,
#  <IO.Sentence at 0x10662d2e0>,
#  <IO.Sentence at 0x10662d5e0>,
#  <IO.Sentence at 0x10662dcd0>,
#  <IO.Sentence at 0x1066372b0>,
#  <IO.Sentence at 0x106637970>,
#  <IO.Sentence at 0x106643310>,
#  <IO.Sentence at 0x106643d90>,
#  <IO.Sentence at 0x10664e190>,
#  <IO.Sentence at 0x10664e640>,
#  <IO.Sentence at 0x10664eca0>,
#  <IO.Sentence at 0x106659280>,
#  <IO.Sentence at 0x106659af0>,
#  <IO.Sentence at 0x106666430>,
#  <IO.Sentence at 0x106666790>,
#  <IO.Sentence at 0x106666c10>,
#  <IO.Sentence at 0x106670250>,
#  <IO.Sentence at 0x106670790>,
#  <IO.Sentence at 0x106670b50>,
#  <IO.Sentence at 0x10667b520>,
#  <IO.Sentence at 0x10667bb20>,
#  <IO.Sentence at 0x1066861f0>,
#  <IO.Sentence at 0x106686af0>,
#  <IO.Sentence at 0x106692730>,
#  <IO.Sentence at 0x106692d90>,
#  <IO.Sentence at 0x10669e4c0>,
#  <IO.Sentence at 0x10669ef40>,
#  <IO.Sentence at 0x1066aa5b0>,
#  <IO.Sentence at 0x1066aae20>,
#  <IO.Sentence at 0x1066b6370>,
#  <IO.Sentence at 0x1066b6a30>,
#  <IO.Sentence at 0x1066c01c0>,
#  <IO.Sentence at 0x1066c06d0>,
#  <IO.Sentence at 0x1066c0d00>,
#  <IO.Sentence at 0x1066cc550>,
#  <IO.Sentence at 0x1066cc880>,
#  <IO.Sentence at 0x1066ccac0>,
#  <IO.Sentence at 0x1066d60d0>,
#  <IO.Sentence at 0x1066d6730>,
#  <IO.Sentence at 0x1066d69d0>,
#  <IO.Sentence at 0x1066d6e80>,
#  <IO.Sentence at 0x1066e1460>,
#  <IO.Sentence at 0x1066e18b0>,
#  <IO.Sentence at 0x1066e1cd0>]

# %%
train_path_en_5k = "Treebanks/english/train/wsj_train.only-projective.first-5k.conll06"
reader_en_5k = Reader(train_path_en_5k)
train_data_en_5k = Data(reader_en_5k.read_file())
train_data_en_5k.sentences
# Out:
# [<IO.Sentence at 0x1066eaa00>,
#  <IO.Sentence at 0x1066eab80>,
#  <IO.Sentence at 0x1066f6070>,
#  <IO.Sentence at 0x1066f6340>,
#  <IO.Sentence at 0x1066f6940>,
#  <IO.Sentence at 0x1066f6ca0>,
#  <IO.Sentence at 0x1066f6ee0>,
#  <IO.Sentence at 0x106700130>,
#  <IO.Sentence at 0x1067004f0>,
#  <IO.Sentence at 0x106700a30>,
#  <IO.Sentence at 0x10670b190>,
#  <IO.Sentence at 0x10670b970>,
#  <IO.Sentence at 0x10670bd30>,
#  <IO.Sentence at 0x106717640>,
#  <IO.Sentence at 0x106717940>,
#  <IO.Sentence at 0x106717f70>,
#  <IO.Sentence at 0x1067213a0>,
#  <IO.Sentence at 0x106721cd0>,
#  <IO.Sentence at 0x10672e430>,
#  <IO.Sentence at 0x10672e790>,
#  <IO.Sentence at 0x10672e9d0>,
#  <IO.Sentence at 0x1067383a0>,
#  <IO.Sentence at 0x106738790>,
#  <IO.Sentence at 0x106738a00>,
#  <IO.Sentence at 0x106738f70>,
#  <IO.Sentence at 0x1067433d0>,
#  <IO.Sentence at 0x106743880>,
#  <IO.Sentence at 0x106743fa0>,
#  <IO.Sentence at 0x10674d8b0>,
#  <IO.Sentence at 0x10674dd60>,
#  <IO.Sentence at 0x106759190>,
#  <IO.Sentence at 0x106759670>,
#  <IO.Sentence at 0x106759c70>,
#  <IO.Sentence at 0x1067643d0>,
#  <IO.Sentence at 0x1067647f0>,
#  <IO.Sentence at 0x106764be0>,
#  <IO.Sentence at 0x106764e50>,
#  <IO.Sentence at 0x10676e5e0>,
#  <IO.Sentence at 0x10676eb80>,
#  <IO.Sentence at 0x10677a0a0>,
#  <IO.Sentence at 0x10677a730>,
#  <IO.Sentence at 0x10677ac10>,
#  <IO.Sentence at 0x106784340>,
#  <IO.Sentence at 0x106784880>,
#  <IO.Sentence at 0x106784f40>,
#  <IO.Sentence at 0x106790400>,
#  <IO.Sentence at 0x106790a00>,
#  <IO.Sentence at 0x106790f10>,
#  <IO.Sentence at 0x10679a820>,
#  <IO.Sentence at 0x10679ab20>,
#  <IO.Sentence at 0x1067a6400>,
#  <IO.Sentence at 0x1067a6fd0>,
#  <IO.Sentence at 0x1067b15b0>,
#  <IO.Sentence at 0x1067b19a0>,
#  <IO.Sentence at 0x1067b1c70>,
#  <IO.Sentence at 0x1067bd130>,
#  <IO.Sentence at 0x1067bd610>,
#  <IO.Sentence at 0x1067c8220>,
#  <IO.Sentence at 0x1067c8940>,
#  <IO.Sentence at 0x1067d3220>,
#  <IO.Sentence at 0x1067d3880>,
#  <IO.Sentence at 0x1067d3e20>,
#  <IO.Sentence at 0x1067de8b0>,
#  <IO.Sentence at 0x1067dea90>,
#  <IO.Sentence at 0x1067e9460>,
#  <IO.Sentence at 0x1067e9f10>,
#  <IO.Sentence at 0x1067f6a00>,
#  <IO.Sentence at 0x1067f6f40>,
#  <IO.Sentence at 0x106801820>,
#  <IO.Sentence at 0x106801af0>,
#  <IO.Sentence at 0x106801e50>,
#  <IO.Sentence at 0x10680b0d0>,
#  <IO.Sentence at 0x10680b4c0>,
#  <IO.Sentence at 0x10680bb50>,
#  <IO.Sentence at 0x106816550>,
#  <IO.Sentence at 0x106816c10>,
#  <IO.Sentence at 0x106821370>,
#  <IO.Sentence at 0x106821580>,
#  <IO.Sentence at 0x106821dc0>,
#  <IO.Sentence at 0x106821f10>,
#  <IO.Sentence at 0x10682e100>,
#  <IO.Sentence at 0x10682e850>,
#  <IO.Sentence at 0x10682eca0>,
#  <IO.Sentence at 0x10682efa0>,
#  <IO.Sentence at 0x1068385e0>,
#  <IO.Sentence at 0x106838a00>,
#  <IO.Sentence at 0x106838e50>,
#  <IO.Sentence at 0x1068432b0>,
#  <IO.Sentence at 0x106843670>,
#  <IO.Sentence at 0x106843a60>,
#  <IO.Sentence at 0x10684d040>,
#  <IO.Sentence at 0x10684d640>,
#  <IO.Sentence at 0x10684dfd0>,
#  <IO.Sentence at 0x106858430>,
#  <IO.Sentence at 0x106858a30>,
#  <IO.Sentence at 0x106864040>,
#  <IO.Sentence at 0x106864730>,
#  <IO.Sentence at 0x1068649d0>,
#  <IO.Sentence at 0x10686e280>,
#  <IO.Sentence at 0x10686e7c0>,
#  <IO.Sentence at 0x10686ec70>,
#  <IO.Sentence at 0x1068793d0>,
#  <IO.Sentence at 0x106879ac0>,
#  <IO.Sentence at 0x106879e50>,
#  <IO.Sentence at 0x1068831f0>,
#  <IO.Sentence at 0x106883760>,
#  <IO.Sentence at 0x106883f40>,
#  <IO.Sentence at 0x10688f220>,
#  <IO.Sentence at 0x10688f7c0>,
#  <IO.Sentence at 0x10688fb50>,
#  <IO.Sentence at 0x106899130>,
#  <IO.Sentence at 0x1068994c0>,
#  <IO.Sentence at 0x106899760>,
#  <IO.Sentence at 0x106899cd0>,
#  <IO.Sentence at 0x1068a5340>,
#  <IO.Sentence at 0x1068a5c40>,
#  <IO.Sentence at 0x1068b01c0>,
#  <IO.Sentence at 0x1068b0730>,
#  <IO.Sentence at 0x1068b0c10>,
#  <IO.Sentence at 0x1068bc280>,
#  <IO.Sentence at 0x1068bc6a0>,
#  <IO.Sentence at 0x1068bcaf0>,
#  <IO.Sentence at 0x1068c7250>,
#  <IO.Sentence at 0x1068c74f0>,
#  <IO.Sentence at 0x1068c7ca0>,
#  <IO.Sentence at 0x1068d1220>,
#  <IO.Sentence at 0x1068d1be0>,
#  <IO.Sentence at 0x1068dd160>,
#  <IO.Sentence at 0x1068dd4c0>,
#  <IO.Sentence at 0x1068ddaf0>,
#  <IO.Sentence at 0x1068ddeb0>,
#  <IO.Sentence at 0x1068e63d0>,
#  <IO.Sentence at 0x1068e6ac0>,
#  <IO.Sentence at 0x1068f2160>,
#  <IO.Sentence at 0x1068f26d0>,
#  <IO.Sentence at 0x1068f2dc0>,
#  <IO.Sentence at 0x1068fd310>,
#  <IO.Sentence at 0x1068fdac0>,
#  <IO.Sentence at 0x1069081c0>,
#  <IO.Sentence at 0x106908640>,
#  <IO.Sentence at 0x106908ca0>,
#  <IO.Sentence at 0x106913340>,
#  <IO.Sentence at 0x106913a00>,
#  <IO.Sentence at 0x106913f10>,
#  <IO.Sentence at 0x10691e520>,
#  <IO.Sentence at 0x10691e8e0>,
#  <IO.Sentence at 0x10692b160>,
#  <IO.Sentence at 0x10692b760>,
#  <IO.Sentence at 0x10692bc70>,
#  <IO.Sentence at 0x106935130>,
#  <IO.Sentence at 0x106935700>,
#  <IO.Sentence at 0x106935b50>,
#  <IO.Sentence at 0x106940130>,
#  <IO.Sentence at 0x106940520>,
#  <IO.Sentence at 0x106940940>,
#  <IO.Sentence at 0x10694b130>,
#  <IO.Sentence at 0x10694b430>,
#  <IO.Sentence at 0x10694b850>,
#  <IO.Sentence at 0x1069563a0>,
#  <IO.Sentence at 0x1069567c0>,
#  <IO.Sentence at 0x106956f40>,
#  <IO.Sentence at 0x1069612e0>,
#  <IO.Sentence at 0x106961af0>,
#  <IO.Sentence at 0x106961f10>,
#  <IO.Sentence at 0x10696b490>,
#  <IO.Sentence at 0x10696baf0>,
#  <IO.Sentence at 0x1069770d0>,
#  <IO.Sentence at 0x1069774c0>,
#  <IO.Sentence at 0x1069777f0>,
#  <IO.Sentence at 0x106977fa0>,
#  <IO.Sentence at 0x1069817f0>,
#  <IO.Sentence at 0x106981a30>,
#  <IO.Sentence at 0x106981dc0>,
#  <IO.Sentence at 0x10698c490>,
#  <IO.Sentence at 0x10698c850>,
#  <IO.Sentence at 0x10698cf10>,
#  <IO.Sentence at 0x1069964f0>,
#  <IO.Sentence at 0x106996e20>,
#  <IO.Sentence at 0x1069a2280>,
#  <IO.Sentence at 0x1069a26d0>,
#  <IO.Sentence at 0x1069a2b50>,
#  <IO.Sentence at 0x1069a2e80>,
#  <IO.Sentence at 0x1069ac3d0>,
#  <IO.Sentence at 0x1069ac880>,
#  <IO.Sentence at 0x1069acdc0>,
#  <IO.Sentence at 0x1069b6550>,
#  <IO.Sentence at 0x1069b67c0>,
#  <IO.Sentence at 0x1069b68b0>,
#  <IO.Sentence at 0x1069b6e20>,
#  <IO.Sentence at 0x1069c1310>,
#  <IO.Sentence at 0x1069c1c10>,
#  <IO.Sentence at 0x1069cd370>,
#  <IO.Sentence at 0x1069cd730>,
#  <IO.Sentence at 0x1069cdbe0>,
#  <IO.Sentence at 0x1069d8100>,
#  <IO.Sentence at 0x1069d8550>,
#  <IO.Sentence at 0x1069d8730>,
#  <IO.Sentence at 0x1069e2130>,
#  <IO.Sentence at 0x1069e25b0>,
#  <IO.Sentence at 0x1069e29a0>,
#  <IO.Sentence at 0x1069e2eb0>,
#  <IO.Sentence at 0x1069ed310>,
#  <IO.Sentence at 0x1069ed8b0>,
#  <IO.Sentence at 0x1069f7040>,
#  <IO.Sentence at 0x1069f7430>,
#  <IO.Sentence at 0x1069f77c0>,
#  <IO.Sentence at 0x1069f7d90>,
#  <IO.Sentence at 0x106a02160>,
#  <IO.Sentence at 0x106a02640>,
#  <IO.Sentence at 0x106a0e1f0>,
#  <IO.Sentence at 0x106a0e3a0>,
#  <IO.Sentence at 0x106a0e880>,
#  <IO.Sentence at 0x106a0ee80>,
#  <IO.Sentence at 0x106a181f0>,
#  <IO.Sentence at 0x106a18520>,
#  <IO.Sentence at 0x106a186a0>,
#  <IO.Sentence at 0x106a18f10>,
#  <IO.Sentence at 0x106a23610>,
#  <IO.Sentence at 0x106a23dc0>,
#  <IO.Sentence at 0x106a2d160>,
#  <IO.Sentence at 0x106a2d430>,
#  <IO.Sentence at 0x106a2d9a0>,
#  <IO.Sentence at 0x106a2dd30>,
#  <IO.Sentence at 0x106a381f0>,
#  <IO.Sentence at 0x106a38a00>,
#  <IO.Sentence at 0x106a38eb0>,
#  <IO.Sentence at 0x106a426a0>,
#  <IO.Sentence at 0x106a42a00>,
#  <IO.Sentence at 0x106a42fa0>,
#  <IO.Sentence at 0x106a4d160>,
#  <IO.Sentence at 0x106a4d2b0>,
#  <IO.Sentence at 0x106a4d5e0>,
#  <IO.Sentence at 0x106a4dac0>,
#  <IO.Sentence at 0x106a4dc40>,
#  <IO.Sentence at 0x106a562e0>,
#  <IO.Sentence at 0x106a56760>,
#  <IO.Sentence at 0x106a569d0>,
#  <IO.Sentence at 0x106a56df0>,
#  <IO.Sentence at 0x106a61220>,
#  <IO.Sentence at 0x106a61370>,
#  <IO.Sentence at 0x106a61550>,
#  <IO.Sentence at 0x106a61850>,
#  <IO.Sentence at 0x106a61eb0>,
#  <IO.Sentence at 0x106a6a430>,
#  <IO.Sentence at 0x106a6a790>,
#  <IO.Sentence at 0x106a6aa00>,
#  <IO.Sentence at 0x106a6ab80>,
#  <IO.Sentence at 0x106a740a0>,
#  <IO.Sentence at 0x106a74520>,
#  <IO.Sentence at 0x106a74af0>,
#  <IO.Sentence at 0x106a7f0a0>,
#  <IO.Sentence at 0x106a7f280>,
#  <IO.Sentence at 0x106a7f430>,
#  <IO.Sentence at 0x106a7f760>,
#  <IO.Sentence at 0x106a7f8e0>,
#  <IO.Sentence at 0x106a7fb80>,
#  <IO.Sentence at 0x106a7ff10>,
#  <IO.Sentence at 0x106a880d0>,
#  <IO.Sentence at 0x106a88550>,
#  <IO.Sentence at 0x106a88ca0>,
#  <IO.Sentence at 0x106a93160>,
#  <IO.Sentence at 0x106a93790>,
#  <IO.Sentence at 0x106a93a60>,
#  <IO.Sentence at 0x106a9e130>,
#  <IO.Sentence at 0x106a9e580>,
#  <IO.Sentence at 0x106a9e8e0>,
#  <IO.Sentence at 0x106a9ef10>,
#  <IO.Sentence at 0x106aaa670>,
#  <IO.Sentence at 0x106aaa820>,
#  <IO.Sentence at 0x106aaad00>,
#  <IO.Sentence at 0x106aaaee0>,
#  <IO.Sentence at 0x106ab3250>,
#  <IO.Sentence at 0x106ab3760>,
#  <IO.Sentence at 0x106ab3b20>,
#  <IO.Sentence at 0x106ab3d90>,
#  <IO.Sentence at 0x106ab3f40>,
#  <IO.Sentence at 0x106abd2e0>,
#  <IO.Sentence at 0x106abd550>,
#  <IO.Sentence at 0x106abd7f0>,
#  <IO.Sentence at 0x106ac63d0>,
#  <IO.Sentence at 0x106ac6af0>,
#  <IO.Sentence at 0x106ad1130>,
#  <IO.Sentence at 0x106ad1700>,
#  <IO.Sentence at 0x106ad18e0>,
#  <IO.Sentence at 0x106ad1d90>,
#  <IO.Sentence at 0x106ada490>,
#  <IO.Sentence at 0x106ada7c0>,
#  <IO.Sentence at 0x106ae5490>,
#  <IO.Sentence at 0x106ae5b20>,
#  <IO.Sentence at 0x106ae5fa0>,
#  <IO.Sentence at 0x106aef4f0>,
#  <IO.Sentence at 0x106aef850>,
#  <IO.Sentence at 0x106afa250>,
#  <IO.Sentence at 0x106afa790>,
#  <IO.Sentence at 0x106afaca0>,
#  <IO.Sentence at 0x106afae50>,
#  <IO.Sentence at 0x106b03850>,
#  <IO.Sentence at 0x106b03a00>,
#  <IO.Sentence at 0x106b03c40>,
#  <IO.Sentence at 0x106b0e0d0>,
#  <IO.Sentence at 0x106b0e7c0>,
#  <IO.Sentence at 0x106b0eaf0>,
#  <IO.Sentence at 0x106b0ee50>,
#  <IO.Sentence at 0x106b181f0>,
#  <IO.Sentence at 0x106b18460>,
#  <IO.Sentence at 0x106b18970>,
#  <IO.Sentence at 0x106b18d30>,
#  <IO.Sentence at 0x106b222e0>,
#  <IO.Sentence at 0x106b22640>,
#  <IO.Sentence at 0x106b22be0>,
#  <IO.Sentence at 0x106b2e1c0>,
#  <IO.Sentence at 0x106b2e8e0>,
#  <IO.Sentence at 0x106b2ed90>,
#  <IO.Sentence at 0x106b380d0>,
#  <IO.Sentence at 0x106b389d0>,
#  <IO.Sentence at 0x106b38fd0>,
#  <IO.Sentence at 0x106b433a0>,
#  <IO.Sentence at 0x106b435b0>,
#  <IO.Sentence at 0x106b4d0a0>,
#  <IO.Sentence at 0x106b4d6d0>,
#  <IO.Sentence at 0x106b4dbe0>,
#  <IO.Sentence at 0x106b58100>,
#  <IO.Sentence at 0x106b58340>,
#  <IO.Sentence at 0x106b58640>,
#  <IO.Sentence at 0x106b58b80>,
#  <IO.Sentence at 0x106b61160>,
#  <IO.Sentence at 0x106b615b0>,
#  <IO.Sentence at 0x106b61ac0>,
#  <IO.Sentence at 0x106b6c070>,
#  <IO.Sentence at 0x106b6c3a0>,
#  <IO.Sentence at 0x106b6c580>,
#  <IO.Sentence at 0x106b6c940>,
#  <IO.Sentence at 0x106b6ce50>,
#  <IO.Sentence at 0x106b75370>,
#  <IO.Sentence at 0x106b75880>,
#  <IO.Sentence at 0x106b75e80>,
#  <IO.Sentence at 0x106b80580>,
#  <IO.Sentence at 0x106b80dc0>,
#  <IO.Sentence at 0x106b8c490>,
#  <IO.Sentence at 0x106b8ca00>,
#  <IO.Sentence at 0x106b8cc40>,
#  <IO.Sentence at 0x106b970d0>,
#  <IO.Sentence at 0x106b97400>,
#  <IO.Sentence at 0x106b97910>,
#  <IO.Sentence at 0x106b97f70>,
#  <IO.Sentence at 0x106ba2220>,
#  <IO.Sentence at 0x106ba26d0>,
#  <IO.Sentence at 0x106ba2d60>,
#  <IO.Sentence at 0x106bac400>,
#  <IO.Sentence at 0x106bac8e0>,
#  <IO.Sentence at 0x106bb70d0>,
#  <IO.Sentence at 0x106bb7670>,
#  <IO.Sentence at 0x106bb7b80>,
#  <IO.Sentence at 0x106bb7f70>,
#  <IO.Sentence at 0x106bc1550>,
#  <IO.Sentence at 0x106bc1ac0>,
#  <IO.Sentence at 0x106bcc4c0>,
#  <IO.Sentence at 0x106bcca30>,
#  <IO.Sentence at 0x106bccdf0>,
#  <IO.Sentence at 0x106bd81c0>,
#  <IO.Sentence at 0x106bd8730>,
#  <IO.Sentence at 0x106bd8e20>,
#  <IO.Sentence at 0x106be3280>,
#  <IO.Sentence at 0x106be37f0>,
#  <IO.Sentence at 0x106be3c10>,
#  <IO.Sentence at 0x106bee0d0>,
#  <IO.Sentence at 0x106bee520>,
#  <IO.Sentence at 0x106bee850>,
#  <IO.Sentence at 0x106beef10>,
#  <IO.Sentence at 0x106bf8310>,
#  <IO.Sentence at 0x106bf88b0>,
#  <IO.Sentence at 0x106bf8d90>,
#  <IO.Sentence at 0x106c02040>,
#  <IO.Sentence at 0x106c025b0>,
#  <IO.Sentence at 0x106c029a0>,
#  <IO.Sentence at 0x106c02df0>,
#  <IO.Sentence at 0x106c0c100>,
#  <IO.Sentence at 0x106c0c5b0>,
#  <IO.Sentence at 0x106c0ca60>,
#  <IO.Sentence at 0x106c0cee0>,
#  <IO.Sentence at 0x106c172e0>,
#  <IO.Sentence at 0x106c17730>,
#  <IO.Sentence at 0x106c17a30>,
#  <IO.Sentence at 0x106c21160>,
#  <IO.Sentence at 0x106c218e0>,
#  <IO.Sentence at 0x106c21d30>,
#  <IO.Sentence at 0x106c2c4c0>,
#  <IO.Sentence at 0x106c2cee0>,
#  <IO.Sentence at 0x106c392e0>,
#  <IO.Sentence at 0x106c39580>,
#  <IO.Sentence at 0x106c39760>,
#  <IO.Sentence at 0x106c39be0>,
#  <IO.Sentence at 0x106c42520>,
#  <IO.Sentence at 0x106c4e190>,
#  <IO.Sentence at 0x106c4e490>,
#  <IO.Sentence at 0x106c4eb80>,
#  <IO.Sentence at 0x106c4ee80>,
#  <IO.Sentence at 0x106c584f0>,
#  <IO.Sentence at 0x106c58790>,
#  <IO.Sentence at 0x106c58b50>,
#  <IO.Sentence at 0x106c58d90>,
#  <IO.Sentence at 0x106c62220>,
#  <IO.Sentence at 0x106c62460>,
#  <IO.Sentence at 0x106c62610>,
#  <IO.Sentence at 0x106c62820>,
#  <IO.Sentence at 0x106c62ee0>,
#  <IO.Sentence at 0x106c6c310>,
#  <IO.Sentence at 0x106c6caf0>,
#  <IO.Sentence at 0x106c78190>,
#  <IO.Sentence at 0x106c788e0>,
#  <IO.Sentence at 0x106c831f0>,
#  <IO.Sentence at 0x106c837c0>,
#  <IO.Sentence at 0x106c838e0>,
#  <IO.Sentence at 0x106c83b20>,
#  <IO.Sentence at 0x106c83eb0>,
#  <IO.Sentence at 0x106c8e0a0>,
#  <IO.Sentence at 0x106c8e7f0>,
#  <IO.Sentence at 0x106c8e9d0>,
#  <IO.Sentence at 0x106c8ee20>,
#  <IO.Sentence at 0x106c991c0>,
#  <IO.Sentence at 0x106c996d0>,
#  <IO.Sentence at 0x106c99d00>,
#  <IO.Sentence at 0x106ca30d0>,
#  <IO.Sentence at 0x106ca3880>,
#  <IO.Sentence at 0x106ca3a30>,
#  <IO.Sentence at 0x106ca3c40>,
#  <IO.Sentence at 0x106cae460>,
#  <IO.Sentence at 0x106cba2b0>,
#  <IO.Sentence at 0x106cba7c0>,
#  <IO.Sentence at 0x106cbaeb0>,
#  <IO.Sentence at 0x106cc6280>,
#  <IO.Sentence at 0x106cc6670>,
#  <IO.Sentence at 0x106cc6b80>,
#  <IO.Sentence at 0x106cc6ee0>,
#  <IO.Sentence at 0x106cd03a0>,
#  <IO.Sentence at 0x106cd0610>,
#  <IO.Sentence at 0x106cd0dc0>,
#  <IO.Sentence at 0x106cdb940>,
#  <IO.Sentence at 0x106ce70d0>,
#  <IO.Sentence at 0x106ce75b0>,
#  <IO.Sentence at 0x106ce7e50>,
#  <IO.Sentence at 0x106cf2340>,
#  <IO.Sentence at 0x106cf2a00>,
#  <IO.Sentence at 0x106cf2c40>,
#  <IO.Sentence at 0x106cfd160>,
#  <IO.Sentence at 0x106cfd550>,
#  <IO.Sentence at 0x106cfda90>,
#  <IO.Sentence at 0x106cfde20>,
#  <IO.Sentence at 0x106d07610>,
#  <IO.Sentence at 0x106d07a60>,
#  <IO.Sentence at 0x106d07f10>,
#  <IO.Sentence at 0x106d12190>,
#  <IO.Sentence at 0x106d124f0>,
#  <IO.Sentence at 0x106d12c40>,
#  <IO.Sentence at 0x106d1c4c0>,
#  <IO.Sentence at 0x106d1c7f0>,
#  <IO.Sentence at 0x106d1cdc0>,
#  <IO.Sentence at 0x106d28700>,
#  <IO.Sentence at 0x106d28eb0>,
#  <IO.Sentence at 0x106d33850>,
#  <IO.Sentence at 0x106d3f100>,
#  <IO.Sentence at 0x106d3f790>,
#  <IO.Sentence at 0x106d3faf0>,
#  <IO.Sentence at 0x106d3feb0>,
#  <IO.Sentence at 0x106d4a340>,
#  <IO.Sentence at 0x106d4ac40>,
#  <IO.Sentence at 0x106d4ae80>,
#  <IO.Sentence at 0x106d542e0>,
#  <IO.Sentence at 0x106d548e0>,
#  <IO.Sentence at 0x106d54ac0>,
#  <IO.Sentence at 0x106d5f0a0>,
#  <IO.Sentence at 0x106d5f460>,
#  <IO.Sentence at 0x106d5fbb0>,
#  <IO.Sentence at 0x106d5fd90>,
#  <IO.Sentence at 0x106d694c0>,
#  <IO.Sentence at 0x106d69820>,
#  <IO.Sentence at 0x106d69df0>,
#  <IO.Sentence at 0x106d74400>,
#  <IO.Sentence at 0x106d74af0>,
#  <IO.Sentence at 0x106d7f1c0>,
#  <IO.Sentence at 0x106d7f760>,
#  <IO.Sentence at 0x106d7fb20>,
#  <IO.Sentence at 0x106d8a1c0>,
#  <IO.Sentence at 0x106d8a5b0>,
#  <IO.Sentence at 0x106d8aa30>,
#  <IO.Sentence at 0x106d8af70>,
#  <IO.Sentence at 0x106d943d0>,
#  <IO.Sentence at 0x106d94820>,
#  <IO.Sentence at 0x106d94cd0>,
#  <IO.Sentence at 0x106d94fd0>,
#  <IO.Sentence at 0x106d9f730>,
#  <IO.Sentence at 0x106d9fa90>,
#  <IO.Sentence at 0x106d9ff70>,
#  <IO.Sentence at 0x106daa490>,
#  <IO.Sentence at 0x106daa8e0>,
#  <IO.Sentence at 0x106daaca0>,
#  <IO.Sentence at 0x106db5340>,
#  <IO.Sentence at 0x106db56d0>,
#  <IO.Sentence at 0x106db5eb0>,
#  <IO.Sentence at 0x106dc02b0>,
#  <IO.Sentence at 0x106dc0940>,
#  <IO.Sentence at 0x106dcb130>,
#  <IO.Sentence at 0x106dcb4f0>,
#  <IO.Sentence at 0x106dcb8b0>,
#  <IO.Sentence at 0x106dcbdc0>,
#  <IO.Sentence at 0x106dd6490>,
#  <IO.Sentence at 0x106dd68b0>,
#  <IO.Sentence at 0x106dd6bb0>,
#  <IO.Sentence at 0x106de0250>,
#  <IO.Sentence at 0x106de0c10>,
#  <IO.Sentence at 0x106ded550>,
#  <IO.Sentence at 0x106dedca0>,
#  <IO.Sentence at 0x106df8250>,
#  <IO.Sentence at 0x106df8610>,
#  <IO.Sentence at 0x106df8d00>,
#  <IO.Sentence at 0x106e031f0>,
#  <IO.Sentence at 0x106e03580>,
#  <IO.Sentence at 0x106e03a00>,
#  <IO.Sentence at 0x106e0e190>,
#  <IO.Sentence at 0x106e0e850>,
#  <IO.Sentence at 0x106e0ee20>,
#  <IO.Sentence at 0x106e18790>,
#  <IO.Sentence at 0x106e18fa0>,
#  <IO.Sentence at 0x106e24460>,
#  <IO.Sentence at 0x106e249d0>,
#  <IO.Sentence at 0x106e24e80>,
#  <IO.Sentence at 0x106e24f70>,
#  <IO.Sentence at 0x106e2e0a0>,
#  <IO.Sentence at 0x106e2e190>,
#  <IO.Sentence at 0x106e2e250>,
#  <IO.Sentence at 0x106e2e970>,
#  <IO.Sentence at 0x106e2efd0>,
#  <IO.Sentence at 0x106e39430>,
#  <IO.Sentence at 0x106e39bb0>,
#  <IO.Sentence at 0x106e44250>,
#  <IO.Sentence at 0x106e44ac0>,
#  <IO.Sentence at 0x106e4f2e0>,
#  <IO.Sentence at 0x106e4f9d0>,
#  <IO.Sentence at 0x106e5c220>,
#  <IO.Sentence at 0x106e5c8b0>,
#  <IO.Sentence at 0x106e67040>,
#  <IO.Sentence at 0x106e67370>,
#  <IO.Sentence at 0x106e676a0>,
#  <IO.Sentence at 0x106e72460>,
#  <IO.Sentence at 0x106e72a90>,
#  <IO.Sentence at 0x106e72cd0>,
#  <IO.Sentence at 0x106e72f40>,
#  <IO.Sentence at 0x106e7b6a0>,
#  <IO.Sentence at 0x106e7beb0>,
#  <IO.Sentence at 0x106e87790>,
#  <IO.Sentence at 0x106e87ee0>,
#  <IO.Sentence at 0x106e91130>,
#  <IO.Sentence at 0x106e918e0>,
#  <IO.Sentence at 0x106e91ca0>,
#  <IO.Sentence at 0x106ea86d0>,
#  <IO.Sentence at 0x106ea8eb0>,
#  <IO.Sentence at 0x106eb3370>,
#  <IO.Sentence at 0x106eb38b0>,
#  <IO.Sentence at 0x106eb3bb0>,
#  <IO.Sentence at 0x106ebe340>,
#  <IO.Sentence at 0x106ebe790>,
#  <IO.Sentence at 0x106ebed00>,
#  <IO.Sentence at 0x106ec8310>,
#  <IO.Sentence at 0x106ec89a0>,
#  <IO.Sentence at 0x106ec8df0>,
#  <IO.Sentence at 0x106ed45e0>,
#  <IO.Sentence at 0x106ed4c70>,
#  <IO.Sentence at 0x106ee0400>,
#  <IO.Sentence at 0x106ee0700>,
#  <IO.Sentence at 0x106ee0c40>,
#  <IO.Sentence at 0x106ee0e50>,
#  <IO.Sentence at 0x106eea4c0>,
#  <IO.Sentence at 0x106eea8b0>,
#  <IO.Sentence at 0x106eeaee0>,
#  <IO.Sentence at 0x106ef5610>,
#  <IO.Sentence at 0x106ef5850>,
#  <IO.Sentence at 0x106f01070>,
#  <IO.Sentence at 0x106f01490>,
#  <IO.Sentence at 0x106f01730>,
#  <IO.Sentence at 0x106f01b20>,
#  <IO.Sentence at 0x106f0b040>,
#  <IO.Sentence at 0x106f0b400>,
#  <IO.Sentence at 0x106f0b880>,
#  <IO.Sentence at 0x106f0bc10>,
#  <IO.Sentence at 0x106f152e0>,
#  <IO.Sentence at 0x106f15910>,
#  <IO.Sentence at 0x106f15b20>,
#  <IO.Sentence at 0x106f202b0>,
#  <IO.Sentence at 0x106f204c0>,
#  <IO.Sentence at 0x106f20730>,
#  <IO.Sentence at 0x106f20dc0>,
#  <IO.Sentence at 0x106f20fd0>,
#  <IO.Sentence at 0x106f29280>,
#  <IO.Sentence at 0x106f29610>,
#  <IO.Sentence at 0x106f29ac0>,
#  <IO.Sentence at 0x106f29c40>,
#  <IO.Sentence at 0x106f34160>,
#  <IO.Sentence at 0x106f34610>,
#  <IO.Sentence at 0x106f34ac0>,
#  <IO.Sentence at 0x106f3e1f0>,
#  <IO.Sentence at 0x106f3e940>,
#  <IO.Sentence at 0x106f4a130>,
#  <IO.Sentence at 0x106f4a9a0>,
#  <IO.Sentence at 0x106f4abe0>,
#  <IO.Sentence at 0x106f55160>,
#  <IO.Sentence at 0x106f557c0>,
#  <IO.Sentence at 0x106f55dc0>,
#  <IO.Sentence at 0x106f60310>,
#  <IO.Sentence at 0x106f60a60>,
#  <IO.Sentence at 0x106f6c1c0>,
#  <IO.Sentence at 0x106f6c5b0>,
#  <IO.Sentence at 0x106f6cbe0>,
#  <IO.Sentence at 0x106f6ce20>,
#  <IO.Sentence at 0x106f76490>,
#  <IO.Sentence at 0x106f76cd0>,
#  <IO.Sentence at 0x106f76ee0>,
#  <IO.Sentence at 0x106f82160>,
#  <IO.Sentence at 0x106f82850>,
#  <IO.Sentence at 0x106f82bb0>,
#  <IO.Sentence at 0x106f8d1f0>,
#  <IO.Sentence at 0x106f8d8e0>,
#  <IO.Sentence at 0x106f8ddf0>,
#  <IO.Sentence at 0x106f980d0>,
#  <IO.Sentence at 0x106f98670>,
#  <IO.Sentence at 0x106f98820>,
#  <IO.Sentence at 0x106f98a30>,
#  <IO.Sentence at 0x106f98fd0>,
#  <IO.Sentence at 0x106fa22e0>,
#  <IO.Sentence at 0x106fa2790>,
#  <IO.Sentence at 0x106fa2af0>,
#  <IO.Sentence at 0x106fa2f70>,
#  <IO.Sentence at 0x106fac160>,
#  <IO.Sentence at 0x106fac6a0>,
#  <IO.Sentence at 0x106fac940>,
#  <IO.Sentence at 0x106facb80>,
#  <IO.Sentence at 0x106fb6250>,
#  <IO.Sentence at 0x106fb68b0>,
#  <IO.Sentence at 0x106fb6ca0>,
#  <IO.Sentence at 0x106fc01f0>,
#  <IO.Sentence at 0x106fc0520>,
#  <IO.Sentence at 0x106fc0a60>,
#  <IO.Sentence at 0x106fcb0a0>,
#  <IO.Sentence at 0x106fcb610>,
#  <IO.Sentence at 0x106fcbc70>,
#  <IO.Sentence at 0x106fd71f0>,
#  <IO.Sentence at 0x106fd7c40>,
#  <IO.Sentence at 0x106fd7f10>,
#  <IO.Sentence at 0x106fe2640>,
#  <IO.Sentence at 0x106fe2b50>,
#  <IO.Sentence at 0x106fe2e20>,
#  <IO.Sentence at 0x106fed3a0>,
#  <IO.Sentence at 0x106fedb50>,
#  <IO.Sentence at 0x106ff92e0>,
#  <IO.Sentence at 0x106ff9580>,
#  <IO.Sentence at 0x106ff9b80>,
#  <IO.Sentence at 0x107003370>,
#  <IO.Sentence at 0x107003790>,
#  <IO.Sentence at 0x107003b50>,
#  <IO.Sentence at 0x107003fa0>,
#  <IO.Sentence at 0x10700d340>,
#  <IO.Sentence at 0x10700d6a0>,
#  <IO.Sentence at 0x107019250>,
#  <IO.Sentence at 0x107019820>,
#  <IO.Sentence at 0x107019e50>,
#  <IO.Sentence at 0x1070242b0>,
#  <IO.Sentence at 0x107024730>,
#  <IO.Sentence at 0x107024b20>,
#  <IO.Sentence at 0x1070300a0>,
#  <IO.Sentence at 0x107030760>,
#  <IO.Sentence at 0x10703a070>,
#  <IO.Sentence at 0x10703a460>,
#  <IO.Sentence at 0x10703aa60>,
#  <IO.Sentence at 0x10703af70>,
#  <IO.Sentence at 0x107045370>,
#  <IO.Sentence at 0x107045dc0>,
#  <IO.Sentence at 0x107050130>,
#  <IO.Sentence at 0x1070507c0>,
#  <IO.Sentence at 0x10705b130>,
#  <IO.Sentence at 0x10705b8e0>,
#  <IO.Sentence at 0x10705bd60>,
#  <IO.Sentence at 0x107066040>,
#  <IO.Sentence at 0x107066640>,
#  <IO.Sentence at 0x107066a30>,
#  <IO.Sentence at 0x107066e80>,
#  <IO.Sentence at 0x1070704f0>,
#  <IO.Sentence at 0x107070df0>,
#  <IO.Sentence at 0x10707c8b0>,
#  <IO.Sentence at 0x10707cd00>,
#  <IO.Sentence at 0x1070873a0>,
#  <IO.Sentence at 0x1070876a0>,
#  <IO.Sentence at 0x107087be0>,
#  <IO.Sentence at 0x107087e80>,
#  <IO.Sentence at 0x1070913a0>,
#  <IO.Sentence at 0x1070918e0>,
#  <IO.Sentence at 0x107091d00>,
#  <IO.Sentence at 0x10709c250>,
#  <IO.Sentence at 0x10709c670>,
#  <IO.Sentence at 0x10709cbb0>,
#  <IO.Sentence at 0x1070a80a0>,
#  <IO.Sentence at 0x1070a85e0>,
#  <IO.Sentence at 0x1070a8880>,
#  <IO.Sentence at 0x1070a8fa0>,
#  <IO.Sentence at 0x1070b2520>,
#  <IO.Sentence at 0x1070b2ca0>,
#  <IO.Sentence at 0x1070bc4f0>,
#  <IO.Sentence at 0x1070bcdc0>,
#  <IO.Sentence at 0x1070c82e0>,
#  <IO.Sentence at 0x1070c8a30>,
#  <IO.Sentence at 0x1070c8e80>,
#  <IO.Sentence at 0x1070d2580>,
#  <IO.Sentence at 0x1070d2c10>,
#  <IO.Sentence at 0x1070de1c0>,
#  <IO.Sentence at 0x1070deaf0>,
#  <IO.Sentence at 0x1070deee0>,
#  <IO.Sentence at 0x1070e8730>,
#  <IO.Sentence at 0x1070e89a0>,
#  <IO.Sentence at 0x1070e8c10>,
#  <IO.Sentence at 0x1070f4100>,
#  <IO.Sentence at 0x1070f4640>,
#  <IO.Sentence at 0x1070f4a60>,
#  <IO.Sentence at 0x1070ff4c0>,
#  <IO.Sentence at 0x1070ff8b0>,
#  <IO.Sentence at 0x10710a1c0>,
#  <IO.Sentence at 0x1071171f0>,
#  <IO.Sentence at 0x107117970>,
#  <IO.Sentence at 0x1071231f0>,
#  <IO.Sentence at 0x1071237c0>,
#  <IO.Sentence at 0x1071239d0>,
#  <IO.Sentence at 0x10712e0a0>,
#  <IO.Sentence at 0x10712e490>,
#  <IO.Sentence at 0x10712ec10>,
#  <IO.Sentence at 0x1071393d0>,
#  <IO.Sentence at 0x1071397c0>,
#  <IO.Sentence at 0x107139d30>,
#  <IO.Sentence at 0x107143340>,
#  <IO.Sentence at 0x107143850>,
#  <IO.Sentence at 0x107143f70>,
#  <IO.Sentence at 0x10714f910>,
#  <IO.Sentence at 0x10714fe80>,
#  <IO.Sentence at 0x107159610>,
#  <IO.Sentence at 0x107159d30>,
#  <IO.Sentence at 0x1071651c0>,
#  <IO.Sentence at 0x107165580>,
#  <IO.Sentence at 0x107165bb0>,
#  <IO.Sentence at 0x107165e50>,
#  <IO.Sentence at 0x107170460>,
#  <IO.Sentence at 0x107170970>,
#  <IO.Sentence at 0x107170d60>,
#  <IO.Sentence at 0x10717b460>,
#  <IO.Sentence at 0x10717bd90>,
#  <IO.Sentence at 0x10717bfa0>,
#  <IO.Sentence at 0x1071852e0>,
#  <IO.Sentence at 0x107185610>,
#  <IO.Sentence at 0x107185f40>,
#  <IO.Sentence at 0x107190550>,
#  <IO.Sentence at 0x107190be0>,
#  <IO.Sentence at 0x10719d130>,
#  <IO.Sentence at 0x10719d370>,
#  <IO.Sentence at 0x10719d4f0>,
#  <IO.Sentence at 0x10719dac0>,
#  <IO.Sentence at 0x10719de80>,
#  <IO.Sentence at 0x1071a6370>,
#  <IO.Sentence at 0x1071a6a00>,
#  <IO.Sentence at 0x1071b1070>,
#  <IO.Sentence at 0x1071b1340>,
#  <IO.Sentence at 0x1071b1850>,
#  <IO.Sentence at 0x1071b1bb0>,
#  <IO.Sentence at 0x1071bc160>,
#  <IO.Sentence at 0x1071bc520>,
#  <IO.Sentence at 0x1071bca60>,
#  <IO.Sentence at 0x1071bce80>,
#  <IO.Sentence at 0x1071c7280>,
#  <IO.Sentence at 0x1071c79a0>,
#  <IO.Sentence at 0x1071d1280>,
#  <IO.Sentence at 0x1071d1bb0>,
#  <IO.Sentence at 0x1071d1f10>,
#  <IO.Sentence at 0x1071dd670>,
#  <IO.Sentence at 0x1071dd9a0>,
#  <IO.Sentence at 0x1071e90d0>,
#  <IO.Sentence at 0x1071e96d0>,
#  <IO.Sentence at 0x1071e9bb0>,
#  <IO.Sentence at 0x1071f3070>,
#  <IO.Sentence at 0x1071f35e0>,
#  <IO.Sentence at 0x1071f37f0>,
#  <IO.Sentence at 0x1071f3b50>,
#  <IO.Sentence at 0x1071fe3d0>,
#  <IO.Sentence at 0x1071fe910>,
#  <IO.Sentence at 0x1071fec40>,
#  <IO.Sentence at 0x107208370>,
#  <IO.Sentence at 0x1072085b0>,
#  <IO.Sentence at 0x107208b20>,
#  <IO.Sentence at 0x107208ca0>,
#  <IO.Sentence at 0x1072135b0>,
#  <IO.Sentence at 0x107213b80>,
#  <IO.Sentence at 0x10721e1c0>,
#  <IO.Sentence at 0x10721e310>,
#  <IO.Sentence at 0x10721ebe0>,
#  <IO.Sentence at 0x10721efa0>,
#  <IO.Sentence at 0x10722a550>,
#  <IO.Sentence at 0x10722a880>,
#  <IO.Sentence at 0x10722adf0>,
#  <IO.Sentence at 0x1072332b0>,
#  <IO.Sentence at 0x1072335e0>,
#  <IO.Sentence at 0x1072339d0>,
#  <IO.Sentence at 0x107233e50>,
#  <IO.Sentence at 0x10723e1c0>,
#  <IO.Sentence at 0x10723e760>,
#  <IO.Sentence at 0x10723ea30>,
#  <IO.Sentence at 0x1072490a0>,
#  <IO.Sentence at 0x1072499a0>,
#  <IO.Sentence at 0x107249b50>,
#  <IO.Sentence at 0x107249c70>,
#  <IO.Sentence at 0x107253670>,
#  <IO.Sentence at 0x107253a30>,
#  <IO.Sentence at 0x10725f3a0>,
#  <IO.Sentence at 0x10725fb20>,
#  <IO.Sentence at 0x10725fc40>,
#  <IO.Sentence at 0x10726a670>,
#  <IO.Sentence at 0x10726aa30>,
#  <IO.Sentence at 0x10726abb0>,
#  <IO.Sentence at 0x107275310>,
#  <IO.Sentence at 0x1072756a0>,
#  <IO.Sentence at 0x107275f40>,
#  <IO.Sentence at 0x10727f4c0>,
#  <IO.Sentence at 0x10727fac0>,
#  <IO.Sentence at 0x10728b070>,
#  <IO.Sentence at 0x10728b4f0>,
#  <IO.Sentence at 0x10728b820>,
#  <IO.Sentence at 0x10728bd00>,
#  <IO.Sentence at 0x1072942e0>,
#  <IO.Sentence at 0x107294d30>,
#  <IO.Sentence at 0x1072a0130>,
#  <IO.Sentence at 0x1072a0820>,
#  <IO.Sentence at 0x1072a0be0>,
#  <IO.Sentence at 0x1072ab130>,
#  <IO.Sentence at 0x1072ab460>,
#  <IO.Sentence at 0x1072abd60>,
#  <IO.Sentence at 0x1072b61f0>,
#  <IO.Sentence at 0x1072b6af0>,
#  <IO.Sentence at 0x1072b6f70>,
#  <IO.Sentence at 0x1072c1310>,
#  <IO.Sentence at 0x1072c1610>,
#  <IO.Sentence at 0x1072c1940>,
#  <IO.Sentence at 0x1072cc040>,
#  <IO.Sentence at 0x1072cc820>,
#  <IO.Sentence at 0x1072cce50>,
#  <IO.Sentence at 0x1072d7490>,
#  <IO.Sentence at 0x1072d7f10>,
#  <IO.Sentence at 0x1072e22b0>,
#  <IO.Sentence at 0x1072e2790>,
#  <IO.Sentence at 0x1072e2a30>,
#  <IO.Sentence at 0x1072ed130>,
#  <IO.Sentence at 0x1072ed940>,
#  <IO.Sentence at 0x1072f90a0>,
#  <IO.Sentence at 0x1072f9700>,
#  <IO.Sentence at 0x1072f9a90>,
#  <IO.Sentence at 0x1072f9e80>,
#  <IO.Sentence at 0x107302370>,
#  <IO.Sentence at 0x1073027c0>,
#  <IO.Sentence at 0x107302a60>,
#  <IO.Sentence at 0x107302c10>,
#  <IO.Sentence at 0x10730d340>,
#  <IO.Sentence at 0x10730d7c0>,
#  <IO.Sentence at 0x10730d970>,
#  <IO.Sentence at 0x10730df40>,
#  <IO.Sentence at 0x107317160>,
#  <IO.Sentence at 0x1073175e0>,
#  <IO.Sentence at 0x107317af0>,
#  <IO.Sentence at 0x1073220d0>,
#  <IO.Sentence at 0x107322700>,
#  <IO.Sentence at 0x107322c70>,
#  <IO.Sentence at 0x107322f40>,
#  <IO.Sentence at 0x10732b460>,
#  <IO.Sentence at 0x10732b970>,
#  <IO.Sentence at 0x10732bc70>,
#  <IO.Sentence at 0x10732bf10>,
#  <IO.Sentence at 0x107336670>,
#  <IO.Sentence at 0x107336d30>,
#  <IO.Sentence at 0x1073424c0>,
#  <IO.Sentence at 0x107342af0>,
#  <IO.Sentence at 0x10734f070>,
#  <IO.Sentence at 0x10734f520>,
#  <IO.Sentence at 0x10734ff40>,
#  <IO.Sentence at 0x10735a4f0>,
#  <IO.Sentence at 0x10735ac70>,
#  <IO.Sentence at 0x1073662e0>,
#  <IO.Sentence at 0x107366940>,
#  <IO.Sentence at 0x107366fa0>,
#  <IO.Sentence at 0x107371370>,
#  <IO.Sentence at 0x107371850>,
#  <IO.Sentence at 0x107371d30>,
#  <IO.Sentence at 0x10737b280>,
#  <IO.Sentence at 0x10737b640>,
#  <IO.Sentence at 0x10737ba30>,
#  <IO.Sentence at 0x10737be50>,
#  <IO.Sentence at 0x107386190>,
#  <IO.Sentence at 0x107386730>,
#  <IO.Sentence at 0x1073910d0>,
#  <IO.Sentence at 0x107391700>,
#  <IO.Sentence at 0x107391c70>,
#  <IO.Sentence at 0x10739c160>,
#  <IO.Sentence at 0x10739c7c0>,
#  <IO.Sentence at 0x10739cb50>,
#  <IO.Sentence at 0x1073a65b0>,
#  <IO.Sentence at 0x1073a6b50>,
#  <IO.Sentence at 0x1073b2070>,
#  <IO.Sentence at 0x1073b2400>,
#  <IO.Sentence at 0x1073b29d0>,
#  <IO.Sentence at 0x1073b2e20>,
#  <IO.Sentence at 0x1073bd0d0>,
#  <IO.Sentence at 0x1073bd610>,
#  <IO.Sentence at 0x1073bd880>,
#  <IO.Sentence at 0x1073bddc0>,
#  <IO.Sentence at 0x1073c83d0>,
#  <IO.Sentence at 0x1073c8790>,
#  <IO.Sentence at 0x1073c8a60>,
#  <IO.Sentence at 0x1073c8d00>,
#  <IO.Sentence at 0x1073d3040>,
#  <IO.Sentence at 0x1073d3370>,
#  <IO.Sentence at 0x1073d3580>,
#  <IO.Sentence at 0x1073d3e20>,
#  <IO.Sentence at 0x1073dd250>,
#  <IO.Sentence at 0x1073dda30>,
#  <IO.Sentence at 0x1073ddfa0>,
#  <IO.Sentence at 0x1073e85e0>,
#  <IO.Sentence at 0x1073e88b0>,
#  <IO.Sentence at 0x1073e8e50>,
#  <IO.Sentence at 0x1073f3430>,
#  <IO.Sentence at 0x1073f38b0>,
#  <IO.Sentence at 0x1073f3bb0>,
#  <IO.Sentence at 0x1073fe130>,
#  <IO.Sentence at 0x1073fed30>,
#  <IO.Sentence at 0x10740a490>,
#  <IO.Sentence at 0x10740aa00>,
#  <IO.Sentence at 0x10740aee0>,
#  <IO.Sentence at 0x1074167f0>,
#  <IO.Sentence at 0x107416c10>,
#  <IO.Sentence at 0x107421190>,
#  <IO.Sentence at 0x107421790>,
#  <IO.Sentence at 0x107421c10>,
#  <IO.Sentence at 0x10742b3a0>,
#  <IO.Sentence at 0x10742b8b0>,
#  <IO.Sentence at 0x10742bc10>,
#  <IO.Sentence at 0x107437340>,
#  <IO.Sentence at 0x107437d00>,
#  <IO.Sentence at 0x107441310>,
#  <IO.Sentence at 0x1074418b0>,
#  <IO.Sentence at 0x10744d400>,
#  <IO.Sentence at 0x10744d760>,
#  <IO.Sentence at 0x10744df10>,
#  <IO.Sentence at 0x107459670>,
#  <IO.Sentence at 0x107459be0>,
#  <IO.Sentence at 0x107463220>,
#  <IO.Sentence at 0x107463790>,
#  <IO.Sentence at 0x1074639a0>,
#  <IO.Sentence at 0x107463d60>,
#  <IO.Sentence at 0x10746f3d0>,
#  <IO.Sentence at 0x10746f700>,
#  <IO.Sentence at 0x10746fa00>,
#  <IO.Sentence at 0x107479130>,
#  <IO.Sentence at 0x1074796d0>,
#  <IO.Sentence at 0x107479d90>,
#  <IO.Sentence at 0x107484730>,
#  <IO.Sentence at 0x10748f1f0>,
#  <IO.Sentence at 0x10748f5b0>,
#  <IO.Sentence at 0x10748fa60>,
#  <IO.Sentence at 0x10749a100>,
#  <IO.Sentence at 0x10749a6a0>,
#  <IO.Sentence at 0x10749af10>,
#  <IO.Sentence at 0x1074a5850>,
#  <IO.Sentence at 0x1074a5bb0>,
#  <IO.Sentence at 0x1074b1070>,
#  <IO.Sentence at 0x1074b1670>,
#  <IO.Sentence at 0x1074b1bb0>,
#  <IO.Sentence at 0x1074b1f70>,
#  <IO.Sentence at 0x1074bb940>,
#  <IO.Sentence at 0x1074bbf40>,
#  <IO.Sentence at 0x1074c7610>,
#  <IO.Sentence at 0x1074c7f10>,
#  <IO.Sentence at 0x1074d3b50>,
#  <IO.Sentence at 0x1074de1f0>,
#  <IO.Sentence at 0x1074de8e0>,
#  <IO.Sentence at 0x1074eb3a0>,
#  <IO.Sentence at 0x1074eb9d0>,
#  <IO.Sentence at 0x1074f7280>,
#  <IO.Sentence at 0x1074f7790>,
#  <IO.Sentence at 0x1074f7e50>,
#  <IO.Sentence at 0x1075015e0>,
#  <IO.Sentence at 0x107501af0>,
#  <IO.Sentence at 0x10750d160>,
#  <IO.Sentence at 0x10750d970>,
#  <IO.Sentence at 0x10750dca0>,
#  <IO.Sentence at 0x10750dee0>,
#  <IO.Sentence at 0x1075174f0>,
#  <IO.Sentence at 0x107517b50>,
#  <IO.Sentence at 0x107517df0>,
#  <IO.Sentence at 0x1075222e0>,
#  <IO.Sentence at 0x107522880>,
#  <IO.Sentence at 0x107522cd0>,
#  <IO.Sentence at 0x10752d130>,
#  ...]

# %%
#train_path_de = "Treebanks/german/train/tiger-2.2.train.only-projective.first-5k.conll06"
#reader = Reader(train_path_de)
#test_data = Data(reader.read_file())
#test_data.sentences

# %%
mapping_en_1k = FeatureMapping(train_data_en_1k.sentences)
mapping_en_1k.create_map()
# Out:
# 1000 sentences mapped

# %%
len(mapping_en_1k.map)
# Out:
# 6063219

# %%
train_data_en_1k.sentences[0].tokens[2].form
# Out:
# 'an'

# %%
model_en_1k = Model(train_data_en_1k, mapping_en_1k)

# %%
model_en_1k.train(3)
# Out:
# Start time: 16.85629275
# Epoch: 1
# Time taken for past 100 sentences: 2.7735615829999993
# Time taken for past 200 sentences: 5.210685082999998
# Time taken for past 300 sentences: 7.451746665999998
# Time taken for past 400 sentences: 9.551509790999997
# Time taken for past 500 sentences: 12.688865707999998
# Time taken for past 600 sentences: 15.115399665999998
# Time taken for past 700 sentences: 17.416576915999997
# Time taken for past 800 sentences: 20.443068832999998
# Time taken for past 900 sentences: 23.008012291
# Time taken for past 1000 sentences: 25.273787999999996
# UAS score on 26145 tokens over 1000 sentences: 0.6599732262382865
# Time taken for epoch: 25.3120695
# 0.0
#
# Start time: 42.604995041
# Epoch: 2
# Time taken for past 100 sentences: 2.5195868339999947
# Time taken for past 200 sentences: 5.058483291999998
# Time taken for past 300 sentences: 7.175467333999997
# Time taken for past 400 sentences: 9.506574084
# Time taken for past 500 sentences: 12.567336749999996
# Time taken for past 600 sentences: 14.878751874999999
# Time taken for past 700 sentences: 17.412075541999997
# Time taken for past 800 sentences: 19.948395458999997
# Time taken for past 900 sentences: 22.480438
# Time taken for past 1000 sentences: 25.001006084000004
# UAS score on 26145 tokens over 1000 sentences: 0.9003633581946835
# Time taken for epoch: 25.007536874999992
# 0.0
#
# Start time: 68.049404416
# Epoch: 3
# Time taken for past 100 sentences: 1.987024125000005
# Time taken for past 200 sentences: 4.256527917
# Time taken for past 300 sentences: 6.8327855
# Time taken for past 400 sentences: 9.710254625000005
# Time taken for past 500 sentences: 12.382598875
# Time taken for past 600 sentences: 15.190875833999996
# Time taken for past 700 sentences: 17.878178333999998
# Time taken for past 800 sentences: 20.036527334
# Time taken for past 900 sentences: 22.476098417000003
# Time taken for past 1000 sentences: 25.21451725
# UAS score on 26145 tokens over 1000 sentences: 0.9375023905144387
# Time taken for epoch: 25.262950875
# 0.0

# %%
vars(model_en_1k)
# Out:
# {'data': <IO.Data at 0x1035443d0>,
#  'feature_mapping': <feature.FeatureMapping at 0x127c43220>,
#  'weight_vector': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}

# %%
dev_gold_path_en = "Treebanks/english/dev/wsj_dev.conll06.gold"
reader_en_dev = Reader(dev_gold_path_en)
dev_gold_data = Data(reader_en_dev.read_file())
dev_gold_data.sentences
# Out:
# [<IO.Sentence at 0x127c43d90>,
#  <IO.Sentence at 0x14b1ed130>,
#  <IO.Sentence at 0x14b1ed8e0>,
#  <IO.Sentence at 0x14b1edf40>,
#  <IO.Sentence at 0x14b24a5e0>,
#  <IO.Sentence at 0x14b24ab80>,
#  <IO.Sentence at 0x14b24af10>,
#  <IO.Sentence at 0x14b244460>,
#  <IO.Sentence at 0x14b244a90>,
#  <IO.Sentence at 0x14b244fa0>,
#  <IO.Sentence at 0x14b280580>,
#  <IO.Sentence at 0x14b280a90>,
#  <IO.Sentence at 0x14b27f2b0>,
#  <IO.Sentence at 0x14b27f9a0>,
#  <IO.Sentence at 0x14b27ff40>,
#  <IO.Sentence at 0x14b3913a0>,
#  <IO.Sentence at 0x14b391a60>,
#  <IO.Sentence at 0x14b391f70>,
#  <IO.Sentence at 0x14b3a25e0>,
#  <IO.Sentence at 0x14b3a2b20>,
#  <IO.Sentence at 0x14b3a2fa0>,
#  <IO.Sentence at 0x14b3833a0>,
#  <IO.Sentence at 0x14b383910>,
#  <IO.Sentence at 0x14b383a60>,
#  <IO.Sentence at 0x14b395130>,
#  <IO.Sentence at 0x14b3952b0>,
#  <IO.Sentence at 0x14b3953a0>,
#  <IO.Sentence at 0x14b395820>,
#  <IO.Sentence at 0x14b395970>,
#  <IO.Sentence at 0x14b388040>,
#  <IO.Sentence at 0x14b388550>,
#  <IO.Sentence at 0x14b3888b0>,
#  <IO.Sentence at 0x14b388b50>,
#  <IO.Sentence at 0x14b375730>,
#  <IO.Sentence at 0x14b375f40>,
#  <IO.Sentence at 0x14b377430>,
#  <IO.Sentence at 0x14b377b20>,
#  <IO.Sentence at 0x14b377eb0>,
#  <IO.Sentence at 0x14b3644c0>,
#  <IO.Sentence at 0x14b3649a0>,
#  <IO.Sentence at 0x14b364c40>,
#  <IO.Sentence at 0x14b384220>,
#  <IO.Sentence at 0x14b3844c0>,
#  <IO.Sentence at 0x14b384940>,
#  <IO.Sentence at 0x14b384ac0>,
#  <IO.Sentence at 0x14b384e80>,
#  <IO.Sentence at 0x14b4921c0>,
#  <IO.Sentence at 0x14b492880>,
#  <IO.Sentence at 0x14b492e80>,
#  <IO.Sentence at 0x14b467460>,
#  <IO.Sentence at 0x14b467a30>,
#  <IO.Sentence at 0x14b467bb0>,
#  <IO.Sentence at 0x14b47f2b0>,
#  <IO.Sentence at 0x14b47f4f0>,
#  <IO.Sentence at 0x14b47f730>,
#  <IO.Sentence at 0x14b4731f0>,
#  <IO.Sentence at 0x14b4737f0>,
#  <IO.Sentence at 0x14b473e50>,
#  <IO.Sentence at 0x14b491310>,
#  <IO.Sentence at 0x14b491730>,
#  <IO.Sentence at 0x14b491bb0>,
#  <IO.Sentence at 0x14b49f280>,
#  <IO.Sentence at 0x14b49fa30>,
#  <IO.Sentence at 0x14b49ff40>,
#  <IO.Sentence at 0x14b497970>,
#  <IO.Sentence at 0x14b497f10>,
#  <IO.Sentence at 0x14b478550>,
#  <IO.Sentence at 0x14b4788e0>,
#  <IO.Sentence at 0x14b484040>,
#  <IO.Sentence at 0x14b484970>,
#  <IO.Sentence at 0x14b484b80>,
#  <IO.Sentence at 0x14b3491f0>,
#  <IO.Sentence at 0x14b349640>,
#  <IO.Sentence at 0x14b337280>,
#  <IO.Sentence at 0x14b337b80>,
#  <IO.Sentence at 0x14b337ee0>,
#  <IO.Sentence at 0x14b354340>,
#  <IO.Sentence at 0x14b354670>,
#  <IO.Sentence at 0x14b3547f0>,
#  <IO.Sentence at 0x14b354ac0>,
#  <IO.Sentence at 0x14b2d52e0>,
#  <IO.Sentence at 0x14b2d5ac0>,
#  <IO.Sentence at 0x14b2d81f0>,
#  <IO.Sentence at 0x14b2d8700>,
#  <IO.Sentence at 0x14b2f6370>,
#  <IO.Sentence at 0x14b2f6ca0>,
#  <IO.Sentence at 0x14b310190>,
#  <IO.Sentence at 0x14b310850>,
#  <IO.Sentence at 0x14b310f10>,
#  <IO.Sentence at 0x14b30b280>,
#  <IO.Sentence at 0x14b30b850>,
#  <IO.Sentence at 0x14b44f1c0>,
#  <IO.Sentence at 0x14b44f700>,
#  <IO.Sentence at 0x14b44fe50>,
#  <IO.Sentence at 0x14b442700>,
#  <IO.Sentence at 0x14b442b80>,
#  <IO.Sentence at 0x14b44d2b0>,
#  <IO.Sentence at 0x14b44d700>,
#  <IO.Sentence at 0x14b44da00>,
#  <IO.Sentence at 0x14b44df70>,
#  <IO.Sentence at 0x14b461670>,
#  <IO.Sentence at 0x14b461ca0>,
#  <IO.Sentence at 0x14b4e00d0>,
#  <IO.Sentence at 0x14b4e0790>,
#  <IO.Sentence at 0x14b4e0eb0>,
#  <IO.Sentence at 0x14b4b02b0>,
#  <IO.Sentence at 0x14b4b0670>,
#  <IO.Sentence at 0x14b4b0c40>,
#  <IO.Sentence at 0x14b4d7340>,
#  <IO.Sentence at 0x14b4d77c0>,
#  <IO.Sentence at 0x14b4d7b50>,
#  <IO.Sentence at 0x14b4c40a0>,
#  <IO.Sentence at 0x14b4c4640>,
#  <IO.Sentence at 0x14b4c48e0>,
#  <IO.Sentence at 0x14b4c4dc0>,
#  <IO.Sentence at 0x14b3e8280>,
#  <IO.Sentence at 0x14b3e8af0>,
#  <IO.Sentence at 0x14b3e8fd0>,
#  <IO.Sentence at 0x14b41a2e0>,
#  <IO.Sentence at 0x14b41a790>,
#  <IO.Sentence at 0x14b41abb0>,
#  <IO.Sentence at 0x14b41af70>,
#  <IO.Sentence at 0x14b420370>,
#  <IO.Sentence at 0x14b420820>,
#  <IO.Sentence at 0x14b420bb0>,
#  <IO.Sentence at 0x14b4041c0>,
#  <IO.Sentence at 0x14b404520>,
#  <IO.Sentence at 0x14b404b20>,
#  <IO.Sentence at 0x14b404dc0>,
#  <IO.Sentence at 0x14b404f10>,
#  <IO.Sentence at 0x14b3c21c0>,
#  <IO.Sentence at 0x14b3c25b0>,
#  <IO.Sentence at 0x14b3c2880>,
#  <IO.Sentence at 0x14b3c2d30>,
#  <IO.Sentence at 0x14b3b40d0>,
#  <IO.Sentence at 0x14b3b4400>,
#  <IO.Sentence at 0x14b3b45e0>,
#  <IO.Sentence at 0x14b3b4af0>,
#  <IO.Sentence at 0x14b3ba2b0>,
#  <IO.Sentence at 0x14b3ba5e0>,
#  <IO.Sentence at 0x14b3baaf0>,
#  <IO.Sentence at 0x14b3ae400>,
#  <IO.Sentence at 0x14b3ae910>,
#  <IO.Sentence at 0x14b3aedf0>,
#  <IO.Sentence at 0x14b4fa190>,
#  <IO.Sentence at 0x14b4fa4c0>,
#  <IO.Sentence at 0x14b4fa910>,
#  <IO.Sentence at 0x14b4faf70>,
#  <IO.Sentence at 0x14b4f5640>,
#  <IO.Sentence at 0x14b4f5af0>,
#  <IO.Sentence at 0x14b4f5dc0>,
#  <IO.Sentence at 0x14b4fd0d0>,
#  <IO.Sentence at 0x14b4fd340>,
#  <IO.Sentence at 0x14b4fd580>,
#  <IO.Sentence at 0x14b4fdb80>,
#  <IO.Sentence at 0x14b508340>,
#  <IO.Sentence at 0x14b5085e0>,
#  <IO.Sentence at 0x14b508cd0>,
#  <IO.Sentence at 0x14b512340>,
#  <IO.Sentence at 0x14b5128b0>,
#  <IO.Sentence at 0x14b512d60>,
#  <IO.Sentence at 0x14b51d460>,
#  <IO.Sentence at 0x14b51d850>,
#  <IO.Sentence at 0x14b5293a0>,
#  <IO.Sentence at 0x14b529580>,
#  <IO.Sentence at 0x14b529df0>,
#  <IO.Sentence at 0x14b534700>,
#  <IO.Sentence at 0x14b534ca0>,
#  <IO.Sentence at 0x14b534ee0>,
#  <IO.Sentence at 0x14b53f190>,
#  <IO.Sentence at 0x14b53f5b0>,
#  <IO.Sentence at 0x14b53fa30>,
#  <IO.Sentence at 0x14b53fd60>,
#  <IO.Sentence at 0x14b548160>,
#  <IO.Sentence at 0x14b548460>,
#  <IO.Sentence at 0x14b548bb0>,
#  <IO.Sentence at 0x14b5530d0>,
#  <IO.Sentence at 0x14b5536a0>,
#  <IO.Sentence at 0x14b553a90>,
#  <IO.Sentence at 0x14b55e100>,
#  <IO.Sentence at 0x14b55e790>,
#  <IO.Sentence at 0x14b55ebe0>,
#  <IO.Sentence at 0x14b56a1f0>,
#  <IO.Sentence at 0x14b56a490>,
#  <IO.Sentence at 0x14b56a850>,
#  <IO.Sentence at 0x14b56aaf0>,
#  <IO.Sentence at 0x14b56aeb0>,
#  <IO.Sentence at 0x14b5731c0>,
#  <IO.Sentence at 0x14b573af0>,
#  <IO.Sentence at 0x14b573f70>,
#  <IO.Sentence at 0x14b57e670>,
#  <IO.Sentence at 0x14b57edf0>,
#  <IO.Sentence at 0x14b58b0d0>,
#  <IO.Sentence at 0x14b58b430>,
#  <IO.Sentence at 0x14b58bac0>,
#  <IO.Sentence at 0x14b595190>,
#  <IO.Sentence at 0x14b595a90>,
#  <IO.Sentence at 0x14b595eb0>,
#  <IO.Sentence at 0x14b5a03d0>,
#  <IO.Sentence at 0x14b5a0a00>,
#  <IO.Sentence at 0x14b5a0f40>,
#  <IO.Sentence at 0x14b5ab280>,
#  <IO.Sentence at 0x14b5ab970>,
#  <IO.Sentence at 0x14b5abfd0>,
#  <IO.Sentence at 0x14b5b6550>,
#  <IO.Sentence at 0x14b5b6be0>,
#  <IO.Sentence at 0x14b5c0250>,
#  <IO.Sentence at 0x14b5c09d0>,
#  <IO.Sentence at 0x14b5c0ee0>,
#  <IO.Sentence at 0x14b5cb7c0>,
#  <IO.Sentence at 0x14b5cbd90>,
#  <IO.Sentence at 0x14b5d7100>,
#  <IO.Sentence at 0x14b5d7a00>,
#  <IO.Sentence at 0x14b5ee130>,
#  <IO.Sentence at 0x14b5ee6d0>,
#  <IO.Sentence at 0x14b5eed90>,
#  <IO.Sentence at 0x14b5f8400>,
#  <IO.Sentence at 0x14b5f8640>,
#  <IO.Sentence at 0x14b5f8940>,
#  <IO.Sentence at 0x14b5f8be0>,
#  <IO.Sentence at 0x14b6033a0>,
#  <IO.Sentence at 0x14b603820>,
#  <IO.Sentence at 0x14b60d070>,
#  <IO.Sentence at 0x14b60d310>,
#  <IO.Sentence at 0x14b60d820>,
#  <IO.Sentence at 0x14b619400>,
#  <IO.Sentence at 0x14b619820>,
#  <IO.Sentence at 0x14b619940>,
#  <IO.Sentence at 0x14b619e80>,
#  <IO.Sentence at 0x14b6245e0>,
#  <IO.Sentence at 0x14b624f70>,
#  <IO.Sentence at 0x14b62f8b0>,
#  <IO.Sentence at 0x14b62fac0>,
#  <IO.Sentence at 0x14b62fe20>,
#  <IO.Sentence at 0x14b63b700>,
#  <IO.Sentence at 0x14b63ba00>,
#  <IO.Sentence at 0x14b63beb0>,
#  <IO.Sentence at 0x14b6475e0>,
#  <IO.Sentence at 0x14b6479a0>,
#  <IO.Sentence at 0x14b647f40>,
#  <IO.Sentence at 0x14b652520>,
#  <IO.Sentence at 0x14b652910>,
#  <IO.Sentence at 0x14b652be0>,
#  <IO.Sentence at 0x14b65b070>,
#  <IO.Sentence at 0x14b65b550>,
#  <IO.Sentence at 0x14b65bd90>,
#  <IO.Sentence at 0x14b666370>,
#  <IO.Sentence at 0x14b666a90>,
#  <IO.Sentence at 0x14b666d90>,
#  <IO.Sentence at 0x14b673310>,
#  <IO.Sentence at 0x14b673880>,
#  <IO.Sentence at 0x14b673b80>,
#  <IO.Sentence at 0x14b673fa0>,
#  <IO.Sentence at 0x14b67d460>,
#  <IO.Sentence at 0x14b67d670>,
#  <IO.Sentence at 0x14b67d8b0>,
#  <IO.Sentence at 0x14b6880d0>,
#  <IO.Sentence at 0x14b688490>,
#  <IO.Sentence at 0x14b688bb0>,
#  <IO.Sentence at 0x14b692580>,
#  <IO.Sentence at 0x14b692760>,
#  <IO.Sentence at 0x14b692c10>,
#  <IO.Sentence at 0x14b692e50>,
#  <IO.Sentence at 0x14b69e0a0>,
#  <IO.Sentence at 0x14b69e4f0>,
#  <IO.Sentence at 0x14b69ea00>,
#  <IO.Sentence at 0x14b69ebb0>,
#  <IO.Sentence at 0x14b69efa0>,
#  <IO.Sentence at 0x14b6a7340>,
#  <IO.Sentence at 0x14b6a7790>,
#  <IO.Sentence at 0x14b6a7ee0>,
#  <IO.Sentence at 0x14b6b22b0>,
#  <IO.Sentence at 0x14b6b24c0>,
#  <IO.Sentence at 0x14b6b2910>,
#  <IO.Sentence at 0x14b6b2af0>,
#  <IO.Sentence at 0x14b6b2c40>,
#  <IO.Sentence at 0x14b6b2e50>,
#  <IO.Sentence at 0x14b6b2fa0>,
#  <IO.Sentence at 0x14b6bb3d0>,
#  <IO.Sentence at 0x14b6bb5e0>,
#  <IO.Sentence at 0x14b6bb7c0>,
#  <IO.Sentence at 0x14b6bbc10>,
#  <IO.Sentence at 0x14b6bbd90>,
#  <IO.Sentence at 0x14b6c40a0>,
#  <IO.Sentence at 0x14b6c4250>,
#  <IO.Sentence at 0x14b6c4580>,
#  <IO.Sentence at 0x14b6c46d0>,
#  <IO.Sentence at 0x14b6c4ac0>,
#  <IO.Sentence at 0x14b6c4d00>,
#  <IO.Sentence at 0x14b6cd190>,
#  <IO.Sentence at 0x14b6cd490>,
#  <IO.Sentence at 0x14b6cd670>,
#  <IO.Sentence at 0x14b6cd8b0>,
#  <IO.Sentence at 0x14b6cdac0>,
#  <IO.Sentence at 0x14b6cde20>,
#  <IO.Sentence at 0x14b6d53a0>,
#  <IO.Sentence at 0x14b6d5a90>,
#  <IO.Sentence at 0x14b6d5f40>,
#  <IO.Sentence at 0x14b6e0100>,
#  <IO.Sentence at 0x14b6e0370>,
#  <IO.Sentence at 0x14b6e04f0>,
#  <IO.Sentence at 0x14b6e06d0>,
#  <IO.Sentence at 0x14b6e0a00>,
#  <IO.Sentence at 0x14b6e0dc0>,
#  <IO.Sentence at 0x14b6e9130>,
#  <IO.Sentence at 0x14b6e98e0>,
#  <IO.Sentence at 0x14b6e9af0>,
#  <IO.Sentence at 0x14b6f3100>,
#  <IO.Sentence at 0x14b6f3820>,
#  <IO.Sentence at 0x14b6f3be0>,
#  <IO.Sentence at 0x14b6f3d90>,
#  <IO.Sentence at 0x14b6fe400>,
#  <IO.Sentence at 0x14b6fe7c0>,
#  <IO.Sentence at 0x14b6fe940>,
#  <IO.Sentence at 0x14b6fed00>,
#  <IO.Sentence at 0x14b6feeb0>,
#  <IO.Sentence at 0x14b708130>,
#  <IO.Sentence at 0x14b708310>,
#  <IO.Sentence at 0x14b708490>,
#  <IO.Sentence at 0x14b708bb0>,
#  <IO.Sentence at 0x14b713190>,
#  <IO.Sentence at 0x14b7133a0>,
#  <IO.Sentence at 0x14b713610>,
#  <IO.Sentence at 0x14b7137f0>,
#  <IO.Sentence at 0x14b713d60>,
#  <IO.Sentence at 0x14b71c100>,
#  <IO.Sentence at 0x14b71c430>,
#  <IO.Sentence at 0x14b71c6a0>,
#  <IO.Sentence at 0x14b71cb50>,
#  <IO.Sentence at 0x14b726250>,
#  <IO.Sentence at 0x14b7264c0>,
#  <IO.Sentence at 0x14b726820>,
#  <IO.Sentence at 0x14b726eb0>,
#  <IO.Sentence at 0x14b730100>,
#  <IO.Sentence at 0x14b7303a0>,
#  <IO.Sentence at 0x14b7307c0>,
#  <IO.Sentence at 0x14b730b20>,
#  <IO.Sentence at 0x14b730d00>,
#  <IO.Sentence at 0x14b7393d0>,
#  <IO.Sentence at 0x14b739e80>,
#  <IO.Sentence at 0x14b7444f0>,
#  <IO.Sentence at 0x14b744820>,
#  <IO.Sentence at 0x14b7500a0>,
#  <IO.Sentence at 0x14b750820>,
#  <IO.Sentence at 0x14b75b160>,
#  <IO.Sentence at 0x14b75b670>,
#  <IO.Sentence at 0x14b75ba90>,
#  <IO.Sentence at 0x14b7660a0>,
#  <IO.Sentence at 0x14b766430>,
#  <IO.Sentence at 0x14b766940>,
#  <IO.Sentence at 0x14b766e20>,
#  <IO.Sentence at 0x14b771310>,
#  <IO.Sentence at 0x14b7717c0>,
#  <IO.Sentence at 0x14b771b20>,
#  <IO.Sentence at 0x14b771eb0>,
#  <IO.Sentence at 0x14b77a3d0>,
#  <IO.Sentence at 0x14b77a7c0>,
#  <IO.Sentence at 0x14b77ab80>,
#  <IO.Sentence at 0x14b7853a0>,
#  <IO.Sentence at 0x14b785730>,
#  <IO.Sentence at 0x14b785940>,
#  <IO.Sentence at 0x14b785f10>,
#  <IO.Sentence at 0x14b7908e0>,
#  <IO.Sentence at 0x14b790d30>,
#  <IO.Sentence at 0x14b79c100>,
#  <IO.Sentence at 0x14b79c550>,
#  <IO.Sentence at 0x14b79ca30>,
#  <IO.Sentence at 0x14b7a6100>,
#  <IO.Sentence at 0x14b7a6490>,
#  <IO.Sentence at 0x14b7a6850>,
#  <IO.Sentence at 0x14b7a6dc0>,
#  <IO.Sentence at 0x14b7b1280>,
#  <IO.Sentence at 0x14b7b1550>,
#  <IO.Sentence at 0x14b7b19a0>,
#  <IO.Sentence at 0x14b7b1df0>,
#  <IO.Sentence at 0x14b7bc340>,
#  <IO.Sentence at 0x14b7bca90>,
#  <IO.Sentence at 0x14b7c90d0>,
#  <IO.Sentence at 0x14b7c94f0>,
#  <IO.Sentence at 0x14b7c9b50>,
#  <IO.Sentence at 0x14b7d3130>,
#  <IO.Sentence at 0x14b7d3730>,
#  <IO.Sentence at 0x14b7d3940>,
#  <IO.Sentence at 0x14b7d3b80>,
#  <IO.Sentence at 0x14b7d3d30>,
#  <IO.Sentence at 0x14b7d3f40>,
#  <IO.Sentence at 0x14b7dc100>,
#  <IO.Sentence at 0x14b7dc280>,
#  <IO.Sentence at 0x14b7dc730>,
#  <IO.Sentence at 0x168003130>,
#  <IO.Sentence at 0x168003790>,
#  <IO.Sentence at 0x168003bb0>,
#  <IO.Sentence at 0x168003f10>,
#  <IO.Sentence at 0x16800e550>,
#  <IO.Sentence at 0x16800e850>,
#  <IO.Sentence at 0x16800eb20>,
#  <IO.Sentence at 0x168018100>,
#  <IO.Sentence at 0x168018880>,
#  <IO.Sentence at 0x168018f10>,
#  <IO.Sentence at 0x168023550>,
#  <IO.Sentence at 0x168023d00>,
#  <IO.Sentence at 0x16802f5b0>,
#  <IO.Sentence at 0x16802fb50>,
#  <IO.Sentence at 0x168039100>,
#  <IO.Sentence at 0x168039610>,
#  <IO.Sentence at 0x168039be0>,
#  <IO.Sentence at 0x168039d90>,
#  <IO.Sentence at 0x1680440a0>,
#  <IO.Sentence at 0x1680445e0>,
#  <IO.Sentence at 0x168044e50>,
#  <IO.Sentence at 0x16804f310>,
#  <IO.Sentence at 0x16804f940>,
#  <IO.Sentence at 0x16804fdf0>,
#  <IO.Sentence at 0x16805b1c0>,
#  <IO.Sentence at 0x16805b730>,
#  <IO.Sentence at 0x16805bd30>,
#  <IO.Sentence at 0x168066460>,
#  <IO.Sentence at 0x1680669a0>,
#  <IO.Sentence at 0x168066c70>,
#  <IO.Sentence at 0x168071130>,
#  <IO.Sentence at 0x168071a00>,
#  <IO.Sentence at 0x168071f40>,
#  <IO.Sentence at 0x16807d4c0>,
#  <IO.Sentence at 0x168088100>,
#  <IO.Sentence at 0x168088370>,
#  <IO.Sentence at 0x168088af0>,
#  <IO.Sentence at 0x168093310>,
#  <IO.Sentence at 0x168093b20>,
#  <IO.Sentence at 0x168093e20>,
#  <IO.Sentence at 0x16809d310>,
#  <IO.Sentence at 0x16809d580>,
#  <IO.Sentence at 0x16809d940>,
#  <IO.Sentence at 0x16809dd00>,
#  <IO.Sentence at 0x1680a8340>,
#  <IO.Sentence at 0x1680a8730>,
#  <IO.Sentence at 0x1680a8b80>,
#  <IO.Sentence at 0x1680a8f70>,
#  <IO.Sentence at 0x1680b1190>,
#  <IO.Sentence at 0x1680b14f0>,
#  <IO.Sentence at 0x1680b1730>,
#  <IO.Sentence at 0x1680b1970>,
#  <IO.Sentence at 0x1680b1b80>,
#  <IO.Sentence at 0x1680b1d30>,
#  <IO.Sentence at 0x1680b1f70>,
#  <IO.Sentence at 0x1680ba190>,
#  <IO.Sentence at 0x1680ba3d0>,
#  <IO.Sentence at 0x1680ba730>,
#  <IO.Sentence at 0x1680baa30>,
#  <IO.Sentence at 0x1680bac10>,
#  <IO.Sentence at 0x1680c3040>,
#  <IO.Sentence at 0x1680c3160>,
#  <IO.Sentence at 0x1680c3520>,
#  <IO.Sentence at 0x1680c3a00>,
#  <IO.Sentence at 0x1680ce220>,
#  <IO.Sentence at 0x1680ce850>,
#  <IO.Sentence at 0x1680cedf0>,
#  <IO.Sentence at 0x1680d8220>,
#  <IO.Sentence at 0x1680d8790>,
#  <IO.Sentence at 0x1680d8c70>,
#  <IO.Sentence at 0x1680e3340>,
#  <IO.Sentence at 0x1680e39d0>,
#  <IO.Sentence at 0x1680e3dc0>,
#  <IO.Sentence at 0x1680ef490>,
#  <IO.Sentence at 0x1680efe20>,
#  <IO.Sentence at 0x1680fa490>,
#  <IO.Sentence at 0x1680fab80>,
#  <IO.Sentence at 0x1680fafd0>,
#  <IO.Sentence at 0x168106550>,
#  <IO.Sentence at 0x168106d30>,
#  <IO.Sentence at 0x168106fd0>,
#  <IO.Sentence at 0x168111580>,
#  <IO.Sentence at 0x168111940>,
#  <IO.Sentence at 0x168111e50>,
#  <IO.Sentence at 0x16811c6d0>,
#  <IO.Sentence at 0x16811ce50>,
#  <IO.Sentence at 0x1681274f0>,
#  <IO.Sentence at 0x168127af0>,
#  <IO.Sentence at 0x168133340>,
#  <IO.Sentence at 0x1681338b0>,
#  <IO.Sentence at 0x168133c10>,
#  <IO.Sentence at 0x16813f460>,
#  <IO.Sentence at 0x16813f9a0>,
#  <IO.Sentence at 0x168149190>,
#  <IO.Sentence at 0x1681499a0>,
#  <IO.Sentence at 0x168149e20>,
#  <IO.Sentence at 0x1681540a0>,
#  <IO.Sentence at 0x1681545b0>,
#  <IO.Sentence at 0x1681547f0>,
#  <IO.Sentence at 0x168154d30>,
#  <IO.Sentence at 0x16815e220>,
#  <IO.Sentence at 0x16815e490>,
#  <IO.Sentence at 0x16815ed00>,
#  <IO.Sentence at 0x1681691c0>,
#  <IO.Sentence at 0x1681696d0>,
#  <IO.Sentence at 0x168169b50>,
#  <IO.Sentence at 0x168173370>,
#  <IO.Sentence at 0x168173820>,
#  <IO.Sentence at 0x168173c40>,
#  <IO.Sentence at 0x168173fd0>,
#  <IO.Sentence at 0x16817e790>,
#  <IO.Sentence at 0x16817ef10>,
#  <IO.Sentence at 0x168188160>,
#  <IO.Sentence at 0x1681885e0>,
#  <IO.Sentence at 0x168188a60>,
#  <IO.Sentence at 0x168188eb0>,
#  <IO.Sentence at 0x168193280>,
#  <IO.Sentence at 0x168193970>,
#  <IO.Sentence at 0x168193f40>,
#  <IO.Sentence at 0x16819e310>,
#  <IO.Sentence at 0x16819e580>,
#  <IO.Sentence at 0x16819ea60>,
#  <IO.Sentence at 0x16819ef10>,
#  <IO.Sentence at 0x1681a73d0>,
#  <IO.Sentence at 0x1681a77c0>,
#  <IO.Sentence at 0x1681a7dc0>,
#  <IO.Sentence at 0x1681b2730>,
#  <IO.Sentence at 0x1681b2a60>,
#  <IO.Sentence at 0x1681be0d0>,
#  <IO.Sentence at 0x1681be610>,
#  <IO.Sentence at 0x1681beaf0>,
#  <IO.Sentence at 0x1681c90a0>,
#  <IO.Sentence at 0x1681c97c0>,
#  <IO.Sentence at 0x1681c9c70>,
#  <IO.Sentence at 0x1681d3460>,
#  <IO.Sentence at 0x1681d3820>,
#  <IO.Sentence at 0x1681d3d00>,
#  <IO.Sentence at 0x1681df0d0>,
#  <IO.Sentence at 0x1681df430>,
#  <IO.Sentence at 0x1681df6a0>,
#  <IO.Sentence at 0x1681df9a0>,
#  <IO.Sentence at 0x1681e80d0>,
#  <IO.Sentence at 0x1681e86a0>,
#  <IO.Sentence at 0x1681e8eb0>,
#  <IO.Sentence at 0x1681f3400>,
#  <IO.Sentence at 0x1681f3700>,
#  <IO.Sentence at 0x1681f3880>,
#  <IO.Sentence at 0x1681f3c10>,
#  <IO.Sentence at 0x1681ff070>,
#  <IO.Sentence at 0x1681ff4f0>,
#  <IO.Sentence at 0x1681ff790>,
#  <IO.Sentence at 0x1681ffe20>,
#  <IO.Sentence at 0x168208670>,
#  <IO.Sentence at 0x168208ac0>,
#  <IO.Sentence at 0x168208fa0>,
#  <IO.Sentence at 0x1682134c0>,
#  <IO.Sentence at 0x1682138b0>,
#  <IO.Sentence at 0x16821e0a0>,
#  <IO.Sentence at 0x16821e250>,
#  <IO.Sentence at 0x16821e940>,
#  <IO.Sentence at 0x16821ec70>,
#  <IO.Sentence at 0x168228040>,
#  <IO.Sentence at 0x168228790>,
#  <IO.Sentence at 0x1682330a0>,
#  <IO.Sentence at 0x1682332e0>,
#  <IO.Sentence at 0x1682339d0>,
#  <IO.Sentence at 0x16823e070>,
#  <IO.Sentence at 0x16823e880>,
#  <IO.Sentence at 0x16823ee80>,
#  <IO.Sentence at 0x168249610>,
#  <IO.Sentence at 0x168249f40>,
#  <IO.Sentence at 0x1682554f0>,
#  <IO.Sentence at 0x168255d00>,
#  <IO.Sentence at 0x1682603a0>,
#  <IO.Sentence at 0x168260a00>,
#  <IO.Sentence at 0x16826c040>,
#  <IO.Sentence at 0x16826c5e0>,
#  <IO.Sentence at 0x16826cc10>,
#  <IO.Sentence at 0x1682771c0>,
#  <IO.Sentence at 0x168277850>,
#  <IO.Sentence at 0x168277df0>,
#  <IO.Sentence at 0x168281460>,
#  <IO.Sentence at 0x168281970>,
#  <IO.Sentence at 0x16828d0d0>,
#  <IO.Sentence at 0x16828d730>,
#  <IO.Sentence at 0x16828dd60>,
#  <IO.Sentence at 0x168298220>,
#  <IO.Sentence at 0x168298730>,
#  <IO.Sentence at 0x1682a3100>,
#  <IO.Sentence at 0x1682a33d0>,
#  <IO.Sentence at 0x1682a3a90>,
#  <IO.Sentence at 0x1682ae190>,
#  <IO.Sentence at 0x1682ae9d0>,
#  <IO.Sentence at 0x1682b92e0>,
#  <IO.Sentence at 0x1682b9970>,
#  <IO.Sentence at 0x1682b9b20>,
#  <IO.Sentence at 0x1682c52b0>,
#  <IO.Sentence at 0x1682c5790>,
#  <IO.Sentence at 0x1682c5d90>,
#  <IO.Sentence at 0x1682cf760>,
#  <IO.Sentence at 0x1682cfc10>,
#  <IO.Sentence at 0x1682cff10>,
#  <IO.Sentence at 0x1682da790>,
#  <IO.Sentence at 0x1682dacd0>,
#  <IO.Sentence at 0x1682e6820>,
#  <IO.Sentence at 0x1682e6dc0>,
#  <IO.Sentence at 0x1682f0640>,
#  <IO.Sentence at 0x1682f0b80>,
#  <IO.Sentence at 0x1682fd2b0>,
#  <IO.Sentence at 0x1682fd730>,
#  <IO.Sentence at 0x1682fddc0>,
#  <IO.Sentence at 0x168308280>,
#  <IO.Sentence at 0x1683088e0>,
#  <IO.Sentence at 0x168308cd0>,
#  <IO.Sentence at 0x168313640>,
#  <IO.Sentence at 0x1683137f0>,
#  <IO.Sentence at 0x168313f70>,
#  <IO.Sentence at 0x16831d3a0>,
#  <IO.Sentence at 0x16831d8e0>,
#  <IO.Sentence at 0x16831de80>,
#  <IO.Sentence at 0x1683283d0>,
#  <IO.Sentence at 0x168328a00>,
#  <IO.Sentence at 0x168328ee0>,
#  <IO.Sentence at 0x1683334f0>,
#  <IO.Sentence at 0x168333ee0>,
#  <IO.Sentence at 0x16833e400>,
#  <IO.Sentence at 0x16833eaf0>,
#  <IO.Sentence at 0x16833efa0>,
#  <IO.Sentence at 0x16834a670>,
#  <IO.Sentence at 0x16834aa60>,
#  <IO.Sentence at 0x16834ae20>,
#  <IO.Sentence at 0x168354100>,
#  <IO.Sentence at 0x1683545e0>,
#  <IO.Sentence at 0x168354a60>,
#  <IO.Sentence at 0x168360160>,
#  <IO.Sentence at 0x1683605e0>,
#  <IO.Sentence at 0x168360ac0>,
#  <IO.Sentence at 0x16836a040>,
#  <IO.Sentence at 0x16836a850>,
#  <IO.Sentence at 0x16836af70>,
#  <IO.Sentence at 0x168375610>,
#  <IO.Sentence at 0x168375af0>,
#  <IO.Sentence at 0x168381310>,
#  <IO.Sentence at 0x168381700>,
#  <IO.Sentence at 0x168381ac0>,
#  <IO.Sentence at 0x16838b0d0>,
#  <IO.Sentence at 0x16838b880>,
#  <IO.Sentence at 0x16838bc70>,
#  <IO.Sentence at 0x16838bf40>,
#  <IO.Sentence at 0x127c3aa30>,
#  <IO.Sentence at 0x168396430>,
#  <IO.Sentence at 0x168396880>,
#  <IO.Sentence at 0x168396e20>,
#  <IO.Sentence at 0x1683993d0>,
#  <IO.Sentence at 0x168399850>,
#  <IO.Sentence at 0x168399df0>,
#  <IO.Sentence at 0x168399fd0>,
#  <IO.Sentence at 0x16839c880>,
#  <IO.Sentence at 0x16839cd60>,
#  <IO.Sentence at 0x16839e3a0>,
#  <IO.Sentence at 0x16839ea60>,
#  <IO.Sentence at 0x16839ed60>,
#  <IO.Sentence at 0x1683a11f0>,
#  <IO.Sentence at 0x1683a18b0>,
#  <IO.Sentence at 0x1683ac0a0>,
#  <IO.Sentence at 0x1683ac6d0>,
#  <IO.Sentence at 0x1683ac910>,
#  <IO.Sentence at 0x1683acaf0>,
#  <IO.Sentence at 0x1683b7370>,
#  <IO.Sentence at 0x1683b77f0>,
#  <IO.Sentence at 0x1683b7f70>,
#  <IO.Sentence at 0x1683c24f0>,
#  <IO.Sentence at 0x1683c2bb0>,
#  <IO.Sentence at 0x1683ce460>,
#  <IO.Sentence at 0x1683ce850>,
#  <IO.Sentence at 0x1683ceeb0>,
#  <IO.Sentence at 0x1683da3d0>,
#  <IO.Sentence at 0x1683da8e0>,
#  <IO.Sentence at 0x1683dadc0>,
#  <IO.Sentence at 0x1683e4280>,
#  <IO.Sentence at 0x1683e4580>,
#  <IO.Sentence at 0x1683e4a30>,
#  <IO.Sentence at 0x1683e4f10>,
#  <IO.Sentence at 0x1683ef730>,
#  <IO.Sentence at 0x1683efa00>,
#  <IO.Sentence at 0x1683fb340>,
#  <IO.Sentence at 0x1683fbac0>,
#  <IO.Sentence at 0x1683fbdf0>,
#  <IO.Sentence at 0x168405040>,
#  <IO.Sentence at 0x168405520>,
#  <IO.Sentence at 0x168405910>,
#  <IO.Sentence at 0x168405d90>,
#  <IO.Sentence at 0x168410160>,
#  <IO.Sentence at 0x1684102e0>,
#  <IO.Sentence at 0x168410700>,
#  <IO.Sentence at 0x1684108e0>,
#  <IO.Sentence at 0x168410f70>,
#  <IO.Sentence at 0x16841a310>,
#  <IO.Sentence at 0x16841a7c0>,
#  <IO.Sentence at 0x16841aaf0>,
#  <IO.Sentence at 0x168425160>,
#  <IO.Sentence at 0x1684258b0>,
#  <IO.Sentence at 0x1684300d0>,
#  <IO.Sentence at 0x168430520>,
#  <IO.Sentence at 0x168430910>,
#  <IO.Sentence at 0x168430e50>,
#  <IO.Sentence at 0x16843a400>,
#  <IO.Sentence at 0x16843aa90>,
#  <IO.Sentence at 0x16843acd0>,
#  <IO.Sentence at 0x168444070>,
#  <IO.Sentence at 0x168444dc0>,
#  <IO.Sentence at 0x1684501f0>,
#  <IO.Sentence at 0x168450ac0>,
#  <IO.Sentence at 0x16845b370>,
#  <IO.Sentence at 0x16845b880>,
#  <IO.Sentence at 0x16845be80>,
#  <IO.Sentence at 0x168465190>,
#  <IO.Sentence at 0x1684657c0>,
#  <IO.Sentence at 0x1684713d0>,
#  <IO.Sentence at 0x168471670>,
#  <IO.Sentence at 0x168471b50>,
#  <IO.Sentence at 0x168471f10>,
#  <IO.Sentence at 0x16847acd0>,
#  <IO.Sentence at 0x168487250>,
#  <IO.Sentence at 0x168487670>,
#  <IO.Sentence at 0x168487b50>,
#  <IO.Sentence at 0x1684912e0>,
#  <IO.Sentence at 0x1684916d0>,
#  <IO.Sentence at 0x168491bb0>,
#  <IO.Sentence at 0x16849c4f0>,
#  <IO.Sentence at 0x16849cbe0>,
#  <IO.Sentence at 0x1684a85e0>,
#  <IO.Sentence at 0x1684a8a30>,
#  <IO.Sentence at 0x1684b32e0>,
#  <IO.Sentence at 0x1684b3820>,
#  <IO.Sentence at 0x1684b3f40>,
#  <IO.Sentence at 0x1684be5e0>,
#  <IO.Sentence at 0x1684bebe0>,
#  <IO.Sentence at 0x1684c9040>,
#  <IO.Sentence at 0x1684c9310>,
#  <IO.Sentence at 0x1684c9760>,
#  <IO.Sentence at 0x1684c9a60>,
#  <IO.Sentence at 0x1684c9e20>,
#  <IO.Sentence at 0x1684d3250>,
#  <IO.Sentence at 0x1684d38b0>,
#  <IO.Sentence at 0x1684d3e50>,
#  <IO.Sentence at 0x1684de4f0>,
#  <IO.Sentence at 0x1684dec10>,
#  <IO.Sentence at 0x1684def40>,
#  <IO.Sentence at 0x1684ea370>,
#  <IO.Sentence at 0x1684ea8e0>,
#  <IO.Sentence at 0x1684eafd0>,
#  <IO.Sentence at 0x1684f5190>,
#  <IO.Sentence at 0x1684f5400>,
#  <IO.Sentence at 0x1684f5ac0>,
#  <IO.Sentence at 0x1684f5e80>,
#  <IO.Sentence at 0x168500310>,
#  <IO.Sentence at 0x168500880>,
#  <IO.Sentence at 0x168500dc0>,
#  <IO.Sentence at 0x16850b340>,
#  <IO.Sentence at 0x16850b5b0>,
#  <IO.Sentence at 0x16850b9a0>,
#  <IO.Sentence at 0x16850bcd0>,
#  <IO.Sentence at 0x16850bf10>,
#  <IO.Sentence at 0x168514220>,
#  <IO.Sentence at 0x168514730>,
#  <IO.Sentence at 0x168514b20>,
#  <IO.Sentence at 0x168520190>,
#  <IO.Sentence at 0x168520400>,
#  <IO.Sentence at 0x1685209a0>,
#  <IO.Sentence at 0x168520ee0>,
#  <IO.Sentence at 0x168529430>,
#  <IO.Sentence at 0x168529af0>,
#  <IO.Sentence at 0x168529ee0>,
#  <IO.Sentence at 0x168535280>,
#  <IO.Sentence at 0x168535820>,
#  <IO.Sentence at 0x168535ac0>,
#  <IO.Sentence at 0x168535d00>,
#  <IO.Sentence at 0x16853e1f0>,
#  <IO.Sentence at 0x16853e640>,
#  <IO.Sentence at 0x16853ea60>,
#  <IO.Sentence at 0x16853eee0>,
#  <IO.Sentence at 0x168549160>,
#  <IO.Sentence at 0x1685495b0>,
#  <IO.Sentence at 0x1685496a0>,
#  <IO.Sentence at 0x168549850>,
#  <IO.Sentence at 0x168549ca0>,
#  <IO.Sentence at 0x168549f10>,
#  <IO.Sentence at 0x168552340>,
#  <IO.Sentence at 0x168552670>,
#  <IO.Sentence at 0x168552cd0>,
#  <IO.Sentence at 0x16855da00>,
#  <IO.Sentence at 0x16855df40>,
#  <IO.Sentence at 0x168567430>,
#  <IO.Sentence at 0x168567af0>,
#  <IO.Sentence at 0x168573130>,
#  <IO.Sentence at 0x168573400>,
#  <IO.Sentence at 0x168573730>,
#  <IO.Sentence at 0x168573940>,
#  <IO.Sentence at 0x168573e80>,
#  <IO.Sentence at 0x16857c0a0>,
#  <IO.Sentence at 0x16857c550>,
#  <IO.Sentence at 0x16857c850>,
#  <IO.Sentence at 0x16857cbe0>,
#  <IO.Sentence at 0x168587040>,
#  <IO.Sentence at 0x168587580>,
#  <IO.Sentence at 0x168587880>,
#  <IO.Sentence at 0x168587c40>,
#  <IO.Sentence at 0x168592430>,
#  <IO.Sentence at 0x168592b80>,
#  <IO.Sentence at 0x168592e20>,
#  <IO.Sentence at 0x16859c490>,
#  <IO.Sentence at 0x16859caf0>,
#  <IO.Sentence at 0x16859cdf0>,
#  <IO.Sentence at 0x1685a7070>,
#  <IO.Sentence at 0x1685a7970>,
#  <IO.Sentence at 0x1685a7f70>,
#  <IO.Sentence at 0x1685b15e0>,
#  <IO.Sentence at 0x1685b1d30>,
#  <IO.Sentence at 0x1685bc1c0>,
#  <IO.Sentence at 0x1685bc7c0>,
#  <IO.Sentence at 0x1685c70d0>,
#  <IO.Sentence at 0x1685c7280>,
#  <IO.Sentence at 0x1685c79a0>,
#  <IO.Sentence at 0x1685c7df0>,
#  <IO.Sentence at 0x1685d23d0>,
#  <IO.Sentence at 0x1685d2b80>,
#  <IO.Sentence at 0x1685d2fa0>,
#  <IO.Sentence at 0x1685dc310>,
#  <IO.Sentence at 0x1685dcbb0>,
#  <IO.Sentence at 0x1685e8580>,
#  <IO.Sentence at 0x1685e8d90>,
#  <IO.Sentence at 0x1685f4790>,
#  <IO.Sentence at 0x1685f4d90>,
#  <IO.Sentence at 0x1685ff430>,
#  <IO.Sentence at 0x1685ff9d0>,
#  <IO.Sentence at 0x1685ffe20>,
#  <IO.Sentence at 0x16860a490>,
#  <IO.Sentence at 0x16860abe0>,
#  <IO.Sentence at 0x1686151f0>,
#  <IO.Sentence at 0x1686157c0>,
#  <IO.Sentence at 0x168615ee0>,
#  <IO.Sentence at 0x1686205b0>,
#  <IO.Sentence at 0x1686209a0>,
#  <IO.Sentence at 0x168620eb0>,
#  <IO.Sentence at 0x16862b280>,
#  <IO.Sentence at 0x16862b850>,
#  <IO.Sentence at 0x16862bc10>,
#  <IO.Sentence at 0x1686362b0>,
#  <IO.Sentence at 0x1686365b0>,
#  <IO.Sentence at 0x168636c40>,
#  <IO.Sentence at 0x168642190>,
#  <IO.Sentence at 0x168642580>,
#  <IO.Sentence at 0x168642850>,
#  <IO.Sentence at 0x168642d00>,
#  <IO.Sentence at 0x16864c070>,
#  <IO.Sentence at 0x16864c4c0>,
#  <IO.Sentence at 0x16864c850>,
#  <IO.Sentence at 0x16864cdf0>,
#  <IO.Sentence at 0x168656280>,
#  <IO.Sentence at 0x1686564f0>,
#  <IO.Sentence at 0x1686568b0>,
#  <IO.Sentence at 0x168656dc0>,
#  <IO.Sentence at 0x1686600a0>,
#  <IO.Sentence at 0x168660250>,
#  <IO.Sentence at 0x168660790>,
#  <IO.Sentence at 0x168660cd0>,
#  <IO.Sentence at 0x168660f70>,
#  <IO.Sentence at 0x16866a250>,
#  <IO.Sentence at 0x16866a550>,
#  <IO.Sentence at 0x16866a9d0>,
#  <IO.Sentence at 0x16866ad60>,
#  <IO.Sentence at 0x1686732b0>,
#  <IO.Sentence at 0x168673640>,
#  <IO.Sentence at 0x168673b80>,
#  <IO.Sentence at 0x16867e2b0>,
#  <IO.Sentence at 0x16867e670>,
#  <IO.Sentence at 0x16867ea30>,
#  <IO.Sentence at 0x16867eca0>,
#  <IO.Sentence at 0x168689160>,
#  <IO.Sentence at 0x1686897c0>,
#  <IO.Sentence at 0x168689ca0>,
#  <IO.Sentence at 0x168689fd0>,
#  <IO.Sentence at 0x168693a30>,
#  <IO.Sentence at 0x16869f340>,
#  <IO.Sentence at 0x16869f910>,
#  <IO.Sentence at 0x16869ff40>,
#  <IO.Sentence at 0x1686aa520>,
#  <IO.Sentence at 0x1686aad90>,
#  <IO.Sentence at 0x1686b66a0>,
#  <IO.Sentence at 0x1686b6ac0>,
#  <IO.Sentence at 0x1686c01c0>,
#  <IO.Sentence at 0x1686c0610>,
#  <IO.Sentence at 0x1686c0940>,
#  <IO.Sentence at 0x1686c0df0>,
#  <IO.Sentence at 0x1686cb160>,
#  <IO.Sentence at 0x1686cba00>,
#  <IO.Sentence at 0x1686d5220>,
#  <IO.Sentence at 0x1686d5a00>,
#  <IO.Sentence at 0x1686e15e0>,
#  <IO.Sentence at 0x1686e1f40>,
#  <IO.Sentence at 0x1686ee370>,
#  <IO.Sentence at 0x1686ee8e0>,
#  <IO.Sentence at 0x1686f9040>,
#  <IO.Sentence at 0x1686f9310>,
#  <IO.Sentence at 0x1686f9a90>,
#  <IO.Sentence at 0x1687043a0>,
#  <IO.Sentence at 0x168704940>,
#  <IO.Sentence at 0x168704e80>,
#  <IO.Sentence at 0x16870f250>,
#  <IO.Sentence at 0x16870f670>,
#  <IO.Sentence at 0x16870fb80>,
#  <IO.Sentence at 0x16871a520>,
#  <IO.Sentence at 0x16871ab80>,
#  <IO.Sentence at 0x168726580>,
#  <IO.Sentence at 0x168726ac0>,
#  <IO.Sentence at 0x1687310a0>,
#  <IO.Sentence at 0x168731730>,
#  <IO.Sentence at 0x168731d00>,
#  <IO.Sentence at 0x16873c760>,
#  <IO.Sentence at 0x168747100>,
#  <IO.Sentence at 0x168747760>,
#  <IO.Sentence at 0x168747bb0>,
#  <IO.Sentence at 0x168752250>,
#  <IO.Sentence at 0x168752580>,
#  <IO.Sentence at 0x168752a00>,
#  <IO.Sentence at 0x16875c2b0>,
#  <IO.Sentence at 0x16875ca30>,
#  <IO.Sentence at 0x16875ce80>,
#  <IO.Sentence at 0x168769580>,
#  <IO.Sentence at 0x1687698b0>,
#  <IO.Sentence at 0x168769b50>,
#  <IO.Sentence at 0x168769fa0>,
#  <IO.Sentence at 0x168773310>,
#  <IO.Sentence at 0x168773700>,
#  <IO.Sentence at 0x168773d60>,
#  <IO.Sentence at 0x16877d2b0>,
#  <IO.Sentence at 0x16877dbb0>,
#  <IO.Sentence at 0x16877dfd0>,
#  <IO.Sentence at 0x1687895b0>,
#  <IO.Sentence at 0x168789a90>,
#  <IO.Sentence at 0x168789eb0>,
#  <IO.Sentence at 0x1687934c0>,
#  <IO.Sentence at 0x168793a60>,
#  <IO.Sentence at 0x168793e20>,
#  <IO.Sentence at 0x16879e310>,
#  <IO.Sentence at 0x16879e790>,
#  <IO.Sentence at 0x16879ef10>,
#  <IO.Sentence at 0x1687a8520>,
#  <IO.Sentence at 0x1687a88b0>,
#  <IO.Sentence at 0x1687a8e20>,
#  <IO.Sentence at 0x1687b31f0>,
#  <IO.Sentence at 0x1687b37f0>,
#  <IO.Sentence at 0x1687b3cd0>,
#  <IO.Sentence at 0x1687be6a0>,
#  <IO.Sentence at 0x1687beaf0>,
#  <IO.Sentence at 0x1687ca130>,
#  <IO.Sentence at 0x1687ca3d0>,
#  <IO.Sentence at 0x1687caa60>,
#  <IO.Sentence at 0x1687d51f0>,
#  <IO.Sentence at 0x1687d5850>,
#  <IO.Sentence at 0x1687d5ca0>,
#  <IO.Sentence at 0x1687e02b0>,
#  <IO.Sentence at 0x1687e08e0>,
#  <IO.Sentence at 0x1687e0dc0>,
#  <IO.Sentence at 0x1687eb490>,
#  <IO.Sentence at 0x1687ebc70>,
#  <IO.Sentence at 0x1687f6040>,
#  <IO.Sentence at 0x1687f6760>,
#  <IO.Sentence at 0x1687f6a30>,
#  <IO.Sentence at 0x168801040>,
#  <IO.Sentence at 0x1688017f0>,
#  <IO.Sentence at 0x1688019d0>,
#  <IO.Sentence at 0x168801cd0>,
#  <IO.Sentence at 0x16880b400>,
#  <IO.Sentence at 0x16880b8b0>,
#  <IO.Sentence at 0x16880bdf0>,
#  <IO.Sentence at 0x168816340>,
#  <IO.Sentence at 0x1688169d0>,
#  <IO.Sentence at 0x168816f40>,
#  <IO.Sentence at 0x1688225b0>,
#  <IO.Sentence at 0x168822cd0>,
#  <IO.Sentence at 0x16882d310>,
#  <IO.Sentence at 0x16882d8e0>,
#  <IO.Sentence at 0x168838070>,
#  <IO.Sentence at 0x168838790>,
#  <IO.Sentence at 0x168843160>,
#  <IO.Sentence at 0x168843460>,
#  <IO.Sentence at 0x168843ac0>,
#  <IO.Sentence at 0x168843fa0>,
#  <IO.Sentence at 0x168850430>,
#  <IO.Sentence at 0x168850ca0>,
#  <IO.Sentence at 0x16885b2b0>,
#  <IO.Sentence at 0x16885b8e0>,
#  <IO.Sentence at 0x168867280>,
#  <IO.Sentence at 0x168867790>,
#  <IO.Sentence at 0x168867ac0>,
#  <IO.Sentence at 0x168867d90>,
#  <IO.Sentence at 0x1688712b0>,
#  <IO.Sentence at 0x168871910>,
#  <IO.Sentence at 0x168871d00>,
#  <IO.Sentence at 0x16887c250>,
#  <IO.Sentence at 0x16887c520>,
#  <IO.Sentence at 0x16887cc40>,
#  <IO.Sentence at 0x168888280>,
#  <IO.Sentence at 0x1688886d0>,
#  <IO.Sentence at 0x168888d00>,
#  <IO.Sentence at 0x1688933a0>,
#  <IO.Sentence at 0x168893700>,
#  <IO.Sentence at 0x168893af0>,
#  <IO.Sentence at 0x168893e50>,
#  ...]

# %%
model_en_1k.make_predictions(dev_gold_data)

# %%
dev_gold_data.sentences[0].tokens[5].x
# Out:
# '0'

# %%
dev_gold_data.evaluate()
# Out:
# UAS score on 27678 tokens over 1083 sentences: 0.726497579304863
# 0.726497579304863

# %%
train_data_en_5k

# %%
mapping_en_5k = FeatureMapping(train_data_en_5k.sentences)
mapping_en_5k.create_map()
# Out:
# 1000 sentences mapped
# 2000 sentences mapped
# 3000 sentences mapped
# 4000 sentences mapped
# 5000 sentences mapped

# %%
model_en_5k = Model(train_data_en_5k, mapping_en_5k)

# %%
model_en_5k.train(5)
# Out:
# Start time: 321.25666925
# Epoch: 1
# Time taken for past 100 sentences: 4.307021582999994
# Time taken for past 200 sentences: 8.581340415999989
# Time taken for past 300 sentences: 12.866729290999956
# Time taken for past 400 sentences: 16.820144957999958
# Time taken for past 500 sentences: 20.933719499999995
# Time taken for past 600 sentences: 24.774229875000003
# Time taken for past 700 sentences: 29.580057915999987
# Time taken for past 800 sentences: 33.602590916
# Time taken for past 900 sentences: 37.64904487499996
# Time taken for past 1000 sentences: 41.21184058299997
# Time taken for past 1100 sentences: 45.356080582999994
# Time taken for past 1200 sentences: 49.25101720800001
# Time taken for past 1300 sentences: 52.69243562499997
# Time taken for past 1400 sentences: 56.355345166000006
# Time taken for past 1500 sentences: 60.635780874999966
# Time taken for past 1600 sentences: 64.61693287499997
# Time taken for past 1700 sentences: 68.22340187499998
# Time taken for past 1800 sentences: 71.778243583
# Time taken for past 1900 sentences: 75.52204808299996
# Time taken for past 2000 sentences: 79.069812458
# Time taken for past 2100 sentences: 83.48900383299997
# Time taken for past 2200 sentences: 87.07894525
# Time taken for past 2300 sentences: 91.12189354099996
# Time taken for past 2400 sentences: 95.56501145799996
# Time taken for past 2500 sentences: 99.50109283299997
# Time taken for past 2600 sentences: 102.704120375
# Time taken for past 2700 sentences: 106.41895074999996
# Time taken for past 2800 sentences: 109.50045729099998
# Time taken for past 2900 sentences: 113.02871854099999
# Time taken for past 3000 sentences: 116.60183162499999
# Time taken for past 3100 sentences: 120.44549945799997
# Time taken for past 3200 sentences: 124.39111224999999
# Time taken for past 3300 sentences: 128.207089
# Time taken for past 3400 sentences: 132.43355299999996
# Time taken for past 3500 sentences: 136.137387041
# Time taken for past 3600 sentences: 139.82725812499996
# Time taken for past 3700 sentences: 144.09286404099998
# Time taken for past 3800 sentences: 148.41547624999998
# Time taken for past 3900 sentences: 152.39307333299996
# Time taken for past 4000 sentences: 155.62228349999998
# Time taken for past 4100 sentences: 158.99778554099998
# Time taken for past 4200 sentences: 163.199708541
# Time taken for past 4300 sentences: 166.538059041
# Time taken for past 4400 sentences: 169.998613041
# Time taken for past 4500 sentences: 173.91038575
# Time taken for past 4600 sentences: 178.17168549999997
# Time taken for past 4700 sentences: 182.313238916
# Time taken for past 4800 sentences: 186.26374316599998
# Time taken for past 4900 sentences: 189.66678724999997
# Time taken for past 5000 sentences: 192.78636950000003
# UAS score on 127143 tokens over 5000 sentences: 0.7294621017279755
# Time taken for epoch: 192.889867208
# 0.0
#
# Start time: 515.721843333
# Epoch: 2
# Time taken for past 100 sentences: 3.737395666999987
# Time taken for past 200 sentences: 8.056204457999911
# Time taken for past 300 sentences: 11.81695041699993
# Time taken for past 400 sentences: 15.52612129199997
# Time taken for past 500 sentences: 18.90253983299999
# Time taken for past 600 sentences: 23.00602099999992
# Time taken for past 700 sentences: 26.974670957999933
# Time taken for past 800 sentences: 30.990256624999915
# Time taken for past 900 sentences: 33.964553583
# Time taken for past 1000 sentences: 37.64581845800001
# Time taken for past 1100 sentences: 41.435862666999924
# Time taken for past 1200 sentences: 44.875623625
# Time taken for past 1300 sentences: 48.588668457999916
# Time taken for past 1400 sentences: 52.03492558300002
# Time taken for past 1500 sentences: 56.347970749999945
# Time taken for past 1600 sentences: 60.097606999999925
# Time taken for past 1700 sentences: 63.56848912499993
# Time taken for past 1800 sentences: 68.26762912499998
# Time taken for past 1900 sentences: 71.83239679199994
# Time taken for past 2000 sentences: 76.90757841699997
# Time taken for past 2100 sentences: 80.91819091699995
# Time taken for past 2200 sentences: 84.18509837499994
# Time taken for past 2300 sentences: 88.30572024999992
# Time taken for past 2400 sentences: 92.20173745799991
# Time taken for past 2500 sentences: 95.94438920799996
# Time taken for past 2600 sentences: 99.452812333
# Time taken for past 2700 sentences: 103.75695566699994
# Time taken for past 2800 sentences: 106.6934655
# Time taken for past 2900 sentences: 110.06006416699995
# Time taken for past 3000 sentences: 113.39203270799999
# Time taken for past 3100 sentences: 117.23678391699991
# Time taken for past 3200 sentences: 120.68170429199995
# Time taken for past 3300 sentences: 123.80664037499992
# Time taken for past 3400 sentences: 127.60923620799997
# Time taken for past 3500 sentences: 130.842613208
# Time taken for past 3600 sentences: 135.34967737499994
# Time taken for past 3700 sentences: 139.46540270799994
# Time taken for past 3800 sentences: 142.7052383749999
# Time taken for past 3900 sentences: 146.70836120799993
# Time taken for past 4000 sentences: 150.99013745799994
# Time taken for past 4100 sentences: 154.784114542
# Time taken for past 4200 sentences: 159.030542458
# Time taken for past 4300 sentences: 163.56221516699998
# Time taken for past 4400 sentences: 167.71248083299997
# Time taken for past 4500 sentences: 172.10972837499992
# Time taken for past 4600 sentences: 175.94089020799993
# Time taken for past 4700 sentences: 179.66191208299995
# Time taken for past 4800 sentences: 183.01832458299998
# Time taken for past 4900 sentences: 186.50785137499997
# Time taken for past 5000 sentences: 189.50332316699996
# UAS score on 127143 tokens over 5000 sentences: 0.8971944975342724
# Time taken for epoch: 189.579435708
# 0.0
#
# Start time: 706.908535833
# Epoch: 3
# Time taken for past 100 sentences: 3.431695750000017
# Time taken for past 200 sentences: 7.428222291999987
# Time taken for past 300 sentences: 11.825803042000075
# Time taken for past 400 sentences: 15.373846208000032
# Time taken for past 500 sentences: 19.989868249999972
# Time taken for past 600 sentences: 23.743659208000054
# Time taken for past 700 sentences: 27.14225762500007
# Time taken for past 800 sentences: 30.243602667000005
# Time taken for past 900 sentences: 33.97212433300001
# Time taken for past 1000 sentences: 37.24736670800007
# Time taken for past 1100 sentences: 40.81281112500005
# Time taken for past 1200 sentences: 44.63080662499999
# Time taken for past 1300 sentences: 47.66735037500007
# Time taken for past 1400 sentences: 50.98173833300007
# Time taken for past 1500 sentences: 54.86304258300004
# Time taken for past 1600 sentences: 58.574185958000044
# Time taken for past 1700 sentences: 62.57720154200001
# Time taken for past 1800 sentences: 66.52188991700007
# Time taken for past 1900 sentences: 70.16460541700008
# Time taken for past 2000 sentences: 75.03967041700002
# Time taken for past 2100 sentences: 79.00305654200008
# Time taken for past 2200 sentences: 82.72536279200006
# Time taken for past 2300 sentences: 88.57899979199999
# Time taken for past 2400 sentences: 93.52189916700002
# Time taken for past 2500 sentences: 96.80817141700004
# Time taken for past 2600 sentences: 101.16116975
# Time taken for past 2700 sentences: 104.78499054200006
# Time taken for past 2800 sentences: 108.78108662500006
# Time taken for past 2900 sentences: 112.44297308299997
# Time taken for past 3000 sentences: 116.780938042
# Time taken for past 3100 sentences: 120.05880920800007
# Time taken for past 3200 sentences: 124.83668262499998
# Time taken for past 3300 sentences: 128.5893995
# Time taken for past 3400 sentences: 133.034879542
# Time taken for past 3500 sentences: 139.16430545800006
# Time taken for past 3600 sentences: 144.036960625
# Time taken for past 3700 sentences: 150.55737058300008
# Time taken for past 3800 sentences: 154.72594612500006
# Time taken for past 3900 sentences: 159.56894791700006
# Time taken for past 4000 sentences: 164.726422083
# Time taken for past 4100 sentences: 168.97164295800007
# Time taken for past 4200 sentences: 174.10135025
# Time taken for past 4300 sentences: 184.779580667
# Time taken for past 4400 sentences: 191.07354716700002
# Time taken for past 4500 sentences: 196.46795674999998
# Time taken for past 4600 sentences: 201.105054333
# Time taken for past 4700 sentences: 206.90146325
# Time taken for past 4800 sentences: 213.07705129200008
# Time taken for past 4900 sentences: 218.72947491700006
# Time taken for past 5000 sentences: 224.237665042
# UAS score on 127143 tokens over 5000 sentences: 0.9292843491187088
# Time taken for epoch: 224.43126008299998
# 0.0
#
# Start time: 932.960990291
# Epoch: 4
# Time taken for past 100 sentences: 4.81632562499999
# Time taken for past 200 sentences: 9.152972792000014
# Time taken for past 300 sentences: 13.009065083999985
# Time taken for past 400 sentences: 16.927612875000023
# Time taken for past 500 sentences: 21.356782291999934
# Time taken for past 600 sentences: 26.469058625000002
# Time taken for past 700 sentences: 30.996722834000025
# Time taken for past 800 sentences: 35.34028095899998
# Time taken for past 900 sentences: 40.41775070899996
# Time taken for past 1000 sentences: 44.930019625
# Time taken for past 1100 sentences: 49.300244583999984
# Time taken for past 1200 sentences: 53.56587887499995
# Time taken for past 1300 sentences: 57.187389209
# Time taken for past 1400 sentences: 61.56952783399993
# Time taken for past 1500 sentences: 65.61080725
# Time taken for past 1600 sentences: 69.69212183399998
# Time taken for past 1700 sentences: 74.06957408400001
# Time taken for past 1800 sentences: 78.23754070899997
# Time taken for past 1900 sentences: 81.65523545899998
# Time taken for past 2000 sentences: 85.73230079199993
# Time taken for past 2100 sentences: 90.16856016700001
# Time taken for past 2200 sentences: 94.41413258399996
# Time taken for past 2300 sentences: 98.89785408399996
# Time taken for past 2400 sentences: 103.10909220899987
# Time taken for past 2500 sentences: 107.28514754199989
# Time taken for past 2600 sentences: 111.38486091700008
# Time taken for past 2700 sentences: 115.92401379199998
# Time taken for past 2800 sentences: 119.45826012500004
# Time taken for past 2900 sentences: 123.08826029199997
# Time taken for past 3000 sentences: 126.83891125000002
# Time taken for past 3100 sentences: 131.36351350000007
# Time taken for past 3200 sentences: 134.8638588749999
# Time taken for past 3300 sentences: 137.85791904199993
# Time taken for past 3400 sentences: 141.7459372919999
# Time taken for past 3500 sentences: 145.58158941699992
# Time taken for past 3600 sentences: 150.2534086249999
# Time taken for past 3700 sentences: 155.924019875
# Time taken for past 3800 sentences: 159.49159841699986
# Time taken for past 3900 sentences: 163.48714029199994
# Time taken for past 4000 sentences: 166.49747708400002
# Time taken for past 4100 sentences: 169.99760754200008
# Time taken for past 4200 sentences: 173.0478147089999
# Time taken for past 4300 sentences: 176.5750233749999
# Time taken for past 4400 sentences: 180.00981749999994
# Time taken for past 4500 sentences: 183.64371829200002
# Time taken for past 4600 sentences: 186.25343695899994
# Time taken for past 4700 sentences: 192.10749395899995
# Time taken for past 4800 sentences: 196.44523070899993
# Time taken for past 4900 sentences: 200.0253040839999
# Time taken for past 5000 sentences: 204.75557700000002
# UAS score on 127143 tokens over 5000 sentences: 0.9417978182046987
# Time taken for epoch: 204.85293816699993
# 0.0
#
# Start time: 1139.418793708
# Epoch: 5
# Time taken for past 100 sentences: 3.6202158749999853
# Time taken for past 200 sentences: 6.813669749999917
# Time taken for past 300 sentences: 10.889560874999916
# Time taken for past 400 sentences: 15.01207070800001
# Time taken for past 500 sentences: 19.536590875
# Time taken for past 600 sentences: 23.166469374999906
# Time taken for past 700 sentences: 27.406545625000035
# Time taken for past 800 sentences: 31.17626241699986
# Time taken for past 900 sentences: 35.479346249999935
# Time taken for past 1000 sentences: 39.0335849999999
# Time taken for past 1100 sentences: 43.22898158299995
# Time taken for past 1200 sentences: 48.95005937499991
# Time taken for past 1300 sentences: 56.43323254200004
# Time taken for past 1400 sentences: 62.56742474999987
# Time taken for past 1500 sentences: 66.93691054199985
# Time taken for past 1600 sentences: 70.94441779199997
# Time taken for past 1700 sentences: 75.51626124999984
# Time taken for past 1800 sentences: 79.95224037499997
# Time taken for past 1900 sentences: 83.78795908300003
# Time taken for past 2000 sentences: 88.90509020800005
# Time taken for past 2100 sentences: 94.46004570799983
# Time taken for past 2200 sentences: 99.07699562499988
# Time taken for past 2300 sentences: 102.21913970799983
# Time taken for past 2400 sentences: 106.99466333299983
# Time taken for past 2500 sentences: 110.265046042
# Time taken for past 2600 sentences: 113.54652575
# Time taken for past 2700 sentences: 118.92602587499982
# Time taken for past 2800 sentences: 123.49995858299985
# Time taken for past 2900 sentences: 127.87017304200003
# Time taken for past 3000 sentences: 132.17290591699998
# Time taken for past 3100 sentences: 136.887720833
# Time taken for past 3200 sentences: 141.75574679199985
# Time taken for past 3300 sentences: 148.622218792
# Time taken for past 3400 sentences: 155.68030079200003
# Time taken for past 3500 sentences: 162.72216266700002
# Time taken for past 3600 sentences: 167.62736395799993
# Time taken for past 3700 sentences: 171.90552187499998
# Time taken for past 3800 sentences: 176.00469254199993
# Time taken for past 3900 sentences: 179.68867345800004
# Time taken for past 4000 sentences: 183.95279812499984
# Time taken for past 4100 sentences: 188.34890124999993
# Time taken for past 4200 sentences: 192.54348341699983
# Time taken for past 4300 sentences: 197.60304470799997
# Time taken for past 4400 sentences: 201.80271954199998
# Time taken for past 4500 sentences: 206.196614125
# Time taken for past 4600 sentences: 210.523493292
# Time taken for past 4700 sentences: 214.54651824999996
# Time taken for past 4800 sentences: 218.02010437499985
# Time taken for past 4900 sentences: 221.62050258299996
# Time taken for past 5000 sentences: 226.56140304199994
# UAS score on 127143 tokens over 5000 sentences: 0.9483337659171169
# Time taken for epoch: 226.72793458299998
# 0.0

# %%
model_en_5k.make_predictions(dev_gold_data)

# %%
dev_gold_data.evaluate()
# Out:
# UAS score on 27678 tokens over 1083 sentences: 0.7910614928824337
# 0.7910614928824337

# %%
test_gold_path_en = "Treebanks/english/test/wsj_test.conll06.blind"
reader_en_test = Reader(test_gold_path_en)
test_gold_data = Data(reader_en_test.read_file())
test_gold_data.sentences
# Out:
# [<IO.Sentence at 0x127c3ab80>,
#  <IO.Sentence at 0x1689eadf0>,
#  <IO.Sentence at 0x168a06250>,
#  <IO.Sentence at 0x168a06790>,
#  <IO.Sentence at 0x168a06eb0>,
#  <IO.Sentence at 0x128030280>,
#  <IO.Sentence at 0x128030910>,
#  <IO.Sentence at 0x128030c10>,
#  <IO.Sentence at 0x128030f70>,
#  <IO.Sentence at 0x1282dd1c0>,
#  <IO.Sentence at 0x1282dd550>,
#  <IO.Sentence at 0x1282ddac0>,
#  <IO.Sentence at 0x1282ddeb0>,
#  <IO.Sentence at 0x128110760>,
#  <IO.Sentence at 0x128110f40>,
#  <IO.Sentence at 0x128540880>,
#  <IO.Sentence at 0x128540d90>,
#  <IO.Sentence at 0x128409310>,
#  <IO.Sentence at 0x128409940>,
#  <IO.Sentence at 0x128409dc0>,
#  <IO.Sentence at 0x1281c5250>,
#  <IO.Sentence at 0x1281c5700>,
#  <IO.Sentence at 0x1281c5a90>,
#  <IO.Sentence at 0x1281c5fa0>,
#  <IO.Sentence at 0x37e76c3a0>,
#  <IO.Sentence at 0x37e76c760>,
#  <IO.Sentence at 0x37e76cd90>,
#  <IO.Sentence at 0x1283d6670>,
#  <IO.Sentence at 0x1283d6910>,
#  <IO.Sentence at 0x1283d6cd0>,
#  <IO.Sentence at 0x12863c0d0>,
#  <IO.Sentence at 0x12863c610>,
#  <IO.Sentence at 0x12863ca90>,
#  <IO.Sentence at 0x1286630a0>,
#  <IO.Sentence at 0x1286636d0>,
#  <IO.Sentence at 0x128663b80>,
#  <IO.Sentence at 0x1281500a0>,
#  <IO.Sentence at 0x128150a00>,
#  <IO.Sentence at 0x1286b9100>,
#  <IO.Sentence at 0x1286b9400>,
#  <IO.Sentence at 0x1286b9820>,
#  <IO.Sentence at 0x1286b9a60>,
#  <IO.Sentence at 0x1286b9cd0>,
#  <IO.Sentence at 0x1286d6100>,
#  <IO.Sentence at 0x1286d65e0>,
#  <IO.Sentence at 0x1286d6ee0>,
#  <IO.Sentence at 0x168a6e520>,
#  <IO.Sentence at 0x168a6e9a0>,
#  <IO.Sentence at 0x168a6edf0>,
#  <IO.Sentence at 0x168a6efd0>,
#  <IO.Sentence at 0x168a6a250>,
#  <IO.Sentence at 0x168a6a580>,
#  <IO.Sentence at 0x168a6af10>,
#  <IO.Sentence at 0x128717220>,
#  <IO.Sentence at 0x128717640>,
#  <IO.Sentence at 0x128717ac0>,
#  <IO.Sentence at 0x128717ee0>,
#  <IO.Sentence at 0x128701490>,
#  <IO.Sentence at 0x128701940>,
#  <IO.Sentence at 0x128701f70>,
#  <IO.Sentence at 0x128722340>,
#  <IO.Sentence at 0x128722910>,
#  <IO.Sentence at 0x128722e20>,
#  <IO.Sentence at 0x128714100>,
#  <IO.Sentence at 0x128714490>,
#  <IO.Sentence at 0x128714ac0>,
#  <IO.Sentence at 0x12870e490>,
#  <IO.Sentence at 0x12870e8e0>,
#  <IO.Sentence at 0x12870eb80>,
#  <IO.Sentence at 0x12870eee0>,
#  <IO.Sentence at 0x12875d400>,
#  <IO.Sentence at 0x12875d580>,
#  <IO.Sentence at 0x12875dd60>,
#  <IO.Sentence at 0x12875a130>,
#  <IO.Sentence at 0x12875a400>,
#  <IO.Sentence at 0x12875a760>,
#  <IO.Sentence at 0x12875aeb0>,
#  <IO.Sentence at 0x1287625e0>,
#  <IO.Sentence at 0x128762c70>,
#  <IO.Sentence at 0x128769130>,
#  <IO.Sentence at 0x128769340>,
#  <IO.Sentence at 0x128769940>,
#  <IO.Sentence at 0x128769d30>,
#  <IO.Sentence at 0x12877d250>,
#  <IO.Sentence at 0x12877d580>,
#  <IO.Sentence at 0x12877d940>,
#  <IO.Sentence at 0x12877dbe0>,
#  <IO.Sentence at 0x128758040>,
#  <IO.Sentence at 0x1287581c0>,
#  <IO.Sentence at 0x1287586a0>,
#  <IO.Sentence at 0x1287588e0>,
#  <IO.Sentence at 0x128758fd0>,
#  <IO.Sentence at 0x12876c4f0>,
#  <IO.Sentence at 0x12876c790>,
#  <IO.Sentence at 0x12876cb80>,
#  <IO.Sentence at 0x12874b250>,
#  <IO.Sentence at 0x12874b5b0>,
#  <IO.Sentence at 0x12874b9d0>,
#  <IO.Sentence at 0x12874bf70>,
#  <IO.Sentence at 0x128797370>,
#  <IO.Sentence at 0x1287977f0>,
#  <IO.Sentence at 0x128797e20>,
#  <IO.Sentence at 0x1287b21f0>,
#  <IO.Sentence at 0x1287b25b0>,
#  <IO.Sentence at 0x1287b2760>,
#  <IO.Sentence at 0x1287b2d30>,
#  <IO.Sentence at 0x1287af0a0>,
#  <IO.Sentence at 0x1287af580>,
#  <IO.Sentence at 0x1287af9a0>,
#  <IO.Sentence at 0x1287afe80>,
#  <IO.Sentence at 0x1287a66d0>,
#  <IO.Sentence at 0x1287a6f70>,
#  <IO.Sentence at 0x1287aaa30>,
#  <IO.Sentence at 0x1287aaf40>,
#  <IO.Sentence at 0x1287955b0>,
#  <IO.Sentence at 0x128795d90>,
#  <IO.Sentence at 0x1287917f0>,
#  <IO.Sentence at 0x128791a30>,
#  <IO.Sentence at 0x128791fa0>,
#  <IO.Sentence at 0x1287a1340>,
#  <IO.Sentence at 0x1287a1730>,
#  <IO.Sentence at 0x1287a1be0>,
#  <IO.Sentence at 0x128789370>,
#  <IO.Sentence at 0x1287899d0>,
#  <IO.Sentence at 0x128789e80>,
#  <IO.Sentence at 0x12887e640>,
#  <IO.Sentence at 0x12887ec10>,
#  <IO.Sentence at 0x12887efd0>,
#  <IO.Sentence at 0x128854580>,
#  <IO.Sentence at 0x128854f10>,
#  <IO.Sentence at 0x12886e550>,
#  <IO.Sentence at 0x12886eca0>,
#  <IO.Sentence at 0x12885c100>,
#  <IO.Sentence at 0x12885c490>,
#  <IO.Sentence at 0x12885c8b0>,
#  <IO.Sentence at 0x12885cd30>,
#  <IO.Sentence at 0x12885cf10>,
#  <IO.Sentence at 0x1288696a0>,
#  <IO.Sentence at 0x128869d60>,
#  <IO.Sentence at 0x128869fd0>,
#  <IO.Sentence at 0x12889f640>,
#  <IO.Sentence at 0x12889ff40>,
#  <IO.Sentence at 0x1288a2850>,
#  <IO.Sentence at 0x1288a2ca0>,
#  <IO.Sentence at 0x1288ba070>,
#  <IO.Sentence at 0x1288ba3a0>,
#  <IO.Sentence at 0x1288ba6d0>,
#  <IO.Sentence at 0x1288baa00>,
#  <IO.Sentence at 0x1288bacd0>,
#  <IO.Sentence at 0x1288951f0>,
#  <IO.Sentence at 0x128895580>,
#  <IO.Sentence at 0x128895c40>,
#  <IO.Sentence at 0x1287ee370>,
#  <IO.Sentence at 0x1287ee7c0>,
#  <IO.Sentence at 0x1287eef40>,
#  <IO.Sentence at 0x1287ce220>,
#  <IO.Sentence at 0x1287ce4f0>,
#  <IO.Sentence at 0x1287ced00>,
#  <IO.Sentence at 0x1287c5130>,
#  <IO.Sentence at 0x1287c57c0>,
#  <IO.Sentence at 0x1287c5d00>,
#  <IO.Sentence at 0x1287d5220>,
#  <IO.Sentence at 0x1287d56a0>,
#  <IO.Sentence at 0x1287d5df0>,
#  <IO.Sentence at 0x128833400>,
#  <IO.Sentence at 0x128833910>,
#  <IO.Sentence at 0x12880e190>,
#  <IO.Sentence at 0x12880e490>,
#  <IO.Sentence at 0x12880eeb0>,
#  <IO.Sentence at 0x128817340>,
#  <IO.Sentence at 0x128817730>,
#  <IO.Sentence at 0x128817eb0>,
#  <IO.Sentence at 0x128808520>,
#  <IO.Sentence at 0x128808760>,
#  <IO.Sentence at 0x128808c10>,
#  <IO.Sentence at 0x128834310>,
#  <IO.Sentence at 0x128834850>,
#  <IO.Sentence at 0x128834f70>,
#  <IO.Sentence at 0x1288d3700>,
#  <IO.Sentence at 0x1288d3a30>,
#  <IO.Sentence at 0x1288c0040>,
#  <IO.Sentence at 0x1288c0430>,
#  <IO.Sentence at 0x1288c0970>,
#  <IO.Sentence at 0x1288c0e80>,
#  <IO.Sentence at 0x1288c7280>,
#  <IO.Sentence at 0x1288c7a90>,
#  <IO.Sentence at 0x1288c7b50>,
#  <IO.Sentence at 0x1288e2220>,
#  <IO.Sentence at 0x1288e28b0>,
#  <IO.Sentence at 0x1288e2c70>,
#  <IO.Sentence at 0x1288ea280>,
#  <IO.Sentence at 0x1288ea700>,
#  <IO.Sentence at 0x1288eac10>,
#  <IO.Sentence at 0x1288f30d0>,
#  <IO.Sentence at 0x1288f3430>,
#  <IO.Sentence at 0x1288f3940>,
#  <IO.Sentence at 0x1288fb0d0>,
#  <IO.Sentence at 0x1288fb6d0>,
#  <IO.Sentence at 0x1288fbd90>,
#  <IO.Sentence at 0x128906460>,
#  <IO.Sentence at 0x128906b50>,
#  <IO.Sentence at 0x128910190>,
#  <IO.Sentence at 0x128910970>,
#  <IO.Sentence at 0x128910c10>,
#  <IO.Sentence at 0x128918520>,
#  <IO.Sentence at 0x1289188b0>,
#  <IO.Sentence at 0x128918f40>,
#  <IO.Sentence at 0x1289224f0>,
#  <IO.Sentence at 0x1289229a0>,
#  <IO.Sentence at 0x12892b070>,
#  <IO.Sentence at 0x12892b790>,
#  <IO.Sentence at 0x12892bf70>,
#  <IO.Sentence at 0x1289347f0>,
#  <IO.Sentence at 0x128934a90>,
#  <IO.Sentence at 0x128934f10>,
#  <IO.Sentence at 0x12893f610>,
#  <IO.Sentence at 0x12893fe80>,
#  <IO.Sentence at 0x128947220>,
#  <IO.Sentence at 0x128947760>,
#  <IO.Sentence at 0x128947be0>,
#  <IO.Sentence at 0x128951340>,
#  <IO.Sentence at 0x128951490>,
#  <IO.Sentence at 0x1289515b0>,
#  <IO.Sentence at 0x128951b50>,
#  <IO.Sentence at 0x128951f70>,
#  <IO.Sentence at 0x1289580d0>,
#  <IO.Sentence at 0x128958550>,
#  <IO.Sentence at 0x128958910>,
#  <IO.Sentence at 0x128958a90>,
#  <IO.Sentence at 0x1289611f0>,
#  <IO.Sentence at 0x128961640>,
#  <IO.Sentence at 0x128961e80>,
#  <IO.Sentence at 0x128961fa0>,
#  <IO.Sentence at 0x1289693d0>,
#  <IO.Sentence at 0x128969a30>,
#  <IO.Sentence at 0x128969d60>,
#  <IO.Sentence at 0x128973160>,
#  <IO.Sentence at 0x128973880>,
#  <IO.Sentence at 0x12897c0d0>,
#  <IO.Sentence at 0x12897c4f0>,
#  <IO.Sentence at 0x12897c940>,
#  <IO.Sentence at 0x12897cf70>,
#  <IO.Sentence at 0x128985490>,
#  <IO.Sentence at 0x1289858b0>,
#  <IO.Sentence at 0x128985e50>,
#  <IO.Sentence at 0x12898d280>,
#  <IO.Sentence at 0x12898dc10>,
#  <IO.Sentence at 0x128998370>,
#  <IO.Sentence at 0x1289988e0>,
#  <IO.Sentence at 0x128998eb0>,
#  <IO.Sentence at 0x1289a14f0>,
#  <IO.Sentence at 0x1289a19a0>,
#  <IO.Sentence at 0x1289aa070>,
#  <IO.Sentence at 0x1289aa6d0>,
#  <IO.Sentence at 0x1289aab50>,
#  <IO.Sentence at 0x1289b4310>,
#  <IO.Sentence at 0x1289b4a90>,
#  <IO.Sentence at 0x1289bd3a0>,
#  <IO.Sentence at 0x1289bd9d0>,
#  <IO.Sentence at 0x1289c6040>,
#  <IO.Sentence at 0x1289c63d0>,
#  <IO.Sentence at 0x1289c6a60>,
#  <IO.Sentence at 0x1289c6f10>,
#  <IO.Sentence at 0x1289d0760>,
#  <IO.Sentence at 0x1289d0d30>,
#  <IO.Sentence at 0x1289da100>,
#  <IO.Sentence at 0x1289da580>,
#  <IO.Sentence at 0x1289dadc0>,
#  <IO.Sentence at 0x1289e3970>,
#  <IO.Sentence at 0x1289e3d60>,
#  <IO.Sentence at 0x1289ec550>,
#  <IO.Sentence at 0x1289ecbb0>,
#  <IO.Sentence at 0x1289ece50>,
#  <IO.Sentence at 0x1289f62b0>,
#  <IO.Sentence at 0x1289f6a30>,
#  <IO.Sentence at 0x1289f6f70>,
#  <IO.Sentence at 0x1289fe190>,
#  <IO.Sentence at 0x1289fe490>,
#  <IO.Sentence at 0x1289fe9d0>,
#  <IO.Sentence at 0x128a071f0>,
#  <IO.Sentence at 0x128a07880>,
#  <IO.Sentence at 0x128a12100>,
#  <IO.Sentence at 0x128a123a0>,
#  <IO.Sentence at 0x128a12610>,
#  <IO.Sentence at 0x128a12c40>,
#  <IO.Sentence at 0x128a1a550>,
#  <IO.Sentence at 0x128a1a940>,
#  <IO.Sentence at 0x128a23430>,
#  <IO.Sentence at 0x128a23820>,
#  <IO.Sentence at 0x128a2c0d0>,
#  <IO.Sentence at 0x128a2cb50>,
#  <IO.Sentence at 0x128a37310>,
#  <IO.Sentence at 0x128a37940>,
#  <IO.Sentence at 0x128a37d00>,
#  <IO.Sentence at 0x128a40520>,
#  <IO.Sentence at 0x128a40a60>,
#  <IO.Sentence at 0x128a49040>,
#  <IO.Sentence at 0x128a49790>,
#  <IO.Sentence at 0x128a49b80>,
#  <IO.Sentence at 0x128a49d90>,
#  <IO.Sentence at 0x128a52490>,
#  <IO.Sentence at 0x128a52910>,
#  <IO.Sentence at 0x128a52d00>,
#  <IO.Sentence at 0x128a5a190>,
#  <IO.Sentence at 0x128a5a4f0>,
#  <IO.Sentence at 0x128a641f0>,
#  <IO.Sentence at 0x128a643d0>,
#  <IO.Sentence at 0x128a64b20>,
#  <IO.Sentence at 0x128a6c0a0>,
#  <IO.Sentence at 0x128a6c5e0>,
#  <IO.Sentence at 0x128a6cac0>,
#  <IO.Sentence at 0x128a75100>,
#  <IO.Sentence at 0x128a755e0>,
#  <IO.Sentence at 0x128a75c70>,
#  <IO.Sentence at 0x128a7e3a0>,
#  <IO.Sentence at 0x128a7e610>,
#  <IO.Sentence at 0x128a7ee80>,
#  <IO.Sentence at 0x128a87760>,
#  <IO.Sentence at 0x128a87a60>,
#  <IO.Sentence at 0x128a87be0>,
#  <IO.Sentence at 0x128a923d0>,
#  <IO.Sentence at 0x128a92b20>,
#  <IO.Sentence at 0x128a92ee0>,
#  <IO.Sentence at 0x128a9a5b0>,
#  <IO.Sentence at 0x128a9ac10>,
#  <IO.Sentence at 0x128aa4520>,
#  <IO.Sentence at 0x128aa4880>,
#  <IO.Sentence at 0x128aa4f70>,
#  <IO.Sentence at 0x128aad4c0>,
#  <IO.Sentence at 0x128aad8b0>,
#  <IO.Sentence at 0x128ab7070>,
#  <IO.Sentence at 0x128ab7700>,
#  <IO.Sentence at 0x128ab7a60>,
#  <IO.Sentence at 0x128ab7f70>,
#  <IO.Sentence at 0x128abf580>,
#  <IO.Sentence at 0x128abf9d0>,
#  <IO.Sentence at 0x128ac9130>,
#  <IO.Sentence at 0x128ac96d0>,
#  <IO.Sentence at 0x128ac9af0>,
#  <IO.Sentence at 0x128ac9d60>,
#  <IO.Sentence at 0x128ad3100>,
#  <IO.Sentence at 0x128ad3370>,
#  <IO.Sentence at 0x128ad3640>,
#  <IO.Sentence at 0x128ad3c10>,
#  <IO.Sentence at 0x128adc2b0>,
#  <IO.Sentence at 0x128adc5b0>,
#  <IO.Sentence at 0x128adcac0>,
#  <IO.Sentence at 0x128adcf70>,
#  <IO.Sentence at 0x128ae5280>,
#  <IO.Sentence at 0x128ae5910>,
#  <IO.Sentence at 0x128ae5e80>,
#  <IO.Sentence at 0x128aee250>,
#  <IO.Sentence at 0x128aee820>,
#  <IO.Sentence at 0x128aeec40>,
#  <IO.Sentence at 0x128af8280>,
#  <IO.Sentence at 0x128af88b0>,
#  <IO.Sentence at 0x128af8e50>,
#  <IO.Sentence at 0x128b015b0>,
#  <IO.Sentence at 0x128b018e0>,
#  <IO.Sentence at 0x128b01c70>,
#  <IO.Sentence at 0x128b0a250>,
#  <IO.Sentence at 0x128b0a820>,
#  <IO.Sentence at 0x128b0ad30>,
#  <IO.Sentence at 0x128b12190>,
#  <IO.Sentence at 0x128b124c0>,
#  <IO.Sentence at 0x128b12850>,
#  <IO.Sentence at 0x128b12b50>,
#  <IO.Sentence at 0x128b1b1f0>,
#  <IO.Sentence at 0x128b1b4f0>,
#  <IO.Sentence at 0x128b1b760>,
#  <IO.Sentence at 0x128b1bbe0>,
#  <IO.Sentence at 0x128b1be20>,
#  <IO.Sentence at 0x128b22160>,
#  <IO.Sentence at 0x128b22400>,
#  <IO.Sentence at 0x128b22820>,
#  <IO.Sentence at 0x128b22c70>,
#  <IO.Sentence at 0x128b2b2b0>,
#  <IO.Sentence at 0x128b2b940>,
#  <IO.Sentence at 0x128b2bee0>,
#  <IO.Sentence at 0x128b345b0>,
#  <IO.Sentence at 0x128b34b50>,
#  <IO.Sentence at 0x128b34f10>,
#  <IO.Sentence at 0x128b3e460>,
#  <IO.Sentence at 0x128b3ebe0>,
#  <IO.Sentence at 0x128b48160>,
#  <IO.Sentence at 0x128b48640>,
#  <IO.Sentence at 0x128b48e80>,
#  <IO.Sentence at 0x128b50400>,
#  <IO.Sentence at 0x128b50820>,
#  <IO.Sentence at 0x128b50eb0>,
#  <IO.Sentence at 0x128b5a550>,
#  <IO.Sentence at 0x128b5ac10>,
#  <IO.Sentence at 0x128b624f0>,
#  <IO.Sentence at 0x128b62b20>,
#  <IO.Sentence at 0x128b6c040>,
#  <IO.Sentence at 0x128b6c490>,
#  <IO.Sentence at 0x128b6cac0>,
#  <IO.Sentence at 0x128b6cee0>,
#  <IO.Sentence at 0x128b75310>,
#  <IO.Sentence at 0x128b75970>,
#  <IO.Sentence at 0x128b75e80>,
#  <IO.Sentence at 0x128b7e160>,
#  <IO.Sentence at 0x128b7e610>,
#  <IO.Sentence at 0x128b7edf0>,
#  <IO.Sentence at 0x128b877c0>,
#  <IO.Sentence at 0x128b87e80>,
#  <IO.Sentence at 0x128b91790>,
#  <IO.Sentence at 0x128b91ee0>,
#  <IO.Sentence at 0x128b9b700>,
#  <IO.Sentence at 0x128b9bd00>,
#  <IO.Sentence at 0x128ba3100>,
#  <IO.Sentence at 0x128ba3460>,
#  <IO.Sentence at 0x128ba3a00>,
#  <IO.Sentence at 0x128ba3e20>,
#  <IO.Sentence at 0x128bac3d0>,
#  <IO.Sentence at 0x128bac8b0>,
#  <IO.Sentence at 0x128bacc10>,
#  <IO.Sentence at 0x128bacee0>,
#  <IO.Sentence at 0x128bb4550>,
#  <IO.Sentence at 0x128bb4bb0>,
#  <IO.Sentence at 0x128bbe070>,
#  <IO.Sentence at 0x128bbe9a0>,
#  <IO.Sentence at 0x128bbec40>,
#  <IO.Sentence at 0x128bc7070>,
#  <IO.Sentence at 0x128bc74f0>,
#  <IO.Sentence at 0x128bc7be0>,
#  <IO.Sentence at 0x128bcf0d0>,
#  <IO.Sentence at 0x128bcf4c0>,
#  <IO.Sentence at 0x128bcf9d0>,
#  <IO.Sentence at 0x128bcffa0>,
#  <IO.Sentence at 0x128bd93a0>,
#  <IO.Sentence at 0x128bd9820>,
#  <IO.Sentence at 0x128bd9f40>,
#  <IO.Sentence at 0x128be2340>,
#  <IO.Sentence at 0x128be27c0>,
#  <IO.Sentence at 0x128be2ac0>,
#  <IO.Sentence at 0x128be2e50>,
#  <IO.Sentence at 0x128beb220>,
#  <IO.Sentence at 0x128beba90>,
#  <IO.Sentence at 0x128bf35e0>,
#  <IO.Sentence at 0x128bf3be0>,
#  <IO.Sentence at 0x128bf3fa0>,
#  <IO.Sentence at 0x128bfc7c0>,
#  <IO.Sentence at 0x128c07520>,
#  <IO.Sentence at 0x128c07df0>,
#  <IO.Sentence at 0x128c0f490>,
#  <IO.Sentence at 0x128c0fc10>,
#  <IO.Sentence at 0x128c194f0>,
#  <IO.Sentence at 0x128c19b20>,
#  <IO.Sentence at 0x128c22040>,
#  <IO.Sentence at 0x128c223d0>,
#  <IO.Sentence at 0x128c22700>,
#  <IO.Sentence at 0x128c229a0>,
#  <IO.Sentence at 0x128c22df0>,
#  <IO.Sentence at 0x128c2b460>,
#  <IO.Sentence at 0x128c2b700>,
#  <IO.Sentence at 0x128c2bc40>,
#  <IO.Sentence at 0x128c34250>,
#  <IO.Sentence at 0x128c34550>,
#  <IO.Sentence at 0x128c34b50>,
#  <IO.Sentence at 0x128c34df0>,
#  <IO.Sentence at 0x128c3d2b0>,
#  <IO.Sentence at 0x128c3dac0>,
#  <IO.Sentence at 0x128c3deb0>,
#  <IO.Sentence at 0x128c466d0>,
#  <IO.Sentence at 0x128c46ac0>,
#  <IO.Sentence at 0x128c4f040>,
#  <IO.Sentence at 0x128c4f370>,
#  <IO.Sentence at 0x128c4f970>,
#  <IO.Sentence at 0x128c4fdf0>,
#  <IO.Sentence at 0x128c58250>,
#  <IO.Sentence at 0x128c58520>,
#  <IO.Sentence at 0x128c58880>,
#  <IO.Sentence at 0x128c58fd0>,
#  <IO.Sentence at 0x128c60760>,
#  <IO.Sentence at 0x128c609a0>,
#  <IO.Sentence at 0x128c6a1f0>,
#  <IO.Sentence at 0x128c6aa30>,
#  <IO.Sentence at 0x128c721c0>,
#  <IO.Sentence at 0x128c729d0>,
#  <IO.Sentence at 0x128c72df0>,
#  <IO.Sentence at 0x128c7c220>,
#  <IO.Sentence at 0x128c7c670>,
#  <IO.Sentence at 0x128c7cfd0>,
#  <IO.Sentence at 0x128c841f0>,
#  <IO.Sentence at 0x128c84640>,
#  <IO.Sentence at 0x128c84bb0>,
#  <IO.Sentence at 0x128c8e0a0>,
#  <IO.Sentence at 0x128c8e670>,
#  <IO.Sentence at 0x128c8edf0>,
#  <IO.Sentence at 0x128c98310>,
#  <IO.Sentence at 0x128c98550>,
#  <IO.Sentence at 0x128c98d60>,
#  <IO.Sentence at 0x128ca1160>,
#  <IO.Sentence at 0x128ca1730>,
#  <IO.Sentence at 0x128ca19d0>,
#  <IO.Sentence at 0x128ca1d30>,
#  <IO.Sentence at 0x128caa340>,
#  <IO.Sentence at 0x128caaac0>,
#  <IO.Sentence at 0x128caad90>,
#  <IO.Sentence at 0x128cb3310>,
#  <IO.Sentence at 0x128cb3b50>,
#  <IO.Sentence at 0x128cbd220>,
#  <IO.Sentence at 0x128cbd6a0>,
#  <IO.Sentence at 0x128cbda30>,
#  <IO.Sentence at 0x128cc5100>,
#  <IO.Sentence at 0x128cc5850>,
#  <IO.Sentence at 0x128cc5a30>,
#  <IO.Sentence at 0x128ccf4c0>,
#  <IO.Sentence at 0x128ccf8b0>,
#  <IO.Sentence at 0x128ccfd60>,
#  <IO.Sentence at 0x128cd8370>,
#  <IO.Sentence at 0x128cd8a00>,
#  <IO.Sentence at 0x128ce21c0>,
#  <IO.Sentence at 0x128ce2940>,
#  <IO.Sentence at 0x128ce2dc0>,
#  <IO.Sentence at 0x128ceb310>,
#  <IO.Sentence at 0x128ceb700>,
#  <IO.Sentence at 0x128ceba90>,
#  <IO.Sentence at 0x128cebf10>,
#  <IO.Sentence at 0x128cf32b0>,
#  <IO.Sentence at 0x128cf3c70>,
#  <IO.Sentence at 0x128cfd610>,
#  <IO.Sentence at 0x128cfdbe0>,
#  <IO.Sentence at 0x128d072b0>,
#  <IO.Sentence at 0x128d07550>,
#  <IO.Sentence at 0x128d07880>,
#  <IO.Sentence at 0x128d07c70>,
#  <IO.Sentence at 0x128d110a0>,
#  <IO.Sentence at 0x128d111c0>,
#  <IO.Sentence at 0x128d117c0>,
#  <IO.Sentence at 0x128d1a130>,
#  <IO.Sentence at 0x128d1a5e0>,
#  <IO.Sentence at 0x128d1ab20>,
#  <IO.Sentence at 0x128d23190>,
#  <IO.Sentence at 0x128d23910>,
#  <IO.Sentence at 0x128d23ca0>,
#  <IO.Sentence at 0x128d2c0a0>,
#  <IO.Sentence at 0x128d2c490>,
#  <IO.Sentence at 0x128d2c790>,
#  <IO.Sentence at 0x128d2cd60>,
#  <IO.Sentence at 0x128d34610>,
#  <IO.Sentence at 0x128d34bb0>,
#  <IO.Sentence at 0x128d3e3a0>,
#  <IO.Sentence at 0x128d3ea90>,
#  <IO.Sentence at 0x128d47430>,
#  <IO.Sentence at 0x128d475e0>,
#  <IO.Sentence at 0x128d47eb0>,
#  <IO.Sentence at 0x128d513d0>,
#  <IO.Sentence at 0x128d51940>,
#  <IO.Sentence at 0x128d5b2e0>,
#  <IO.Sentence at 0x128d5b8e0>,
#  <IO.Sentence at 0x128d5be20>,
#  <IO.Sentence at 0x128d634f0>,
#  <IO.Sentence at 0x128d63a60>,
#  <IO.Sentence at 0x128d63dc0>,
#  <IO.Sentence at 0x128d6c2b0>,
#  <IO.Sentence at 0x128d6c8b0>,
#  <IO.Sentence at 0x128d6ca90>,
#  <IO.Sentence at 0x128d6cd90>,
#  <IO.Sentence at 0x128d74430>,
#  <IO.Sentence at 0x128d74730>,
#  <IO.Sentence at 0x128d74eb0>,
#  <IO.Sentence at 0x128d7f3a0>,
#  <IO.Sentence at 0x128d7f700>,
#  <IO.Sentence at 0x128d7f9d0>,
#  <IO.Sentence at 0x128d87310>,
#  <IO.Sentence at 0x128d876a0>,
#  <IO.Sentence at 0x128d87cd0>,
#  <IO.Sentence at 0x128d91070>,
#  <IO.Sentence at 0x128d914f0>,
#  <IO.Sentence at 0x128d918e0>,
#  <IO.Sentence at 0x128d91ee0>,
#  <IO.Sentence at 0x128d9b370>,
#  <IO.Sentence at 0x128d9b880>,
#  <IO.Sentence at 0x128d9be20>,
#  <IO.Sentence at 0x128da53d0>,
#  <IO.Sentence at 0x128da5550>,
#  <IO.Sentence at 0x128da5970>,
#  <IO.Sentence at 0x128da5f10>,
#  <IO.Sentence at 0x128dad670>,
#  <IO.Sentence at 0x128dadbe0>,
#  <IO.Sentence at 0x128db71c0>,
#  <IO.Sentence at 0x128db77f0>,
#  <IO.Sentence at 0x128db7b20>,
#  <IO.Sentence at 0x128db7e50>,
#  <IO.Sentence at 0x128dc0520>,
#  <IO.Sentence at 0x128dc0970>,
#  <IO.Sentence at 0x128dc0d90>,
#  <IO.Sentence at 0x128dc8070>,
#  <IO.Sentence at 0x128dc86a0>,
#  <IO.Sentence at 0x128dc8c40>,
#  <IO.Sentence at 0x128dd2280>,
#  <IO.Sentence at 0x128dd26d0>,
#  <IO.Sentence at 0x128dd2c70>,
#  <IO.Sentence at 0x128dda1f0>,
#  <IO.Sentence at 0x128dda670>,
#  <IO.Sentence at 0x128ddae50>,
#  <IO.Sentence at 0x128de4100>,
#  <IO.Sentence at 0x128de4670>,
#  <IO.Sentence at 0x128de4c40>,
#  <IO.Sentence at 0x128dec730>,
#  <IO.Sentence at 0x128decbb0>,
#  <IO.Sentence at 0x128df61c0>,
#  <IO.Sentence at 0x128df6a90>,
#  <IO.Sentence at 0x128e011c0>,
#  <IO.Sentence at 0x128e01940>,
#  <IO.Sentence at 0x128e091c0>,
#  <IO.Sentence at 0x128e098b0>,
#  <IO.Sentence at 0x128e130a0>,
#  <IO.Sentence at 0x128e135e0>,
#  <IO.Sentence at 0x128e13ee0>,
#  <IO.Sentence at 0x128e1d2e0>,
#  <IO.Sentence at 0x128e1dc40>,
#  <IO.Sentence at 0x128e26310>,
#  <IO.Sentence at 0x128e26730>,
#  <IO.Sentence at 0x128e26a00>,
#  <IO.Sentence at 0x128e26ee0>,
#  <IO.Sentence at 0x128e2e5e0>,
#  <IO.Sentence at 0x128e2e9d0>,
#  <IO.Sentence at 0x128e2ef10>,
#  <IO.Sentence at 0x128e38580>,
#  <IO.Sentence at 0x128e38b50>,
#  <IO.Sentence at 0x128e41040>,
#  <IO.Sentence at 0x128e41730>,
#  <IO.Sentence at 0x128e41e80>,
#  <IO.Sentence at 0x128e4a310>,
#  <IO.Sentence at 0x128e4aa60>,
#  <IO.Sentence at 0x128e552b0>,
#  <IO.Sentence at 0x128e557c0>,
#  <IO.Sentence at 0x128e55c40>,
#  <IO.Sentence at 0x128e5d100>,
#  <IO.Sentence at 0x128e5d5b0>,
#  <IO.Sentence at 0x128e5d8b0>,
#  <IO.Sentence at 0x128e5dd00>,
#  <IO.Sentence at 0x128e66100>,
#  <IO.Sentence at 0x128e666d0>,
#  <IO.Sentence at 0x128e66ac0>,
#  <IO.Sentence at 0x128e6e0d0>,
#  <IO.Sentence at 0x128e6e700>,
#  <IO.Sentence at 0x128e6ef70>,
#  <IO.Sentence at 0x128e77160>,
#  <IO.Sentence at 0x128e77ac0>,
#  <IO.Sentence at 0x128e81430>,
#  <IO.Sentence at 0x128e81910>,
#  <IO.Sentence at 0x128e8b0d0>,
#  <IO.Sentence at 0x128e8b490>,
#  <IO.Sentence at 0x128e8b8e0>,
#  <IO.Sentence at 0x128e8bdc0>,
#  <IO.Sentence at 0x128e944f0>,
#  <IO.Sentence at 0x128e94a00>,
#  <IO.Sentence at 0x128e94d60>,
#  <IO.Sentence at 0x128e9c7c0>,
#  <IO.Sentence at 0x128ea6070>,
#  <IO.Sentence at 0x128ea66d0>,
#  <IO.Sentence at 0x128ea6e20>,
#  <IO.Sentence at 0x128eae460>,
#  <IO.Sentence at 0x128eae880>,
#  <IO.Sentence at 0x128eaed90>,
#  <IO.Sentence at 0x128eb80d0>,
#  <IO.Sentence at 0x128eb88e0>,
#  <IO.Sentence at 0x128eb8eb0>,
#  <IO.Sentence at 0x128ec1280>,
#  <IO.Sentence at 0x128ec1640>,
#  <IO.Sentence at 0x128ec1d30>,
#  <IO.Sentence at 0x128ec1fa0>,
#  <IO.Sentence at 0x128ec9460>,
#  <IO.Sentence at 0x128ec9a30>,
#  <IO.Sentence at 0x128ec9d00>,
#  <IO.Sentence at 0x128ec9fa0>,
#  <IO.Sentence at 0x128ed28b0>,
#  <IO.Sentence at 0x128edc040>,
#  <IO.Sentence at 0x128edc760>,
#  <IO.Sentence at 0x128edcc10>,
#  <IO.Sentence at 0x128ee5070>,
#  <IO.Sentence at 0x128ee57f0>,
#  <IO.Sentence at 0x128ee5b50>,
#  <IO.Sentence at 0x128ee5d60>,
#  <IO.Sentence at 0x128eed250>,
#  <IO.Sentence at 0x128eeda60>,
#  <IO.Sentence at 0x128ef7130>,
#  <IO.Sentence at 0x128ef7580>,
#  <IO.Sentence at 0x128ef7b80>,
#  <IO.Sentence at 0x128f022e0>,
#  <IO.Sentence at 0x128f02880>,
#  <IO.Sentence at 0x128f02df0>,
#  <IO.Sentence at 0x128f0a0d0>,
#  <IO.Sentence at 0x128f0a8e0>,
#  <IO.Sentence at 0x128f0af40>,
#  <IO.Sentence at 0x128f14340>,
#  <IO.Sentence at 0x128f14d30>,
#  <IO.Sentence at 0x128f1c2e0>,
#  <IO.Sentence at 0x128f1c9a0>,
#  <IO.Sentence at 0x128f261f0>,
#  <IO.Sentence at 0x128f26700>,
#  <IO.Sentence at 0x128f269d0>,
#  <IO.Sentence at 0x128f26f10>,
#  <IO.Sentence at 0x128f2e460>,
#  <IO.Sentence at 0x128f2ea30>,
#  <IO.Sentence at 0x128f38130>,
#  <IO.Sentence at 0x128f387f0>,
#  <IO.Sentence at 0x128f38df0>,
#  <IO.Sentence at 0x128f423d0>,
#  <IO.Sentence at 0x128f42ac0>,
#  <IO.Sentence at 0x128f4b250>,
#  <IO.Sentence at 0x128f4b6a0>,
#  <IO.Sentence at 0x128f4be80>,
#  <IO.Sentence at 0x128f54820>,
#  <IO.Sentence at 0x128f54ca0>,
#  <IO.Sentence at 0x128f5d310>,
#  <IO.Sentence at 0x128f5d6d0>,
#  <IO.Sentence at 0x128f5dbb0>,
#  <IO.Sentence at 0x128f66100>,
#  <IO.Sentence at 0x128f66ac0>,
#  <IO.Sentence at 0x128f66d00>,
#  <IO.Sentence at 0x128f6f0d0>,
#  <IO.Sentence at 0x128f6f940>,
#  <IO.Sentence at 0x128f78070>,
#  <IO.Sentence at 0x128f784f0>,
#  <IO.Sentence at 0x128f78910>,
#  <IO.Sentence at 0x128f78df0>,
#  <IO.Sentence at 0x128f81340>,
#  <IO.Sentence at 0x128f81af0>,
#  <IO.Sentence at 0x128f8a460>,
#  <IO.Sentence at 0x128f8a970>,
#  <IO.Sentence at 0x128f8afa0>,
#  <IO.Sentence at 0x128f92610>,
#  <IO.Sentence at 0x128f92a30>,
#  <IO.Sentence at 0x128f96100>,
#  <IO.Sentence at 0x128f96d30>,
#  <IO.Sentence at 0x128f982b0>,
#  <IO.Sentence at 0x128f98850>,
#  <IO.Sentence at 0x128f9b1c0>,
#  <IO.Sentence at 0x128f9ba00>,
#  <IO.Sentence at 0x128f9be80>,
#  <IO.Sentence at 0x128f9e5e0>,
#  <IO.Sentence at 0x128f9e820>,
#  <IO.Sentence at 0x128f9ebe0>,
#  <IO.Sentence at 0x128fa63d0>,
#  <IO.Sentence at 0x128fa6be0>,
#  <IO.Sentence at 0x128fa6ee0>,
#  <IO.Sentence at 0x128fb00d0>,
#  <IO.Sentence at 0x128fb0280>,
#  <IO.Sentence at 0x128fb0490>,
#  <IO.Sentence at 0x128fb09d0>,
#  <IO.Sentence at 0x128fb0c70>,
#  <IO.Sentence at 0x128fb7250>,
#  <IO.Sentence at 0x128fb76d0>,
#  <IO.Sentence at 0x128fb7be0>,
#  <IO.Sentence at 0x128fc0190>,
#  <IO.Sentence at 0x128fc0460>,
#  <IO.Sentence at 0x128fc09d0>,
#  <IO.Sentence at 0x128fc0dc0>,
#  <IO.Sentence at 0x128fc8220>,
#  <IO.Sentence at 0x128fc87f0>,
#  <IO.Sentence at 0x128fc8e50>,
#  <IO.Sentence at 0x128fd2220>,
#  <IO.Sentence at 0x128fd23a0>,
#  <IO.Sentence at 0x128fd2670>,
#  <IO.Sentence at 0x128fd29d0>,
#  <IO.Sentence at 0x128fd9100>,
#  <IO.Sentence at 0x128fd9430>,
#  <IO.Sentence at 0x128fd96d0>,
#  <IO.Sentence at 0x128fd9be0>,
#  <IO.Sentence at 0x128fe3160>,
#  <IO.Sentence at 0x128fe33d0>,
#  <IO.Sentence at 0x128fe39d0>,
#  <IO.Sentence at 0x128fe3d90>,
#  <IO.Sentence at 0x128feb310>,
#  <IO.Sentence at 0x128feb730>,
#  <IO.Sentence at 0x128febac0>,
#  <IO.Sentence at 0x128febd30>,
#  <IO.Sentence at 0x128febfd0>,
#  <IO.Sentence at 0x128ff4430>,
#  <IO.Sentence at 0x128ff4b80>,
#  <IO.Sentence at 0x128ff4f40>,
#  <IO.Sentence at 0x128ffc2b0>,
#  <IO.Sentence at 0x128ffc700>,
#  <IO.Sentence at 0x128ffcbb0>,
#  <IO.Sentence at 0x129005040>,
#  <IO.Sentence at 0x1290055e0>,
#  <IO.Sentence at 0x129005cd0>,
#  <IO.Sentence at 0x129005fa0>,
#  <IO.Sentence at 0x12900e2b0>,
#  <IO.Sentence at 0x12900e5b0>,
#  <IO.Sentence at 0x12900ea60>,
#  <IO.Sentence at 0x1290170a0>,
#  <IO.Sentence at 0x1290171c0>,
#  <IO.Sentence at 0x129017700>,
#  <IO.Sentence at 0x129017cd0>,
#  <IO.Sentence at 0x1290200d0>,
#  <IO.Sentence at 0x1290205b0>,
#  <IO.Sentence at 0x129020b80>,
#  <IO.Sentence at 0x129020f40>,
#  <IO.Sentence at 0x129029490>,
#  <IO.Sentence at 0x1290297f0>,
#  <IO.Sentence at 0x129029a00>,
#  <IO.Sentence at 0x129029d90>,
#  <IO.Sentence at 0x129031520>,
#  <IO.Sentence at 0x129031b80>,
#  <IO.Sentence at 0x12903b190>,
#  <IO.Sentence at 0x12903b7f0>,
#  <IO.Sentence at 0x12903bca0>,
#  <IO.Sentence at 0x129045280>,
#  <IO.Sentence at 0x129045820>,
#  <IO.Sentence at 0x129045d30>,
#  <IO.Sentence at 0x12904d3a0>,
#  <IO.Sentence at 0x12904d820>,
#  <IO.Sentence at 0x12904db20>,
#  <IO.Sentence at 0x12904de20>,
#  <IO.Sentence at 0x1290560a0>,
#  <IO.Sentence at 0x129056340>,
#  <IO.Sentence at 0x129056b50>,
#  <IO.Sentence at 0x129056fd0>,
#  <IO.Sentence at 0x12905e1c0>,
#  <IO.Sentence at 0x12905e5e0>,
#  <IO.Sentence at 0x12905e940>,
#  <IO.Sentence at 0x129068220>,
#  <IO.Sentence at 0x1290686a0>,
#  <IO.Sentence at 0x129068b50>,
#  <IO.Sentence at 0x129068ee0>,
#  <IO.Sentence at 0x129070610>,
#  <IO.Sentence at 0x1290709d0>,
#  <IO.Sentence at 0x129070ac0>,
#  <IO.Sentence at 0x129070e50>,
#  <IO.Sentence at 0x12907a220>,
#  <IO.Sentence at 0x12907a880>,
#  <IO.Sentence at 0x1290820d0>,
#  <IO.Sentence at 0x129082a00>,
#  <IO.Sentence at 0x129082e20>,
#  <IO.Sentence at 0x12908c310>,
#  <IO.Sentence at 0x12908c6d0>,
#  <IO.Sentence at 0x12908c970>,
#  <IO.Sentence at 0x12908cfa0>,
#  <IO.Sentence at 0x129095640>,
#  <IO.Sentence at 0x129095ca0>,
#  <IO.Sentence at 0x12909f430>,
#  <IO.Sentence at 0x12909f940>,
#  <IO.Sentence at 0x12909fdc0>,
#  <IO.Sentence at 0x1290a80d0>,
#  <IO.Sentence at 0x1290a8910>,
#  <IO.Sentence at 0x1290b1130>,
#  <IO.Sentence at 0x1290b16a0>,
#  <IO.Sentence at 0x1290b1a60>,
#  <IO.Sentence at 0x1290b1b80>,
#  <IO.Sentence at 0x1290ba340>,
#  <IO.Sentence at 0x1290ba910>,
#  <IO.Sentence at 0x1290c3040>,
#  <IO.Sentence at 0x1290c3850>,
#  <IO.Sentence at 0x1290c3f70>,
#  <IO.Sentence at 0x1290cc6d0>,
#  <IO.Sentence at 0x1290cc940>,
#  <IO.Sentence at 0x1290d6310>,
#  <IO.Sentence at 0x1290d65b0>,
#  <IO.Sentence at 0x1290d6940>,
#  <IO.Sentence at 0x1290d6d60>,
#  <IO.Sentence at 0x1290df2e0>,
#  <IO.Sentence at 0x1290dfdf0>,
#  <IO.Sentence at 0x1290e96d0>,
#  <IO.Sentence at 0x1290e9c40>,
#  <IO.Sentence at 0x1290e9f10>,
#  <IO.Sentence at 0x1290f24c0>,
#  <IO.Sentence at 0x1290f2940>,
#  <IO.Sentence at 0x1290fb0a0>,
#  <IO.Sentence at 0x1290fb430>,
#  <IO.Sentence at 0x1290fbdc0>,
#  <IO.Sentence at 0x129104430>,
#  <IO.Sentence at 0x1291049a0>,
#  <IO.Sentence at 0x129104f10>,
#  <IO.Sentence at 0x12910d6a0>,
#  <IO.Sentence at 0x12910db50>,
#  <IO.Sentence at 0x1291170d0>,
#  <IO.Sentence at 0x129117700>,
#  <IO.Sentence at 0x129117be0>,
#  <IO.Sentence at 0x129117d00>,
#  <IO.Sentence at 0x12911f130>,
#  <IO.Sentence at 0x12911f490>,
#  <IO.Sentence at 0x12911f5e0>,
#  <IO.Sentence at 0x12911fb20>,
#  <IO.Sentence at 0x1291280a0>,
#  <IO.Sentence at 0x129128730>,
#  <IO.Sentence at 0x129128be0>,
#  <IO.Sentence at 0x129128f40>,
#  <IO.Sentence at 0x1291306a0>,
#  <IO.Sentence at 0x129130eb0>,
#  <IO.Sentence at 0x12913a3a0>,
#  <IO.Sentence at 0x12913aaf0>,
#  <IO.Sentence at 0x1291432e0>,
#  <IO.Sentence at 0x129143760>,
#  <IO.Sentence at 0x129143af0>,
#  <IO.Sentence at 0x12914e100>,
#  <IO.Sentence at 0x12914e610>,
#  <IO.Sentence at 0x12914ec40>,
#  <IO.Sentence at 0x129157070>,
#  <IO.Sentence at 0x129157820>,
#  <IO.Sentence at 0x129157d90>,
#  <IO.Sentence at 0x129157fa0>,
#  <IO.Sentence at 0x129160790>,
#  <IO.Sentence at 0x129160fa0>,
#  <IO.Sentence at 0x12916a700>,
#  <IO.Sentence at 0x12916a9d0>,
#  <IO.Sentence at 0x12916ad90>,
#  <IO.Sentence at 0x1291724c0>,
#  <IO.Sentence at 0x129172910>,
#  <IO.Sentence at 0x129172b50>,
#  <IO.Sentence at 0x12917c040>,
#  <IO.Sentence at 0x12917ca00>,
#  <IO.Sentence at 0x12917cd00>,
#  <IO.Sentence at 0x1291841c0>,
#  <IO.Sentence at 0x129184940>,
#  <IO.Sentence at 0x129184f40>,
#  <IO.Sentence at 0x12918d5b0>,
#  <IO.Sentence at 0x12918dd60>,
#  <IO.Sentence at 0x1291966d0>,
#  <IO.Sentence at 0x1291969d0>,
#  <IO.Sentence at 0x1291a0040>,
#  <IO.Sentence at 0x1291a0580>,
#  <IO.Sentence at 0x1291a0c40>,
#  <IO.Sentence at 0x1291a0e50>,
#  <IO.Sentence at 0x1291a9160>,
#  <IO.Sentence at 0x1291a95b0>,
#  <IO.Sentence at 0x1291a9b80>,
#  <IO.Sentence at 0x1291b10a0>,
#  <IO.Sentence at 0x1291b1760>,
#  <IO.Sentence at 0x1291b1c40>,
#  <IO.Sentence at 0x1291bb220>,
#  <IO.Sentence at 0x1291bb5b0>,
#  <IO.Sentence at 0x1291bb9d0>,
#  <IO.Sentence at 0x1291c3580>,
#  <IO.Sentence at 0x1291c3a60>,
#  <IO.Sentence at 0x1291c3d60>,
#  <IO.Sentence at 0x1291cd550>,
#  <IO.Sentence at 0x1291cdca0>,
#  <IO.Sentence at 0x1291d6280>,
#  <IO.Sentence at 0x1291d6a00>,
#  <IO.Sentence at 0x1291d6f40>,
#  <IO.Sentence at 0x1291e03a0>,
#  <IO.Sentence at 0x1291e0760>,
#  <IO.Sentence at 0x1291e0dc0>,
#  <IO.Sentence at 0x1291e9190>,
#  <IO.Sentence at 0x1291e9550>,
#  <IO.Sentence at 0x1291e9ac0>,
#  <IO.Sentence at 0x1291f2220>,
#  <IO.Sentence at 0x1291f24f0>,
#  <IO.Sentence at 0x1291f2640>,
#  <IO.Sentence at 0x1291f2b50>,
#  <IO.Sentence at 0x1291f2e50>,
#  <IO.Sentence at 0x1291fc370>,
#  <IO.Sentence at 0x1291fc5b0>,
#  <IO.Sentence at 0x1291fce80>,
#  <IO.Sentence at 0x129204190>,
#  <IO.Sentence at 0x1292045b0>,
#  <IO.Sentence at 0x129204c40>,
#  <IO.Sentence at 0x129204e50>,
#  <IO.Sentence at 0x12920d550>,
#  <IO.Sentence at 0x12920da30>,
#  <IO.Sentence at 0x12920de80>,
#  <IO.Sentence at 0x1292156d0>,
#  <IO.Sentence at 0x12921f0d0>,
#  <IO.Sentence at 0x12921f610>,
#  <IO.Sentence at 0x12921f760>,
#  <IO.Sentence at 0x12921fbe0>,
#  <IO.Sentence at 0x12921fdf0>,
#  <IO.Sentence at 0x12921fee0>,
#  <IO.Sentence at 0x129229070>,
#  <IO.Sentence at 0x129229880>,
#  <IO.Sentence at 0x129229f40>,
#  <IO.Sentence at 0x129232280>,
#  <IO.Sentence at 0x1292326a0>,
#  <IO.Sentence at 0x129232970>,
#  <IO.Sentence at 0x129232bb0>,
#  <IO.Sentence at 0x12923a280>,
#  <IO.Sentence at 0x12923aa30>,
#  <IO.Sentence at 0x12923aee0>,
#  <IO.Sentence at 0x1292441f0>,
#  <IO.Sentence at 0x129244640>,
#  <IO.Sentence at 0x129244880>,
#  <IO.Sentence at 0x129244d00>,
#  <IO.Sentence at 0x12924c280>,
#  <IO.Sentence at 0x12924c3a0>,
#  <IO.Sentence at 0x12924cc10>,
#  <IO.Sentence at 0x12924cfd0>,
#  <IO.Sentence at 0x129256400>,
#  <IO.Sentence at 0x1292566a0>,
#  <IO.Sentence at 0x129256a00>,
#  <IO.Sentence at 0x129256c10>,
#  <IO.Sentence at 0x129256ee0>,
#  <IO.Sentence at 0x12925d5b0>,
#  <IO.Sentence at 0x12925da00>,
#  <IO.Sentence at 0x12925db20>,
#  <IO.Sentence at 0x129267100>,
#  <IO.Sentence at 0x129267430>,
#  <IO.Sentence at 0x129267790>,
#  <IO.Sentence at 0x129267af0>,
#  <IO.Sentence at 0x129267df0>,
#  <IO.Sentence at 0x12926e280>,
#  <IO.Sentence at 0x12926e610>,
#  <IO.Sentence at 0x12926eaf0>,
#  <IO.Sentence at 0x12926ecd0>,
#  <IO.Sentence at 0x129277100>,
#  ...]

# %%
model_en_5k.make_predictions(test_gold_data)

# %%
test_gold_data.sentences[0].tokens[1].x
# Out:
# '2'

# %%
for gold_sentence in test_gold_data.sentences:
    for token in gold_sentence.tokens:
        token.head = token.x
        token.x = "_"

# %%
test_gold_data.sentences[0].tokens[1].head
# Out:
# '2'

# %%
test_gold_writer = Writer(test_gold_path_en.split('/')[-1], test_gold_data.sentences)
test_gold_writer.write_file()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 test_gold_writer = Writer(test_gold_path-en.split('/')[-1], test_gold_data.sentences)
#       2 test_gold_writer.write_file()
#
# NameError: name 'test_gold_path' is not defined

# %%
writer = Writer(train_path_en.split('/')[-1], train_data_en_1k.sentences)
writer.write_file()

# %%
from difflib import Differ
 
with open(train_path_en) as file_1, open(train_path_en.split('/')[-1]+'.pred') as file_2:
    differ = Differ()
 
    for line in differ.compare(file_1.readlines(), file_2.readlines()):
        print(line)
