# %%
import numpy as np

# %%
train_path_en = "Treebanks/english/train/wsj_train.only-projective.first-1k.conll06"

# %%
train_path_en.split('/')[-1]
# Out:
# 'wsj_train.only-projective.first-1k.conll06'

# %%
class Token:
    
    def __init__(self):
        self.id = None
        self.form = None
        self.lemma = None
        self.pos = None
        self.xpos = None
        self.morph = None
        self.head = None
        self.deprel = None
        self.x = None
        self.y = None

# %%
class Sentence:
    
    def __init__(self, token_items):
        # create ROOT token
        root = Token()
        root.id = '0'
        root.form = 'ROOT'
        root.lemma = '_'
        root.pos = 'ROOT'
        root.xpos = '_'
        root.morph = '_'
        root.head = '_'
        root.deprel = '_'
        root.x = '_'
        root.y = '_'
        
        # initialize tokens with ROOT
        self.tokens = [root]
        
        # add each token in token_items to sentence
        for token in token_items:
            self.tokens.append(token)

# %%
class Reader:
    
    def __init__(self, filepath):
        self.filepath = filepath
        self.sentences = []
    
    def read_file(self):
        f = open(self.filepath)
        sentences = []
    
        # init token_items
        token_items = []
    
        for line in f:
            # init current sentence and token
            token = Token()
        
            # if not at end of sentence
            if line != '\n':
                items = line.split('\t')
                #print(items)
            
                # add token data
                token.id = items[0]
                token.form = items[1]
                token.lemma = items[2]
                token.pos = items[3]
                token.xpos = items[4]
                token.morph = items[5]
                token.head = items[6]
                token.deprel = items[7]
                token.x = items[8]
                token.y = items[9]
            
                # add Token to Sentence
                token_items.append(token)
        
            # add sentence and reset token_items
            else:
                sentences.append(Sentence(token_items))
                token_items = []
                
        f.close()
        self.sentences = sentences

# %%
class Writer:
    
    def __init__(self, filepath, sentences):
        self.filepath = filepath
        self.sentences = sentences
        
    def write_file(self):
        target_filename = self.filepath.split('/')[-1]
        with open(target_filename+'.pred', 'w') as f:
            for sentence in self.sentences:
                for token in sentence.tokens:
                    if token.form == 'ROOT':
                        continue
                    else:
                        line = ""
                        line+=token.id+'\t'
                        line+=token.form+'\t'
                        line+=token.lemma+'\t'
                        line+=token.pos+'\t'
                        line+=token.xpos+'\t'
                        line+=token.morph+'\t'
                        line+=token.head+'\t'
                        line+=token.deprel+'\t'
                        line+=token.x+'\t'
                        line+=token.y
                    
                        f.write(str(line))
                f.write('\n')
            f.close()

# %%
train_1k_sentences = Reader(train_path_en)
train_1k_sentences.read_file()
train_1k_sentences.sentences
# Out:
# [<__main__.Sentence at 0x1116cddf0>,
#  <__main__.Sentence at 0x1116cf2b0>,
#  <__main__.Sentence at 0x1116cf5e0>,
#  <__main__.Sentence at 0x1116cf9a0>,
#  <__main__.Sentence at 0x1116cfbb0>,
#  <__main__.Sentence at 0x1107dffa0>,
#  <__main__.Sentence at 0x1107df7c0>,
#  <__main__.Sentence at 0x1107dfdc0>,
#  <__main__.Sentence at 0x107728940>,
#  <__main__.Sentence at 0x1116e9430>,
#  <__main__.Sentence at 0x1116e9b50>,
#  <__main__.Sentence at 0x1116f4310>,
#  <__main__.Sentence at 0x1116f46d0>,
#  <__main__.Sentence at 0x1116f4fa0>,
#  <__main__.Sentence at 0x1117002e0>,
#  <__main__.Sentence at 0x111700910>,
#  <__main__.Sentence at 0x1119083d0>,
#  <__main__.Sentence at 0x111908820>,
#  <__main__.Sentence at 0x111908c40>,
#  <__main__.Sentence at 0x111912040>,
#  <__main__.Sentence at 0x111912430>,
#  <__main__.Sentence at 0x1119129d0>,
#  <__main__.Sentence at 0x111912fd0>,
#  <__main__.Sentence at 0x11191d9a0>,
#  <__main__.Sentence at 0x11191ddc0>,
#  <__main__.Sentence at 0x111928400>,
#  <__main__.Sentence at 0x1119289d0>,
#  <__main__.Sentence at 0x111934100>,
#  <__main__.Sentence at 0x1119343a0>,
#  <__main__.Sentence at 0x111934c10>,
#  <__main__.Sentence at 0x11193f190>,
#  <__main__.Sentence at 0x11193f640>,
#  <__main__.Sentence at 0x11193fd60>,
#  <__main__.Sentence at 0x11194a490>,
#  <__main__.Sentence at 0x11194a820>,
#  <__main__.Sentence at 0x11194ab80>,
#  <__main__.Sentence at 0x111955130>,
#  <__main__.Sentence at 0x111955910>,
#  <__main__.Sentence at 0x111955bb0>,
#  <__main__.Sentence at 0x11195f190>,
#  <__main__.Sentence at 0x11195f520>,
#  <__main__.Sentence at 0x11195fac0>,
#  <__main__.Sentence at 0x11195fe50>,
#  <__main__.Sentence at 0x11196a130>,
#  <__main__.Sentence at 0x11196a6a0>,
#  <__main__.Sentence at 0x11196acd0>,
#  <__main__.Sentence at 0x111974610>,
#  <__main__.Sentence at 0x111974b50>,
#  <__main__.Sentence at 0x111980100>,
#  <__main__.Sentence at 0x1119805e0>,
#  <__main__.Sentence at 0x111980c10>,
#  <__main__.Sentence at 0x11198b070>,
#  <__main__.Sentence at 0x11198b4c0>,
#  <__main__.Sentence at 0x11198bbe0>,
#  <__main__.Sentence at 0x11198be80>,
#  <__main__.Sentence at 0x111995670>,
#  <__main__.Sentence at 0x111995bb0>,
#  <__main__.Sentence at 0x1119a15b0>,
#  <__main__.Sentence at 0x1119a1af0>,
#  <__main__.Sentence at 0x1119a1e50>,
#  <__main__.Sentence at 0x1119ac4c0>,
#  <__main__.Sentence at 0x1119ac880>,
#  <__main__.Sentence at 0x1119acd60>,
#  <__main__.Sentence at 0x1119b8490>,
#  <__main__.Sentence at 0x1119b8af0>,
#  <__main__.Sentence at 0x1119c20a0>,
#  <__main__.Sentence at 0x1119c2790>,
#  <__main__.Sentence at 0x1119c2ca0>,
#  <__main__.Sentence at 0x1119ce490>,
#  <__main__.Sentence at 0x1119ceb50>,
#  <__main__.Sentence at 0x1119cefd0>,
#  <__main__.Sentence at 0x1119d9670>,
#  <__main__.Sentence at 0x1119d9cd0>,
#  <__main__.Sentence at 0x1119e43d0>,
#  <__main__.Sentence at 0x1119e48e0>,
#  <__main__.Sentence at 0x1119e4eb0>,
#  <__main__.Sentence at 0x1119f02b0>,
#  <__main__.Sentence at 0x1119f0af0>,
#  <__main__.Sentence at 0x1119fa130>,
#  <__main__.Sentence at 0x1119fa640>,
#  <__main__.Sentence at 0x1119faac0>,
#  <__main__.Sentence at 0x111a050d0>,
#  <__main__.Sentence at 0x111a05520>,
#  <__main__.Sentence at 0x111af3af0>,
#  <__main__.Sentence at 0x111af3dc0>,
#  <__main__.Sentence at 0x111afe370>,
#  <__main__.Sentence at 0x111afe700>,
#  <__main__.Sentence at 0x111afeb80>,
#  <__main__.Sentence at 0x111b083d0>,
#  <__main__.Sentence at 0x111b08880>,
#  <__main__.Sentence at 0x111b14070>,
#  <__main__.Sentence at 0x111b143d0>,
#  <__main__.Sentence at 0x111b14970>,
#  <__main__.Sentence at 0x111b14af0>,
#  <__main__.Sentence at 0x111b14c40>,
#  <__main__.Sentence at 0x111b14f70>,
#  <__main__.Sentence at 0x111b1d490>,
#  <__main__.Sentence at 0x111b1d610>,
#  <__main__.Sentence at 0x111b1dc70>,
#  <__main__.Sentence at 0x111b28130>,
#  <__main__.Sentence at 0x111b283a0>,
#  <__main__.Sentence at 0x111b287c0>,
#  <__main__.Sentence at 0x111b28bb0>,
#  <__main__.Sentence at 0x111b28d00>,
#  <__main__.Sentence at 0x111b28ee0>,
#  <__main__.Sentence at 0x111b30220>,
#  <__main__.Sentence at 0x111b30880>,
#  <__main__.Sentence at 0x111b30dc0>,
#  <__main__.Sentence at 0x111b3b160>,
#  <__main__.Sentence at 0x111b3b3d0>,
#  <__main__.Sentence at 0x111b3b550>,
#  <__main__.Sentence at 0x111b3ba30>,
#  <__main__.Sentence at 0x111b3beb0>,
#  <__main__.Sentence at 0x111b444c0>,
#  <__main__.Sentence at 0x111b44a30>,
#  <__main__.Sentence at 0x111b44c10>,
#  <__main__.Sentence at 0x111b44dc0>,
#  <__main__.Sentence at 0x111b4f130>,
#  <__main__.Sentence at 0x111b4f2b0>,
#  <__main__.Sentence at 0x111b4f550>,
#  <__main__.Sentence at 0x111b4f8e0>,
#  <__main__.Sentence at 0x111b4fa60>,
#  <__main__.Sentence at 0x111b4fee0>,
#  <__main__.Sentence at 0x111b57670>,
#  <__main__.Sentence at 0x111b57af0>,
#  <__main__.Sentence at 0x111b64160>,
#  <__main__.Sentence at 0x111b64430>,
#  <__main__.Sentence at 0x111b64ac0>,
#  <__main__.Sentence at 0x111b64f10>,
#  <__main__.Sentence at 0x111b6d2b0>,
#  <__main__.Sentence at 0x111b6d8e0>,
#  <__main__.Sentence at 0x111b78040>,
#  <__main__.Sentence at 0x111b781f0>,
#  <__main__.Sentence at 0x111b786d0>,
#  <__main__.Sentence at 0x111b788b0>,
#  <__main__.Sentence at 0x111b78be0>,
#  <__main__.Sentence at 0x111b81130>,
#  <__main__.Sentence at 0x111b814f0>,
#  <__main__.Sentence at 0x111b81760>,
#  <__main__.Sentence at 0x111b81910>,
#  <__main__.Sentence at 0x111b81c70>,
#  <__main__.Sentence at 0x111b81ee0>,
#  <__main__.Sentence at 0x111b8b1c0>,
#  <__main__.Sentence at 0x111b8bd60>,
#  <__main__.Sentence at 0x111b964c0>,
#  <__main__.Sentence at 0x111b96ac0>,
#  <__main__.Sentence at 0x111ba00d0>,
#  <__main__.Sentence at 0x111ba02b0>,
#  <__main__.Sentence at 0x111ba0760>,
#  <__main__.Sentence at 0x111ba0e20>,
#  <__main__.Sentence at 0x111bab190>,
#  <__main__.Sentence at 0x111babe20>,
#  <__main__.Sentence at 0x111bb54f0>,
#  <__main__.Sentence at 0x111bb5970>,
#  <__main__.Sentence at 0x111bb5e80>,
#  <__main__.Sentence at 0x111bc0220>,
#  <__main__.Sentence at 0x111bc0be0>,
#  <__main__.Sentence at 0x111bca160>,
#  <__main__.Sentence at 0x111bca670>,
#  <__main__.Sentence at 0x111bca820>,
#  <__main__.Sentence at 0x111bd5220>,
#  <__main__.Sentence at 0x111bd53d0>,
#  <__main__.Sentence at 0x111bd5610>,
#  <__main__.Sentence at 0x111bd5a60>,
#  <__main__.Sentence at 0x111bdf190>,
#  <__main__.Sentence at 0x111bdf4c0>,
#  <__main__.Sentence at 0x111bdf820>,
#  <__main__.Sentence at 0x111bdfb80>,
#  <__main__.Sentence at 0x111bdfdf0>,
#  <__main__.Sentence at 0x111be9340>,
#  <__main__.Sentence at 0x111be9700>,
#  <__main__.Sentence at 0x111be9c70>,
#  <__main__.Sentence at 0x111be9fd0>,
#  <__main__.Sentence at 0x111bf35b0>,
#  <__main__.Sentence at 0x111bf3b50>,
#  <__main__.Sentence at 0x111bfe2b0>,
#  <__main__.Sentence at 0x111bfe760>,
#  <__main__.Sentence at 0x111bfea60>,
#  <__main__.Sentence at 0x111c093a0>,
#  <__main__.Sentence at 0x111c099a0>,
#  <__main__.Sentence at 0x111c09d30>,
#  <__main__.Sentence at 0x111c09f40>,
#  <__main__.Sentence at 0x111c13a30>,
#  <__main__.Sentence at 0x111c1f0a0>,
#  <__main__.Sentence at 0x111c1f5b0>,
#  <__main__.Sentence at 0x111c1fa90>,
#  <__main__.Sentence at 0x111c1fcd0>,
#  <__main__.Sentence at 0x111c1ffd0>,
#  <__main__.Sentence at 0x111c28550>,
#  <__main__.Sentence at 0x111c28af0>,
#  <__main__.Sentence at 0x111c28f40>,
#  <__main__.Sentence at 0x111c33490>,
#  <__main__.Sentence at 0x111c33a00>,
#  <__main__.Sentence at 0x111c33d30>,
#  <__main__.Sentence at 0x111c33f10>,
#  <__main__.Sentence at 0x111c3c310>,
#  <__main__.Sentence at 0x111c3c820>,
#  <__main__.Sentence at 0x111c3cd00>,
#  <__main__.Sentence at 0x111c47250>,
#  <__main__.Sentence at 0x111c47850>,
#  <__main__.Sentence at 0x111c47f10>,
#  <__main__.Sentence at 0x111c52790>,
#  <__main__.Sentence at 0x111c52e20>,
#  <__main__.Sentence at 0x111c5d3d0>,
#  <__main__.Sentence at 0x111c5d610>,
#  <__main__.Sentence at 0x111c5da60>,
#  <__main__.Sentence at 0x111c5dd90>,
#  <__main__.Sentence at 0x111c682e0>,
#  <__main__.Sentence at 0x111c68940>,
#  <__main__.Sentence at 0x111c68bb0>,
#  <__main__.Sentence at 0x111c720a0>,
#  <__main__.Sentence at 0x111c72730>,
#  <__main__.Sentence at 0x111c72d90>,
#  <__main__.Sentence at 0x111c7d2b0>,
#  <__main__.Sentence at 0x111c7da60>,
#  <__main__.Sentence at 0x111c88040>,
#  <__main__.Sentence at 0x111c88550>,
#  <__main__.Sentence at 0x111c88940>,
#  <__main__.Sentence at 0x111c88ee0>,
#  <__main__.Sentence at 0x111c92490>,
#  <__main__.Sentence at 0x111c92e50>,
#  <__main__.Sentence at 0x111c9d400>,
#  <__main__.Sentence at 0x111c9d7c0>,
#  <__main__.Sentence at 0x111c9db50>,
#  <__main__.Sentence at 0x111ca8100>,
#  <__main__.Sentence at 0x111ca87f0>,
#  <__main__.Sentence at 0x111ca8c10>,
#  <__main__.Sentence at 0x111cb31c0>,
#  <__main__.Sentence at 0x111cb35e0>,
#  <__main__.Sentence at 0x111cb3a60>,
#  <__main__.Sentence at 0x111cb3eb0>,
#  <__main__.Sentence at 0x111cbd220>,
#  <__main__.Sentence at 0x111cbd8e0>,
#  <__main__.Sentence at 0x111cbdca0>,
#  <__main__.Sentence at 0x111cc8280>,
#  <__main__.Sentence at 0x111cc8760>,
#  <__main__.Sentence at 0x111cc89d0>,
#  <__main__.Sentence at 0x111cc8f40>,
#  <__main__.Sentence at 0x111cd2370>,
#  <__main__.Sentence at 0x111cd27c0>,
#  <__main__.Sentence at 0x111cd2a90>,
#  <__main__.Sentence at 0x111cd2f40>,
#  <__main__.Sentence at 0x111cdd430>,
#  <__main__.Sentence at 0x111cdd8b0>,
#  <__main__.Sentence at 0x111cddc70>,
#  <__main__.Sentence at 0x111ce7100>,
#  <__main__.Sentence at 0x111ce7400>,
#  <__main__.Sentence at 0x111ce7af0>,
#  <__main__.Sentence at 0x111cf22b0>,
#  <__main__.Sentence at 0x111cf2700>,
#  <__main__.Sentence at 0x111cf2e50>,
#  <__main__.Sentence at 0x111cfc8b0>,
#  <__main__.Sentence at 0x111cfcc70>,
#  <__main__.Sentence at 0x111cfcf10>,
#  <__main__.Sentence at 0x111d08130>,
#  <__main__.Sentence at 0x111d085b0>,
#  <__main__.Sentence at 0x1106f2310>,
#  <__main__.Sentence at 0x111d126d0>,
#  <__main__.Sentence at 0x111d129d0>,
#  <__main__.Sentence at 0x111d1a100>,
#  <__main__.Sentence at 0x111d1a400>,
#  <__main__.Sentence at 0x111d1aa30>,
#  <__main__.Sentence at 0x111d1acd0>,
#  <__main__.Sentence at 0x111d240d0>,
#  <__main__.Sentence at 0x111d24310>,
#  <__main__.Sentence at 0x111d24760>,
#  <__main__.Sentence at 0x111d249a0>,
#  <__main__.Sentence at 0x111d24b50>,
#  <__main__.Sentence at 0x111d24d60>,
#  <__main__.Sentence at 0x111d2c460>,
#  <__main__.Sentence at 0x111d2c850>,
#  <__main__.Sentence at 0x111d39070>,
#  <__main__.Sentence at 0x111d396d0>,
#  <__main__.Sentence at 0x111d39e20>,
#  <__main__.Sentence at 0x111d45730>,
#  <__main__.Sentence at 0x111d45d00>,
#  <__main__.Sentence at 0x111d45e20>,
#  <__main__.Sentence at 0x111d4f0a0>,
#  <__main__.Sentence at 0x111d4f430>,
#  <__main__.Sentence at 0x111d4f5e0>,
#  <__main__.Sentence at 0x111d4fd30>,
#  <__main__.Sentence at 0x111d4ff10>,
#  <__main__.Sentence at 0x111d593a0>,
#  <__main__.Sentence at 0x111e564f0>,
#  <__main__.Sentence at 0x111e56910>,
#  <__main__.Sentence at 0x111e56d60>,
#  <__main__.Sentence at 0x111e60250>,
#  <__main__.Sentence at 0x111e60550>,
#  <__main__.Sentence at 0x111e60c70>,
#  <__main__.Sentence at 0x111e60fd0>,
#  <__main__.Sentence at 0x111e6b4f0>,
#  <__main__.Sentence at 0x111e6b9d0>,
#  <__main__.Sentence at 0x111e6be20>,
#  <__main__.Sentence at 0x111e76220>,
#  <__main__.Sentence at 0x111e76880>,
#  <__main__.Sentence at 0x111e76c10>,
#  <__main__.Sentence at 0x111e81430>,
#  <__main__.Sentence at 0x111e817f0>,
#  <__main__.Sentence at 0x111e81e80>,
#  <__main__.Sentence at 0x111e8b670>,
#  <__main__.Sentence at 0x111e8ba30>,
#  <__main__.Sentence at 0x111e8bdf0>,
#  <__main__.Sentence at 0x111e96340>,
#  <__main__.Sentence at 0x111e969d0>,
#  <__main__.Sentence at 0x111e96df0>,
#  <__main__.Sentence at 0x111ea0130>,
#  <__main__.Sentence at 0x111ea0790>,
#  <__main__.Sentence at 0x111eac190>,
#  <__main__.Sentence at 0x111eaca90>,
#  <__main__.Sentence at 0x111eb9220>,
#  <__main__.Sentence at 0x111eb9790>,
#  <__main__.Sentence at 0x111eb9b50>,
#  <__main__.Sentence at 0x111ec3280>,
#  <__main__.Sentence at 0x111ec3730>,
#  <__main__.Sentence at 0x111ec3ac0>,
#  <__main__.Sentence at 0x111ec3f40>,
#  <__main__.Sentence at 0x111ece6d0>,
#  <__main__.Sentence at 0x111eced90>,
#  <__main__.Sentence at 0x111ed93a0>,
#  <__main__.Sentence at 0x111ed9cd0>,
#  <__main__.Sentence at 0x111ee5520>,
#  <__main__.Sentence at 0x111ee59a0>,
#  <__main__.Sentence at 0x111ee5f10>,
#  <__main__.Sentence at 0x111eef400>,
#  <__main__.Sentence at 0x111eef4f0>,
#  <__main__.Sentence at 0x111eef5e0>,
#  <__main__.Sentence at 0x111eef6d0>,
#  <__main__.Sentence at 0x111eef790>,
#  <__main__.Sentence at 0x111eefeb0>,
#  <__main__.Sentence at 0x111ef9550>,
#  <__main__.Sentence at 0x111ef9970>,
#  <__main__.Sentence at 0x111f05130>,
#  <__main__.Sentence at 0x111f05790>,
#  <__main__.Sentence at 0x111f10040>,
#  <__main__.Sentence at 0x111f10820>,
#  <__main__.Sentence at 0x111f10f10>,
#  <__main__.Sentence at 0x111f1b760>,
#  <__main__.Sentence at 0x111f1bdf0>,
#  <__main__.Sentence at 0x111f26580>,
#  <__main__.Sentence at 0x111f268b0>,
#  <__main__.Sentence at 0x111f26be0>,
#  <__main__.Sentence at 0x111f319a0>,
#  <__main__.Sentence at 0x111f31fd0>,
#  <__main__.Sentence at 0x111f3c250>,
#  <__main__.Sentence at 0x111f3c4c0>,
#  <__main__.Sentence at 0x111f3cbe0>,
#  <__main__.Sentence at 0x111f46430>,
#  <__main__.Sentence at 0x111f46cd0>,
#  <__main__.Sentence at 0x111f52460>,
#  <__main__.Sentence at 0x111f52670>,
#  <__main__.Sentence at 0x111f52e20>,
#  <__main__.Sentence at 0x111f5c220>,
#  <__main__.Sentence at 0x111f68c10>,
#  <__main__.Sentence at 0x111f73430>,
#  <__main__.Sentence at 0x111f738b0>,
#  <__main__.Sentence at 0x111f73df0>,
#  <__main__.Sentence at 0x111f7f130>,
#  <__main__.Sentence at 0x111f7f880>,
#  <__main__.Sentence at 0x111f7fcd0>,
#  <__main__.Sentence at 0x111f8a280>,
#  <__main__.Sentence at 0x111f8a850>,
#  <__main__.Sentence at 0x111f8aee0>,
#  <__main__.Sentence at 0x111f94370>,
#  <__main__.Sentence at 0x111f94b20>,
#  <__main__.Sentence at 0x111fa01f0>,
#  <__main__.Sentence at 0x111fa0940>,
#  <__main__.Sentence at 0x111fa0c40>,
#  <__main__.Sentence at 0x111faa1c0>,
#  <__main__.Sentence at 0x111faa3d0>,
#  <__main__.Sentence at 0x111faaa00>,
#  <__main__.Sentence at 0x111faadf0>,
#  <__main__.Sentence at 0x111fb6460>,
#  <__main__.Sentence at 0x111fb6b50>,
#  <__main__.Sentence at 0x111fb6d90>,
#  <__main__.Sentence at 0x111fc05b0>,
#  <__main__.Sentence at 0x111fc09d0>,
#  <__main__.Sentence at 0x111fc0c70>,
#  <__main__.Sentence at 0x111fcb0a0>,
#  <__main__.Sentence at 0x111fcb580>,
#  <__main__.Sentence at 0x111fcb940>,
#  <__main__.Sentence at 0x111fcbdc0>,
#  <__main__.Sentence at 0x111fd6190>,
#  <__main__.Sentence at 0x111fd6820>,
#  <__main__.Sentence at 0x111fd6e50>,
#  <__main__.Sentence at 0x111fe10a0>,
#  <__main__.Sentence at 0x111fe17f0>,
#  <__main__.Sentence at 0x111fe1a00>,
#  <__main__.Sentence at 0x111fe1c70>,
#  <__main__.Sentence at 0x111feb340>,
#  <__main__.Sentence at 0x111feb550>,
#  <__main__.Sentence at 0x111feb7c0>,
#  <__main__.Sentence at 0x111febb50>,
#  <__main__.Sentence at 0x111ff4040>,
#  <__main__.Sentence at 0x111ff41c0>,
#  <__main__.Sentence at 0x111ff46a0>,
#  <__main__.Sentence at 0x111ff4b50>,
#  <__main__.Sentence at 0x111fff040>,
#  <__main__.Sentence at 0x111fff730>,
#  <__main__.Sentence at 0x111fffe80>,
#  <__main__.Sentence at 0x11200a670>,
#  <__main__.Sentence at 0x11200aee0>,
#  <__main__.Sentence at 0x112016160>,
#  <__main__.Sentence at 0x1120166a0>,
#  <__main__.Sentence at 0x112016d00>,
#  <__main__.Sentence at 0x112020340>,
#  <__main__.Sentence at 0x112020850>,
#  <__main__.Sentence at 0x112020fa0>,
#  <__main__.Sentence at 0x11202c700>,
#  <__main__.Sentence at 0x11202caf0>,
#  <__main__.Sentence at 0x112036160>,
#  <__main__.Sentence at 0x1120363a0>,
#  <__main__.Sentence at 0x1120369d0>,
#  <__main__.Sentence at 0x112041250>,
#  <__main__.Sentence at 0x112041460>,
#  <__main__.Sentence at 0x1120416a0>,
#  <__main__.Sentence at 0x112041d90>,
#  <__main__.Sentence at 0x11204d130>,
#  <__main__.Sentence at 0x11204d730>,
#  <__main__.Sentence at 0x11204de20>,
#  <__main__.Sentence at 0x112058370>,
#  <__main__.Sentence at 0x112058610>,
#  <__main__.Sentence at 0x112058bb0>,
#  <__main__.Sentence at 0x112058d60>,
#  <__main__.Sentence at 0x112058f70>,
#  <__main__.Sentence at 0x112063550>,
#  <__main__.Sentence at 0x112063820>,
#  <__main__.Sentence at 0x112063cd0>,
#  <__main__.Sentence at 0x11206d070>,
#  <__main__.Sentence at 0x11206d4f0>,
#  <__main__.Sentence at 0x11206d6a0>,
#  <__main__.Sentence at 0x11206dbe0>,
#  <__main__.Sentence at 0x11206de80>,
#  <__main__.Sentence at 0x112077100>,
#  <__main__.Sentence at 0x112077790>,
#  <__main__.Sentence at 0x112077df0>,
#  <__main__.Sentence at 0x112081220>,
#  <__main__.Sentence at 0x112081730>,
#  <__main__.Sentence at 0x112081a60>,
#  <__main__.Sentence at 0x112081fa0>,
#  <__main__.Sentence at 0x11208d5e0>,
#  <__main__.Sentence at 0x11208db50>,
#  <__main__.Sentence at 0x1120971f0>,
#  <__main__.Sentence at 0x112097730>,
#  <__main__.Sentence at 0x1120a31c0>,
#  <__main__.Sentence at 0x1120a3490>,
#  <__main__.Sentence at 0x1120a3b80>,
#  <__main__.Sentence at 0x1120ae0d0>,
#  <__main__.Sentence at 0x1120ae3a0>,
#  <__main__.Sentence at 0x1120ae8e0>,
#  <__main__.Sentence at 0x1120b90d0>,
#  <__main__.Sentence at 0x1120b9820>,
#  <__main__.Sentence at 0x1120b9ac0>,
#  <__main__.Sentence at 0x1120c4100>,
#  <__main__.Sentence at 0x1120c48b0>,
#  <__main__.Sentence at 0x1120c4cd0>,
#  <__main__.Sentence at 0x1120cd0d0>,
#  <__main__.Sentence at 0x1120cd520>,
#  <__main__.Sentence at 0x1120cd880>,
#  <__main__.Sentence at 0x1120cdbe0>,
#  <__main__.Sentence at 0x1120d8790>,
#  <__main__.Sentence at 0x1120d8d60>,
#  <__main__.Sentence at 0x1120e33d0>,
#  <__main__.Sentence at 0x1120e37f0>,
#  <__main__.Sentence at 0x1120e3c70>,
#  <__main__.Sentence at 0x1120ee0a0>,
#  <__main__.Sentence at 0x1120ee5e0>,
#  <__main__.Sentence at 0x1120eeca0>,
#  <__main__.Sentence at 0x1120f95b0>,
#  <__main__.Sentence at 0x1120f99a0>,
#  <__main__.Sentence at 0x1120f9fa0>,
#  <__main__.Sentence at 0x1121044f0>,
#  <__main__.Sentence at 0x1121048b0>,
#  <__main__.Sentence at 0x11210f340>,
#  <__main__.Sentence at 0x11210f670>,
#  <__main__.Sentence at 0x11210fd00>,
#  <__main__.Sentence at 0x11211a670>,
#  <__main__.Sentence at 0x11211ae20>,
#  <__main__.Sentence at 0x1121262e0>,
#  <__main__.Sentence at 0x112126580>,
#  <__main__.Sentence at 0x112126b80>,
#  <__main__.Sentence at 0x112126f70>,
#  <__main__.Sentence at 0x112131400>,
#  <__main__.Sentence at 0x112131a30>,
#  <__main__.Sentence at 0x11213e370>,
#  <__main__.Sentence at 0x11213edf0>,
#  <__main__.Sentence at 0x11225c670>,
#  <__main__.Sentence at 0x11225c8b0>,
#  <__main__.Sentence at 0x11225ca30>,
#  <__main__.Sentence at 0x112266040>,
#  <__main__.Sentence at 0x112266400>,
#  <__main__.Sentence at 0x1122668b0>,
#  <__main__.Sentence at 0x112266f40>,
#  <__main__.Sentence at 0x1122715b0>,
#  <__main__.Sentence at 0x112271880>,
#  <__main__.Sentence at 0x112271d90>,
#  <__main__.Sentence at 0x11227a130>,
#  <__main__.Sentence at 0x11227a6a0>,
#  <__main__.Sentence at 0x11227aa60>,
#  <__main__.Sentence at 0x11227afa0>,
#  <__main__.Sentence at 0x112286400>,
#  <__main__.Sentence at 0x1122867c0>,
#  <__main__.Sentence at 0x112286ee0>,
#  <__main__.Sentence at 0x1122907c0>,
#  <__main__.Sentence at 0x11229d130>,
#  <__main__.Sentence at 0x11229d490>,
#  <__main__.Sentence at 0x11229dbb0>,
#  <__main__.Sentence at 0x11229dee0>,
#  <__main__.Sentence at 0x1122a8610>,
#  <__main__.Sentence at 0x1122a8c10>,
#  <__main__.Sentence at 0x1122b2130>,
#  <__main__.Sentence at 0x1122b25b0>,
#  <__main__.Sentence at 0x1122b2b20>,
#  <__main__.Sentence at 0x1122b2d30>,
#  <__main__.Sentence at 0x1122bd0d0>,
#  <__main__.Sentence at 0x1122bd910>,
#  <__main__.Sentence at 0x1122bde50>,
#  <__main__.Sentence at 0x1122c71c0>,
#  <__main__.Sentence at 0x1122c78b0>,
#  <__main__.Sentence at 0x1122c7af0>,
#  <__main__.Sentence at 0x1122d30a0>,
#  <__main__.Sentence at 0x1122d3220>,
#  <__main__.Sentence at 0x1122d3af0>,
#  <__main__.Sentence at 0x1122dd100>,
#  <__main__.Sentence at 0x1122dd700>,
#  <__main__.Sentence at 0x1122dd850>,
#  <__main__.Sentence at 0x1122ea160>,
#  <__main__.Sentence at 0x1122ea520>,
#  <__main__.Sentence at 0x1122eaa90>,
#  <__main__.Sentence at 0x1122eadc0>,
#  <__main__.Sentence at 0x1122f4370>,
#  <__main__.Sentence at 0x1122f47f0>,
#  <__main__.Sentence at 0x1122f4b20>,
#  <__main__.Sentence at 0x1122f4f10>,
#  <__main__.Sentence at 0x1122ff3d0>,
#  <__main__.Sentence at 0x1122ff700>,
#  <__main__.Sentence at 0x1122ffca0>,
#  <__main__.Sentence at 0x1122fff70>,
#  <__main__.Sentence at 0x1123095e0>,
#  <__main__.Sentence at 0x112309ee0>,
#  <__main__.Sentence at 0x1123140d0>,
#  <__main__.Sentence at 0x1123141f0>,
#  <__main__.Sentence at 0x112314bb0>,
#  <__main__.Sentence at 0x112314f70>,
#  <__main__.Sentence at 0x11231e8e0>,
#  <__main__.Sentence at 0x11232a0a0>,
#  <__main__.Sentence at 0x11232a1c0>,
#  <__main__.Sentence at 0x11232abb0>,
#  <__main__.Sentence at 0x11232af70>,
#  <__main__.Sentence at 0x112335130>,
#  <__main__.Sentence at 0x112335850>,
#  <__main__.Sentence at 0x112335be0>,
#  <__main__.Sentence at 0x11233f4c0>,
#  <__main__.Sentence at 0x11252ff40>,
#  <__main__.Sentence at 0x112539670>,
#  <__main__.Sentence at 0x112539c10>,
#  <__main__.Sentence at 0x112544310>,
#  <__main__.Sentence at 0x112544c70>,
#  <__main__.Sentence at 0x112550730>,
#  <__main__.Sentence at 0x112550af0>,
#  <__main__.Sentence at 0x112550fa0>,
#  <__main__.Sentence at 0x11255b640>,
#  <__main__.Sentence at 0x11255bbe0>,
#  <__main__.Sentence at 0x112566490>,
#  <__main__.Sentence at 0x112566d90>,
#  <__main__.Sentence at 0x112571130>,
#  <__main__.Sentence at 0x1125715b0>,
#  <__main__.Sentence at 0x112571bb0>,
#  <__main__.Sentence at 0x11257c130>,
#  <__main__.Sentence at 0x11257c4f0>,
#  <__main__.Sentence at 0x11257ce80>,
#  <__main__.Sentence at 0x1125884c0>,
#  <__main__.Sentence at 0x112588b50>,
#  <__main__.Sentence at 0x112593490>,
#  <__main__.Sentence at 0x1125a00d0>,
#  <__main__.Sentence at 0x1125a0730>,
#  <__main__.Sentence at 0x1125a0e20>,
#  <__main__.Sentence at 0x1125aa8e0>,
#  <__main__.Sentence at 0x1125aaf10>,
#  <__main__.Sentence at 0x1125b67c0>,
#  <__main__.Sentence at 0x1125b6cd0>,
#  <__main__.Sentence at 0x1125c13d0>,
#  <__main__.Sentence at 0x1125c1b20>,
#  <__main__.Sentence at 0x1125cd070>,
#  <__main__.Sentence at 0x1125cd6a0>,
#  <__main__.Sentence at 0x1125cdeb0>,
#  <__main__.Sentence at 0x1125d9220>,
#  <__main__.Sentence at 0x1125d9460>,
#  <__main__.Sentence at 0x1125d9a30>,
#  <__main__.Sentence at 0x1125e30d0>,
#  <__main__.Sentence at 0x1125e3370>,
#  <__main__.Sentence at 0x1125e3820>,
#  <__main__.Sentence at 0x1125e3dc0>,
#  <__main__.Sentence at 0x1125ee250>,
#  <__main__.Sentence at 0x1125ee670>]

# %%
from difflib import Differ
 
with open(train_path_en) as file_1, open(train_path_en.split('/')[-1]+'.pred') as file_2:
    differ = Differ()
 
    for line in differ.compare(file_1.readlines(), file_2.readlines()):
        print(line)

# %% [markdown]
# # Evaluation

# %% [markdown]
# # Decoder (Eisner's Algorithm)

# %%
test_matrix = np.array([[-10000, 9, 10, 9], 
               [-10000, -10000, 20, 3], 
               [-10000, 30, -10000, 30],
               [-10000, 11, 0, -10000]])

# %%
# Some constants
L, R = 0, 1
I, C = 0, 1
DIRECTIONS = (L, R)
COMPLETENESS = (I, C)
NEG_INF = -float('inf')


class Span(object):
    def __init__(self, left_idx, right_idx, head_side, complete):
        self.data = (left_idx, right_idx, head_side, complete)

    @property
    def left_idx(self):
        return self.data[0]

    @property
    def right_idx(self):
        return self.data[1]

    @property
    def head_side(self):
        return self.data[2]

    @property
    def complete(self):
        return self.data[3]

    def __str__(self):
        return "({}, {}, {}, {})".format(
            self.left_idx,
            self.right_idx,
            "L" if self.head_side == L else "R",
            "C" if self.complete == C else "I",
        )

    def __repr__(self):
        return self.__str__()

    def __hash__(self):
        return hash(self.data)

    def __eq__(self, other):
        return isinstance(other, Span) and hash(other) == hash(self)

# %%
def eisner(weight):
    """
    `N` denotes the length of sentence.

    :param weight: size N x N
    :return: the projective tree with maximum score
    """
    N = weight.shape[0]

    btp = {}  # Back-track pointer
    dp_s = {}

    # Init
    for i in range(N):
        for j in range(i + 1, N):
            for dir in DIRECTIONS:
                for comp in COMPLETENESS:
                    dp_s[Span(i, j, dir, comp)] = NEG_INF
    print(dp_s)

    # base case
    for i in range(N):
        for dir in DIRECTIONS:
            dp_s[Span(i, i, dir, C)] = 0.
            btp[Span(i, i, dir, C)] = None

    rules = [
        # span_shape_tuple := (span_direction, span_completeness),
        # rule := (span_shape, (left_subspan_shape, right_subspan_shape))
        ((L, I), ((R, C), (L, C))),
        ((R, I), ((R, C), (L, C))),
        ((L, C), ((L, C), (L, I))),
        ((R, C), ((R, I), (R, C))),
    ]

    for size in range(1, N):
        for i in range(0, N - size):
            j = i + size
            for rule in rules:
                ((dir, comp), ((l_dir, l_comp), (r_dir, r_comp))) = rule

                if comp == I:
                    edge_w = weight[i, j] if (dir == R) else weight[j, i]
                    k_start, k_end = (i, j)
                    offset = 1
                else:
                    edge_w = 0.
                    k_start, k_end = (i + 1, j + 1) if dir == R else (i, j)
                    offset = 0

                span = Span(i, j, dir, comp)
                for k in range(k_start, k_end):
                    l_span = Span(i, k, l_dir, l_comp)
                    r_span = Span(k + offset, j, r_dir, r_comp)
                    s = edge_w + dp_s[l_span] + dp_s[r_span]
                    if s > dp_s[span]:
                        dp_s[span] = s
                        btp[span] = (l_span, r_span)

    # recover tree
    return back_track(btp, Span(0, N - 1, R, C), set())


def back_track(btp, span, edge_set):
    if span.complete == I:
        if span.head_side == L:
            edge = (span.right_idx, span.left_idx)
        else:
            edge = (span.left_idx, span.right_idx)
        edge_set.add(edge)

    if btp[span] is not None:
        l_span, r_span = btp[span]

        back_track(btp, l_span, edge_set)
        back_track(btp, r_span, edge_set)
    else:
        return

    return edge_set

# %%
eisner(test_matrix)
# Out:
# {(0, 1, L, I): -inf, (0, 1, L, C): -inf, (0, 1, R, I): -inf, (0, 1, R, C): -inf, (0, 2, L, I): -inf, (0, 2, L, C): -inf, (0, 2, R, I): -inf, (0, 2, R, C): -inf, (0, 3, L, I): -inf, (0, 3, L, C): -inf, (0, 3, R, I): -inf, (0, 3, R, C): -inf, (1, 2, L, I): -inf, (1, 2, L, C): -inf, (1, 2, R, I): -inf, (1, 2, R, C): -inf, (1, 3, L, I): -inf, (1, 3, L, C): -inf, (1, 3, R, I): -inf, (1, 3, R, C): -inf, (2, 3, L, I): -inf, (2, 3, L, C): -inf, (2, 3, R, I): -inf, (2, 3, R, C): -inf}
# {(0, 2), (2, 1), (2, 3)}

# %%
test_list = []
test_list.append((2, 1))
test_list
# Out:
# [(2, 1)]

# %%
tree = []

def Eisner(edge_scores):
    # Get length of sentence
    #n = len(sentence.tokens)
    n=4
    
    # Initialize matrices with zeros
    O_r = np.zeros([n, n], dtype=int)
    O_l = np.zeros([n, n], dtype=int)
    C_r = np.zeros([n, n], dtype=int)
    C_l = np.zeros([n, n], dtype=int)
    
    # Initialize backtracking matrices
    b_table = [[None]*n]*n
    
    for m in np.arange(1, n):
        for s in np.arange(0, n-m):
            t = s+m
            
            # O_r
            q=s
            max_q_score = -10000; max_q = q
            while q < t:
                curr_q_score = C_l[s][q] + C_r[q+1][t] + edge_scores[t][s]
                #print("O_r step: " + str((C_l[s][q], C_r[q+1][t], edge_scores[t][s])))
                if curr_q_score > max_q_score:
                    max_q_score = curr_q_score; max_q = q
                q += 1
            #print("O_r max_q: " + str(max_q_score))
            O_r[s][t] = max_q_score; b_table[s][t] = (max_q, "Open", "R")
            
            # O_l
            q=s
            max_q_score = -10000; max_q = q
            while q < t:
                curr_q_score = C_l[s][q] + C_r[q+1][t] + edge_scores[s][t]
                #print("O_l step: " + str((C_l[s][q], C_r[q+1][t], edge_scores[s][t])))
                if curr_q_score > max_q_score:
                    max_q_score = curr_q_score; max_q = q
                q += 1
            #print("O_l max_q: " + str(max_q_score))
            O_l[s][t] = max_q_score; b_table[s][t] = (max_q, "Open", "L")
            
            # C_r
            q=s
            max_q_score = -10000; max_q = q
            while q < t:
                curr_q_score = C_r[s][q] + O_r[q][t]
                #print("C_r step: " + str((C_r[s][q], O_r[q][t])))
                if curr_q_score > max_q_score:
                    max_q_score = curr_q_score; max_q = q
                q += 1
            #print("C_r max_q: " + str(max_q_score))
            C_r[s][t] = max_q_score; b_table[s][t] = (max_q, "Closed", "R")
                
            # C_l
            q=s+1
            max_q_score = -10000; max_q = q
            while q <= t:
                curr_q_score = O_l[s][q] + C_l[q][t]
                #print("C_l step: " + str((O_l[s][q], C_l[q][t])))
                if curr_q_score > max_q_score:
                    max_q_score = curr_q_score; max_q = q
                q += 1
            #print("C_l max_q: " + str(max_q_score))
            C_l[s][t] = max_q_score; b_table[s][t] = (max_q, "Closed", "L")
            
            #print("s: " + str(s))
            #print("")

    print(O_r)
    print(O_l)
    print(C_r)
    print(C_l)
    print("")
    
    for line in b_table:
        print(line)
    
    d_index = np.argmax(C_l[0])
    tree.append((0, d_index))
    #return C_l
    #return backtrack(b_Or, b_Ol, b_Cr, b_Cl, 0, d_index, n)
    return C_l[0][n-1]

def backtrack(C_r, C_l, b_Cr, b_Cl, h_index, d_index, n):
    if h_index > d_index:
        direction = "L"
    else:
        direction = "R"
    for n in np.arange(0, n):
        if direction == "L":
            next_index = np.argmax(C_l[h_index])
            tree.append((h_index, next_index))
            h_index = b_Cl[h_index][next_index]
        else:
            next_index = np.argmax(C_r[h_index])
            h_index = b_Cr[h_index][next_index]

# %%
Eisner(test_matrix)
# Out:
# [[     0 -10000  -9970  -9960]
#  [     0      0     30     31]
#  [     0      0      0      0]
#  [     0      0      0      0]]
# [[ 0  9 40 49]
#  [ 0  0 20 23]
#  [ 0  0  0 30]
#  [ 0  0  0  0]]
# [[     0 -10000  -9970  -9960]
#  [     0      0     30     31]
#  [     0      0      0      0]
#  [     0      0      0      0]]
# [[ 0  9 40 70]
#  [ 0  0 20 50]
#  [ 0  0  0 30]
#  [ 0  0  0  0]]
#
# [None, (1, 'Closed', 'L'), (2, 'Closed', 'L'), (2, 'Closed', 'L')]
# [None, (1, 'Closed', 'L'), (2, 'Closed', 'L'), (2, 'Closed', 'L')]
# [None, (1, 'Closed', 'L'), (2, 'Closed', 'L'), (2, 'Closed', 'L')]
# [None, (1, 'Closed', 'L'), (2, 'Closed', 'L'), (2, 'Closed', 'L')]
# 70

# %% [markdown]
# # Feature Templates, Extraction, and Mapping

# %%
### Feature templates

unigram_features = ["hform, hpos", "hform", "hpos", "dform, dpos", "dform", "dpos"]
bigram_features = ["hform, hpos, dform, dpos", 
                   "hpos, dform, dpos", 
                   "hform, dform, dpos", 
                   "hform, hpos, dform", 
                   "hform, hpos, dpos", 
                   "hform, dform", 
                   "hpos, dpos"]

# Combine features with direction of edge and distance between head and dependent

# %%
test_sentence = train_1k_sentences.sentences[0]
vars(test_sentence.tokens[1])
# Out:
# {'id': '1',
#  'form': 'In',
#  'lemma': 'in',
#  'pos': 'IN',
#  'xpos': '_',
#  'morph': '_',
#  'head': '43',
#  'deprel': 'ADV',
#  'x': '_',
#  'y': '_\n'}

# %%
test_data = [test_sentence]
len(test_data[0].tokens)
# Out:
# 50

# %%
getattr(test_sentence.tokens[0], "form")
# Out:
# 'ROOT'

# %%
### Feature extraction
test_features = ["dform", "dpos", "dform, dpos"]

class FeatureMapping:
    
    '''
        IMPORTANT: m features for each n token
        AKA n*m feature vectors
        .map -> dictionary
            keys = feature_name, values = feature_vector_id
                ex. feature_name = 'hform=likes'
                    feature_vector_id = 1
    '''
    
    def __init__(self, features, sentences):
        self.sentences = sentences
        self.features = features
        self.feature_dict = {"dform": "form", "dpos": "pos", "dform, dpos": "form, pos"}
        self.map = {}
        self.vectors = {}
        self.frozen = False
    
    def arcs(self, sentence):
        '''
            arc_list = list of (head_int, token(dependency)_int) tuples
        '''
        arc_list = []
        for token in sentence.tokens:
            if token.form == "ROOT":
                continue
            else:
                arc_list.append((int(token.head), int(token.id)))
        return arc_list
    
    def create_mapping(self):
        i=0
        for sentence in self.sentences:
            sentence_arcs = self.arcs(sentence)
            #print(len(sentence_arcs))
            for arc in sentence_arcs:
                # Get current arc
                token = sentence.tokens[arc[1]]
                head = sentence.tokens[arc[0]]
                token_vector = []
                #print("feature: " + str(feature))
                #print("token: " + str(token.form))
                #print("head: " + str(head.form))
                for feature_name in self.features:
                    full_feature = feature_name+"="
                    if feature_name in ["dform", "dpos"]:
                        feature_val = getattr(token, feature_name[1:])
                        if feature_val == "_":
                            full_feature += "_NULL_"
                        else:
                            full_feature += feature_val
                    if feature_name == "dform, dpos":
                        form_val = "_NULL_" if token.form == "_" else token.form
                        pos_val = "_NULL_" if token.pos == "_" else token.pos
                        full_feature += form_val+"+"+pos_val
                    #print(full_feature, i)
                    #print("")
                    if full_feature not in self.map.keys():
                        self.map[full_feature] = i
                        token_vector.append(i)
                        i += 1
                self.vectors[token] = token_vector

# %%
test_mapping = FeatureMapping(test_features, test_data)
test_mapping.create_mapping()
test_mapping.map
# Out:
# {'dform=In': 0,
#  'dpos=IN': 1,
#  'dform, dpos=In+IN': 2,
#  'dform=an': 3,
#  'dpos=DT': 4,
#  'dform, dpos=an+DT': 5,
#  'dform=Oct.': 6,
#  'dpos=NNP': 7,
#  'dform, dpos=Oct.+NNP': 8,
#  'dform=19': 9,
#  'dpos=CD': 10,
#  'dform, dpos=19+CD': 11,
#  'dform=review': 12,
#  'dpos=NN': 13,
#  'dform, dpos=review+NN': 14,
#  'dform=of': 15,
#  'dform, dpos=of+IN': 16,
#  'dform=``': 17,
#  'dpos=``': 18,
#  'dform, dpos=``+``': 19,
#  'dform=The': 20,
#  'dform, dpos=The+DT': 21,
#  'dform=Misanthrope': 22,
#  'dform, dpos=Misanthrope+NN': 23,
#  "dform=''": 24,
#  "dpos=''": 25,
#  "dform, dpos=''+''": 26,
#  'dform=at': 27,
#  'dform, dpos=at+IN': 28,
#  'dform=Chicago': 29,
#  'dform, dpos=Chicago+NNP': 30,
#  "dform='s": 31,
#  'dpos=POS': 32,
#  "dform, dpos='s+POS": 33,
#  'dform=Goodman': 34,
#  'dform, dpos=Goodman+NNP': 35,
#  'dform=Theatre': 36,
#  'dform, dpos=Theatre+NNP': 37,
#  'dform=(': 38,
#  'dpos=-LRB-': 39,
#  'dform, dpos=(+-LRB-': 40,
#  'dform=Revitalized': 41,
#  'dpos=VBN': 42,
#  'dform, dpos=Revitalized+VBN': 43,
#  'dform=Classics': 44,
#  'dpos=NNS': 45,
#  'dform, dpos=Classics+NNS': 46,
#  'dform=Take': 47,
#  'dpos=VBP': 48,
#  'dform, dpos=Take+VBP': 49,
#  'dform=the': 50,
#  'dform, dpos=the+DT': 51,
#  'dform=Stage': 52,
#  'dform, dpos=Stage+NN': 53,
#  'dform=in': 54,
#  'dform, dpos=in+IN': 55,
#  'dform=Windy': 56,
#  'dform, dpos=Windy+NNP': 57,
#  'dform=City': 58,
#  'dform, dpos=City+NNP': 59,
#  'dform=,': 60,
#  'dpos=,': 61,
#  'dform, dpos=,+,': 62,
#  'dform=Leisure': 63,
#  'dform, dpos=Leisure+NN': 64,
#  'dform=&': 65,
#  'dpos=CC': 66,
#  'dform, dpos=&+CC': 67,
#  'dform=Arts': 68,
#  'dform, dpos=Arts+NNS': 69,
#  'dform=)': 70,
#  'dpos=-RRB-': 71,
#  'dform, dpos=)+-RRB-': 72,
#  'dform=role': 73,
#  'dform, dpos=role+NN': 74,
#  'dform=Celimene': 75,
#  'dform, dpos=Celimene+NNP': 76,
#  'dform=played': 77,
#  'dform, dpos=played+VBN': 78,
#  'dform=by': 79,
#  'dform, dpos=by+IN': 80,
#  'dform=Kim': 81,
#  'dform, dpos=Kim+NNP': 82,
#  'dform=Cattrall': 83,
#  'dform, dpos=Cattrall+NNP': 84,
#  'dform=was': 85,
#  'dpos=VBD': 86,
#  'dform, dpos=was+VBD': 87,
#  'dform=mistakenly': 88,
#  'dpos=RB': 89,
#  'dform, dpos=mistakenly+RB': 90,
#  'dform=attributed': 91,
#  'dform, dpos=attributed+VBN': 92,
#  'dform=to': 93,
#  'dform, dpos=to+IN': 94,
#  'dform=Christina': 95,
#  'dform, dpos=Christina+NNP': 96,
#  'dform=Haag': 97,
#  'dform, dpos=Haag+NNP': 98,
#  'dform=.': 99,
#  'dpos=.': 100,
#  'dform, dpos=.+.': 101}

# %% [markdown]
# # Feature Vector Representation

# %%
test_mapping.vectors
# Out:
# {<__main__.Token at 0x1077788b0>: [0, 1, 2],
#  <__main__.Token at 0x107778190>: [3, 4, 5],
#  <__main__.Token at 0x1077789d0>: [6, 7, 8],
#  <__main__.Token at 0x1107d45b0>: [9, 10, 11],
#  <__main__.Token at 0x10771ea60>: [12, 13, 14],
#  <__main__.Token at 0x10771ee80>: [15, 16],
#  <__main__.Token at 0x10771ec10>: [17, 18, 19],
#  <__main__.Token at 0x10771ec40>: [20, 21],
#  <__main__.Token at 0x1116cd880>: [22, 23],
#  <__main__.Token at 0x1116cd850>: [24, 25, 26],
#  <__main__.Token at 0x1116cdfd0>: [27, 28],
#  <__main__.Token at 0x1116cd8b0>: [29, 30],
#  <__main__.Token at 0x1116cd910>: [31, 32, 33],
#  <__main__.Token at 0x1116cd8e0>: [34, 35],
#  <__main__.Token at 0x1116cd2e0>: [36, 37],
#  <__main__.Token at 0x1116cd100>: [38, 39, 40],
#  <__main__.Token at 0x1116cd820>: [],
#  <__main__.Token at 0x1116cd580>: [41, 42, 43],
#  <__main__.Token at 0x1116cd730>: [44, 45, 46],
#  <__main__.Token at 0x1116cdf70>: [47, 48, 49],
#  <__main__.Token at 0x1116cd5b0>: [50, 51],
#  <__main__.Token at 0x1116cd3d0>: [52, 53],
#  <__main__.Token at 0x1116cd430>: [54, 55],
#  <__main__.Token at 0x1116cd070>: [56, 57],
#  <__main__.Token at 0x1116cd250>: [58, 59],
#  <__main__.Token at 0x1116cd310>: [60, 61, 62],
#  <__main__.Token at 0x1116cd040>: [],
#  <__main__.Token at 0x1116cdca0>: [63, 64],
#  <__main__.Token at 0x1116cd7f0>: [65, 66, 67],
#  <__main__.Token at 0x1116cdc40>: [68, 69],
#  <__main__.Token at 0x1116cd160>: [70, 71, 72],
#  <__main__.Token at 0x1116cd190>: [],
#  <__main__.Token at 0x1116cd130>: [],
#  <__main__.Token at 0x1116cdcd0>: [73, 74],
#  <__main__.Token at 0x1116cd9a0>: [],
#  <__main__.Token at 0x1116cd970>: [75, 76],
#  <__main__.Token at 0x1116cda60>: [],
#  <__main__.Token at 0x1116cd9d0>: [77, 78],
#  <__main__.Token at 0x1116cda30>: [79, 80],
#  <__main__.Token at 0x1116cda00>: [81, 82],
#  <__main__.Token at 0x1116cdaf0>: [83, 84],
#  <__main__.Token at 0x1116cdac0>: [],
#  <__main__.Token at 0x1116cdd30>: [85, 86, 87],
#  <__main__.Token at 0x1116cdd60>: [88, 89, 90],
#  <__main__.Token at 0x1116cddc0>: [91, 92],
#  <__main__.Token at 0x1116cde50>: [93, 94],
#  <__main__.Token at 0x1116cde20>: [95, 96],
#  <__main__.Token at 0x1116cdee0>: [97, 98],
#  <__main__.Token at 0x1116cde80>: [99, 100, 101]}

# %% [markdown]
# # Weight Vector
