# %%
import numpy as np
import timeit
import random
import pickle, gzip

# %%
from IO import Reader, Writer, Data, Sentence, Token
from feature import FeatureMapping
from eisner import Eisner
from model import Model

# %% [markdown]
# # Decoder (Eisner's Algorithm)

# %%
test_matrix = np.array([[-10000, 9, 10, 9], 
               [-10000, -10000, 20, 3], 
               [-10000, 30, -10000, 30],
               [-10000, 11, 0, -10000]])
test_matrix[0, 2]
# Out:
# 10

# %%
test_decoder = Eisner()
test_decoder.decode(test_matrix)
# Out:
# {'1': '2', '2': '0', '3': '2'}

# %% [markdown]
# # Main

# %%
train_path_en_1k = "Treebanks/english/train/wsj_train.only-projective.first-1k.conll06"
reader_en_1k = Reader(train_path_en_1k)
train_data_en_1k = Data(reader_en_1k.read_file())
train_data_en_1k.sentences

# %%
train_path_en_5k = "Treebanks/english/train/wsj_train.only-projective.first-5k.conll06"
reader_en_5k = Reader(train_path_en_5k)
train_data_en_5k = Data(reader_en_5k.read_file())
train_data_en_5k.sentences
# Out:
# [<IO.Sentence at 0x11046bd00>,
#  <IO.Sentence at 0x11046be80>,
#  <IO.Sentence at 0x11046b490>,
#  <IO.Sentence at 0x11046b1c0>,
#  <IO.Sentence at 0x11045cee0>,
#  <IO.Sentence at 0x11045c910>,
#  <IO.Sentence at 0x11045c6d0>,
#  <IO.Sentence at 0x11045c4c0>,
#  <IO.Sentence at 0x110446b50>,
#  <IO.Sentence at 0x1104468e0>,
#  <IO.Sentence at 0x1104930a0>,
#  <IO.Sentence at 0x1104938b0>,
#  <IO.Sentence at 0x110493c70>,
#  <IO.Sentence at 0x11049e580>,
#  <IO.Sentence at 0x11049e880>,
#  <IO.Sentence at 0x11049eeb0>,
#  <IO.Sentence at 0x1104aa2e0>,
#  <IO.Sentence at 0x1104aac10>,
#  <IO.Sentence at 0x1104b5370>,
#  <IO.Sentence at 0x1104b56d0>,
#  <IO.Sentence at 0x1104b5910>,
#  <IO.Sentence at 0x1104c02e0>,
#  <IO.Sentence at 0x1104c06d0>,
#  <IO.Sentence at 0x1104c0940>,
#  <IO.Sentence at 0x1104c0eb0>,
#  <IO.Sentence at 0x1104ca310>,
#  <IO.Sentence at 0x1104ca7c0>,
#  <IO.Sentence at 0x1104caee0>,
#  <IO.Sentence at 0x1105be7f0>,
#  <IO.Sentence at 0x1105beca0>,
#  <IO.Sentence at 0x1105c90d0>,
#  <IO.Sentence at 0x1105c95b0>,
#  <IO.Sentence at 0x1105c9bb0>,
#  <IO.Sentence at 0x1105d4310>,
#  <IO.Sentence at 0x1105d4730>,
#  <IO.Sentence at 0x1105d4b20>,
#  <IO.Sentence at 0x1105d4d90>,
#  <IO.Sentence at 0x1105de520>,
#  <IO.Sentence at 0x1105deac0>,
#  <IO.Sentence at 0x1105defa0>,
#  <IO.Sentence at 0x1105e9670>,
#  <IO.Sentence at 0x1105e9b50>,
#  <IO.Sentence at 0x1105f4280>,
#  <IO.Sentence at 0x1105f47c0>,
#  <IO.Sentence at 0x1105f4e80>,
#  <IO.Sentence at 0x110703340>,
#  <IO.Sentence at 0x110703940>,
#  <IO.Sentence at 0x110703e50>,
#  <IO.Sentence at 0x11070e760>,
#  <IO.Sentence at 0x11070ea60>,
#  <IO.Sentence at 0x110719340>,
#  <IO.Sentence at 0x110719f10>,
#  <IO.Sentence at 0x1107254f0>,
#  <IO.Sentence at 0x1107258e0>,
#  <IO.Sentence at 0x110725bb0>,
#  <IO.Sentence at 0x11072e070>,
#  <IO.Sentence at 0x11072e550>,
#  <IO.Sentence at 0x11073a160>,
#  <IO.Sentence at 0x11073a880>,
#  <IO.Sentence at 0x110747160>,
#  <IO.Sentence at 0x1107477c0>,
#  <IO.Sentence at 0x110747d60>,
#  <IO.Sentence at 0x1107517f0>,
#  <IO.Sentence at 0x1107519d0>,
#  <IO.Sentence at 0x11075c3a0>,
#  <IO.Sentence at 0x11075ce50>,
#  <IO.Sentence at 0x110767940>,
#  <IO.Sentence at 0x110767e80>,
#  <IO.Sentence at 0x110773760>,
#  <IO.Sentence at 0x110773a30>,
#  <IO.Sentence at 0x110773d90>,
#  <IO.Sentence at 0x110773fd0>,
#  <IO.Sentence at 0x11077c400>,
#  <IO.Sentence at 0x11077ca90>,
#  <IO.Sentence at 0x110788490>,
#  <IO.Sentence at 0x110788b50>,
#  <IO.Sentence at 0x1107952b0>,
#  <IO.Sentence at 0x1107954c0>,
#  <IO.Sentence at 0x110795d00>,
#  <IO.Sentence at 0x110795e50>,
#  <IO.Sentence at 0x11079e040>,
#  <IO.Sentence at 0x11079e790>,
#  <IO.Sentence at 0x11079ebe0>,
#  <IO.Sentence at 0x11079eee0>,
#  <IO.Sentence at 0x1107a9520>,
#  <IO.Sentence at 0x1107a9940>,
#  <IO.Sentence at 0x1107a9d90>,
#  <IO.Sentence at 0x1107b31f0>,
#  <IO.Sentence at 0x1107b35b0>,
#  <IO.Sentence at 0x1107b39a0>,
#  <IO.Sentence at 0x1107b3f40>,
#  <IO.Sentence at 0x1107bf580>,
#  <IO.Sentence at 0x1107bff10>,
#  <IO.Sentence at 0x1107ca370>,
#  <IO.Sentence at 0x1107ca970>,
#  <IO.Sentence at 0x1107caf40>,
#  <IO.Sentence at 0x1107d5670>,
#  <IO.Sentence at 0x1107d5910>,
#  <IO.Sentence at 0x1107e11c0>,
#  <IO.Sentence at 0x1107e1700>,
#  <IO.Sentence at 0x1107e1bb0>,
#  <IO.Sentence at 0x1107eb310>,
#  <IO.Sentence at 0x1107eba00>,
#  <IO.Sentence at 0x1107ebd90>,
#  <IO.Sentence at 0x1107f7130>,
#  <IO.Sentence at 0x1107f76a0>,
#  <IO.Sentence at 0x1107f7e80>,
#  <IO.Sentence at 0x111eb2160>,
#  <IO.Sentence at 0x111eb2700>,
#  <IO.Sentence at 0x111eb2a90>,
#  <IO.Sentence at 0x111ebd070>,
#  <IO.Sentence at 0x111ebd400>,
#  <IO.Sentence at 0x111ebd6a0>,
#  <IO.Sentence at 0x111ebdc10>,
#  <IO.Sentence at 0x111ec6280>,
#  <IO.Sentence at 0x111ec6b80>,
#  <IO.Sentence at 0x111ed2100>,
#  <IO.Sentence at 0x111ed2670>,
#  <IO.Sentence at 0x111ed2b50>,
#  <IO.Sentence at 0x111edc1c0>,
#  <IO.Sentence at 0x111edc5e0>,
#  <IO.Sentence at 0x111edca30>,
#  <IO.Sentence at 0x111ee8190>,
#  <IO.Sentence at 0x111ee8430>,
#  <IO.Sentence at 0x111ee8be0>,
#  <IO.Sentence at 0x111ef3160>,
#  <IO.Sentence at 0x111ef3b20>,
#  <IO.Sentence at 0x111efe0a0>,
#  <IO.Sentence at 0x111efe400>,
#  <IO.Sentence at 0x111efea30>,
#  <IO.Sentence at 0x111efedf0>,
#  <IO.Sentence at 0x111f0a310>,
#  <IO.Sentence at 0x111f0aa00>,
#  <IO.Sentence at 0x111f150a0>,
#  <IO.Sentence at 0x111f15610>,
#  <IO.Sentence at 0x111f15d00>,
#  <IO.Sentence at 0x111f20250>,
#  <IO.Sentence at 0x111f20a00>,
#  <IO.Sentence at 0x111f2b100>,
#  <IO.Sentence at 0x111f2b580>,
#  <IO.Sentence at 0x111f2bbe0>,
#  <IO.Sentence at 0x111f36280>,
#  <IO.Sentence at 0x111f36940>,
#  <IO.Sentence at 0x111f36e50>,
#  <IO.Sentence at 0x111f41460>,
#  <IO.Sentence at 0x111f41820>,
#  <IO.Sentence at 0x111f4b0a0>,
#  <IO.Sentence at 0x111f4b6a0>,
#  <IO.Sentence at 0x111f4bbb0>,
#  <IO.Sentence at 0x111f56070>,
#  <IO.Sentence at 0x111f56640>,
#  <IO.Sentence at 0x111f56a90>,
#  <IO.Sentence at 0x111f61070>,
#  <IO.Sentence at 0x111f61460>,
#  <IO.Sentence at 0x111f61880>,
#  <IO.Sentence at 0x111f6c070>,
#  <IO.Sentence at 0x111f6c370>,
#  <IO.Sentence at 0x111f6c790>,
#  <IO.Sentence at 0x111f762e0>,
#  <IO.Sentence at 0x111f76700>,
#  <IO.Sentence at 0x111f76e80>,
#  <IO.Sentence at 0x111f82220>,
#  <IO.Sentence at 0x111f82a30>,
#  <IO.Sentence at 0x111f82e50>,
#  <IO.Sentence at 0x111f8d3d0>,
#  <IO.Sentence at 0x111f8da30>,
#  <IO.Sentence at 0x111f8dfd0>,
#  <IO.Sentence at 0x111f97400>,
#  <IO.Sentence at 0x111f97730>,
#  <IO.Sentence at 0x111f97ee0>,
#  <IO.Sentence at 0x111fa3730>,
#  <IO.Sentence at 0x111fa3970>,
#  <IO.Sentence at 0x111fa3d00>,
#  <IO.Sentence at 0x111fae3d0>,
#  <IO.Sentence at 0x111fae790>,
#  <IO.Sentence at 0x111faee50>,
#  <IO.Sentence at 0x111fb9430>,
#  <IO.Sentence at 0x111fb9d60>,
#  <IO.Sentence at 0x111fc51c0>,
#  <IO.Sentence at 0x111fc5610>,
#  <IO.Sentence at 0x111fc5a90>,
#  <IO.Sentence at 0x111fc5dc0>,
#  <IO.Sentence at 0x111fd0310>,
#  <IO.Sentence at 0x111fd07c0>,
#  <IO.Sentence at 0x111fd0d00>,
#  <IO.Sentence at 0x111fd9490>,
#  <IO.Sentence at 0x111fd9700>,
#  <IO.Sentence at 0x111fd97f0>,
#  <IO.Sentence at 0x111fd9d60>,
#  <IO.Sentence at 0x111fe4250>,
#  <IO.Sentence at 0x111fe4b50>,
#  <IO.Sentence at 0x111ff02b0>,
#  <IO.Sentence at 0x111ff0670>,
#  <IO.Sentence at 0x111ff0b20>,
#  <IO.Sentence at 0x111ffa040>,
#  <IO.Sentence at 0x111ffa490>,
#  <IO.Sentence at 0x111ffa670>,
#  <IO.Sentence at 0x112006070>,
#  <IO.Sentence at 0x1120064f0>,
#  <IO.Sentence at 0x1120068e0>,
#  <IO.Sentence at 0x112006df0>,
#  <IO.Sentence at 0x11200f250>,
#  <IO.Sentence at 0x11200f7f0>,
#  <IO.Sentence at 0x11200ff40>,
#  <IO.Sentence at 0x11201b370>,
#  <IO.Sentence at 0x11201b700>,
#  <IO.Sentence at 0x11201bcd0>,
#  <IO.Sentence at 0x1120240a0>,
#  <IO.Sentence at 0x112024580>,
#  <IO.Sentence at 0x112030130>,
#  <IO.Sentence at 0x1120302e0>,
#  <IO.Sentence at 0x1120307c0>,
#  <IO.Sentence at 0x112030dc0>,
#  <IO.Sentence at 0x112039130>,
#  <IO.Sentence at 0x112039460>,
#  <IO.Sentence at 0x1120395e0>,
#  <IO.Sentence at 0x112039e50>,
#  <IO.Sentence at 0x112044550>,
#  <IO.Sentence at 0x112044d00>,
#  <IO.Sentence at 0x1120500a0>,
#  <IO.Sentence at 0x112050370>,
#  <IO.Sentence at 0x1120508e0>,
#  <IO.Sentence at 0x112050c70>,
#  <IO.Sentence at 0x112059130>,
#  <IO.Sentence at 0x112059940>,
#  <IO.Sentence at 0x112059df0>,
#  <IO.Sentence at 0x1120655e0>,
#  <IO.Sentence at 0x112065940>,
#  <IO.Sentence at 0x112065ee0>,
#  <IO.Sentence at 0x11206f0a0>,
#  <IO.Sentence at 0x11206f1f0>,
#  <IO.Sentence at 0x11206f520>,
#  <IO.Sentence at 0x11206fa00>,
#  <IO.Sentence at 0x11206fb80>,
#  <IO.Sentence at 0x112079220>,
#  <IO.Sentence at 0x1120796a0>,
#  <IO.Sentence at 0x112079910>,
#  <IO.Sentence at 0x112079d30>,
#  <IO.Sentence at 0x112083160>,
#  <IO.Sentence at 0x1120832b0>,
#  <IO.Sentence at 0x112083490>,
#  <IO.Sentence at 0x112083790>,
#  <IO.Sentence at 0x112083df0>,
#  <IO.Sentence at 0x11208e370>,
#  <IO.Sentence at 0x11208e6d0>,
#  <IO.Sentence at 0x11208e940>,
#  <IO.Sentence at 0x11208eac0>,
#  <IO.Sentence at 0x11208efa0>,
#  <IO.Sentence at 0x112097460>,
#  <IO.Sentence at 0x112097a30>,
#  <IO.Sentence at 0x112097fa0>,
#  <IO.Sentence at 0x1120a11c0>,
#  <IO.Sentence at 0x1120a1370>,
#  <IO.Sentence at 0x1120a16a0>,
#  <IO.Sentence at 0x1120a1820>,
#  <IO.Sentence at 0x1120a1ac0>,
#  <IO.Sentence at 0x1120a1e50>,
#  <IO.Sentence at 0x1120a1fd0>,
#  <IO.Sentence at 0x1120aa490>,
#  <IO.Sentence at 0x1120aabe0>,
#  <IO.Sentence at 0x1120b60a0>,
#  <IO.Sentence at 0x1120b66d0>,
#  <IO.Sentence at 0x1120b69a0>,
#  <IO.Sentence at 0x1120c1070>,
#  <IO.Sentence at 0x1120c14c0>,
#  <IO.Sentence at 0x1120c1820>,
#  <IO.Sentence at 0x1120c1e50>,
#  <IO.Sentence at 0x1120cb5b0>,
#  <IO.Sentence at 0x1120cb760>,
#  <IO.Sentence at 0x1120cbc40>,
#  <IO.Sentence at 0x1120cbe20>,
#  <IO.Sentence at 0x1120d5190>,
#  <IO.Sentence at 0x1120d56a0>,
#  <IO.Sentence at 0x1120d5a60>,
#  <IO.Sentence at 0x1120d5cd0>,
#  <IO.Sentence at 0x1120d5e80>,
#  <IO.Sentence at 0x1120de220>,
#  <IO.Sentence at 0x1120de490>,
#  <IO.Sentence at 0x1120de730>,
#  <IO.Sentence at 0x1120e8310>,
#  <IO.Sentence at 0x1120e8a30>,
#  <IO.Sentence at 0x1120f4070>,
#  <IO.Sentence at 0x1120f4640>,
#  <IO.Sentence at 0x1120f4820>,
#  <IO.Sentence at 0x1120f4cd0>,
#  <IO.Sentence at 0x1120fe3d0>,
#  <IO.Sentence at 0x1120fe700>,
#  <IO.Sentence at 0x1121083d0>,
#  <IO.Sentence at 0x112108a60>,
#  <IO.Sentence at 0x112108ee0>,
#  <IO.Sentence at 0x112113430>,
#  <IO.Sentence at 0x112113790>,
#  <IO.Sentence at 0x11211d190>,
#  <IO.Sentence at 0x11211d6d0>,
#  <IO.Sentence at 0x11211dbe0>,
#  <IO.Sentence at 0x11211dd90>,
#  <IO.Sentence at 0x112127790>,
#  <IO.Sentence at 0x112127940>,
#  <IO.Sentence at 0x112127b80>,
#  <IO.Sentence at 0x112127fd0>,
#  <IO.Sentence at 0x112130700>,
#  <IO.Sentence at 0x112130a30>,
#  <IO.Sentence at 0x112130d90>,
#  <IO.Sentence at 0x11213b130>,
#  <IO.Sentence at 0x11213b3a0>,
#  <IO.Sentence at 0x11213b8b0>,
#  <IO.Sentence at 0x11213bc70>,
#  <IO.Sentence at 0x112144220>,
#  <IO.Sentence at 0x112144580>,
#  <IO.Sentence at 0x112144b20>,
#  <IO.Sentence at 0x11214f100>,
#  <IO.Sentence at 0x11214f820>,
#  <IO.Sentence at 0x11214fcd0>,
#  <IO.Sentence at 0x11214ffd0>,
#  <IO.Sentence at 0x112159910>,
#  <IO.Sentence at 0x112159f10>,
#  <IO.Sentence at 0x1121642e0>,
#  <IO.Sentence at 0x1121644f0>,
#  <IO.Sentence at 0x112164fa0>,
#  <IO.Sentence at 0x11216f610>,
#  <IO.Sentence at 0x11216fb20>,
#  <IO.Sentence at 0x11217a040>,
#  <IO.Sentence at 0x11217a280>,
#  <IO.Sentence at 0x11217a580>,
#  <IO.Sentence at 0x11217aac0>,
#  <IO.Sentence at 0x1121850a0>,
#  <IO.Sentence at 0x1121854f0>,
#  <IO.Sentence at 0x112185a00>,
#  <IO.Sentence at 0x112185f70>,
#  <IO.Sentence at 0x11218f2e0>,
#  <IO.Sentence at 0x11218f4c0>,
#  <IO.Sentence at 0x11218f880>,
#  <IO.Sentence at 0x11218fd90>,
#  <IO.Sentence at 0x1121992b0>,
#  <IO.Sentence at 0x1121997c0>,
#  <IO.Sentence at 0x112199dc0>,
#  <IO.Sentence at 0x1121a34c0>,
#  <IO.Sentence at 0x1121a3d00>,
#  <IO.Sentence at 0x1121af3d0>,
#  <IO.Sentence at 0x1121af940>,
#  <IO.Sentence at 0x1121afb80>,
#  <IO.Sentence at 0x1121affd0>,
#  <IO.Sentence at 0x1121b8340>,
#  <IO.Sentence at 0x1121b8850>,
#  <IO.Sentence at 0x1121b8eb0>,
#  <IO.Sentence at 0x1121c3160>,
#  <IO.Sentence at 0x1121c3610>,
#  <IO.Sentence at 0x1121c3ca0>,
#  <IO.Sentence at 0x1121ce340>,
#  <IO.Sentence at 0x1121ce820>,
#  <IO.Sentence at 0x1121cefd0>,
#  <IO.Sentence at 0x1121d95b0>,
#  <IO.Sentence at 0x1121d9ac0>,
#  <IO.Sentence at 0x1121d9eb0>,
#  <IO.Sentence at 0x1121e4490>,
#  <IO.Sentence at 0x1121e4a00>,
#  <IO.Sentence at 0x1121ee400>,
#  <IO.Sentence at 0x1121ee970>,
#  <IO.Sentence at 0x1121eed30>,
#  <IO.Sentence at 0x1121fb100>,
#  <IO.Sentence at 0x1121fb670>,
#  <IO.Sentence at 0x1121fbd60>,
#  <IO.Sentence at 0x1122051c0>,
#  <IO.Sentence at 0x112205730>,
#  <IO.Sentence at 0x112205b50>,
#  <IO.Sentence at 0x112205fd0>,
#  <IO.Sentence at 0x112211460>,
#  <IO.Sentence at 0x112211790>,
#  <IO.Sentence at 0x112211e50>,
#  <IO.Sentence at 0x11221b250>,
#  <IO.Sentence at 0x11221b7f0>,
#  <IO.Sentence at 0x11221bcd0>,
#  <IO.Sentence at 0x11221bf40>,
#  <IO.Sentence at 0x1122254f0>,
#  <IO.Sentence at 0x1122258e0>,
#  <IO.Sentence at 0x112225d30>,
#  <IO.Sentence at 0x11222f040>,
#  <IO.Sentence at 0x11222f4f0>,
#  <IO.Sentence at 0x11222f9a0>,
#  <IO.Sentence at 0x11222fe20>,
#  <IO.Sentence at 0x11223a220>,
#  <IO.Sentence at 0x11223a670>,
#  <IO.Sentence at 0x11223a970>,
#  <IO.Sentence at 0x1122450a0>,
#  <IO.Sentence at 0x112245820>,
#  <IO.Sentence at 0x112245c70>,
#  <IO.Sentence at 0x112250400>,
#  <IO.Sentence at 0x112250e20>,
#  <IO.Sentence at 0x11225c220>,
#  <IO.Sentence at 0x11225c4c0>,
#  <IO.Sentence at 0x11225c6a0>,
#  <IO.Sentence at 0x11225cb20>,
#  <IO.Sentence at 0x112265460>,
#  <IO.Sentence at 0x1122720d0>,
#  <IO.Sentence at 0x1122723d0>,
#  <IO.Sentence at 0x106214df0>,
#  <IO.Sentence at 0x112272a90>,
#  <IO.Sentence at 0x11227d100>,
#  <IO.Sentence at 0x11227d3a0>,
#  <IO.Sentence at 0x11227d760>,
#  <IO.Sentence at 0x11227d9a0>,
#  <IO.Sentence at 0x11227ddf0>,
#  <IO.Sentence at 0x112285070>,
#  <IO.Sentence at 0x112285220>,
#  <IO.Sentence at 0x112285430>,
#  <IO.Sentence at 0x112285af0>,
#  <IO.Sentence at 0x112285ee0>,
#  <IO.Sentence at 0x11228f700>,
#  <IO.Sentence at 0x11228fd60>,
#  <IO.Sentence at 0x11229a4f0>,
#  <IO.Sentence at 0x11229adc0>,
#  <IO.Sentence at 0x1122a63d0>,
#  <IO.Sentence at 0x1122a64f0>,
#  <IO.Sentence at 0x1122a6730>,
#  <IO.Sentence at 0x1122a6ac0>,
#  <IO.Sentence at 0x1122a6c70>,
#  <IO.Sentence at 0x1122b0400>,
#  <IO.Sentence at 0x1122b05e0>,
#  <IO.Sentence at 0x1122b0a30>,
#  <IO.Sentence at 0x1122b0d90>,
#  <IO.Sentence at 0x1122ba2e0>,
#  <IO.Sentence at 0x1122ba910>,
#  <IO.Sentence at 0x1122baca0>,
#  <IO.Sentence at 0x1122c4490>,
#  <IO.Sentence at 0x1122c4640>,
#  <IO.Sentence at 0x1122c4850>,
#  <IO.Sentence at 0x1122cf070>,
#  <IO.Sentence at 0x1122cfe80>,
#  <IO.Sentence at 0x1122db3d0>,
#  <IO.Sentence at 0x1122dbac0>,
#  <IO.Sentence at 0x1122dbe50>,
#  <IO.Sentence at 0x1122e7280>,
#  <IO.Sentence at 0x1122e7790>,
#  <IO.Sentence at 0x1122e7af0>,
#  <IO.Sentence at 0x1122e7f70>,
#  <IO.Sentence at 0x1122f1220>,
#  <IO.Sentence at 0x1122f19d0>,
#  <IO.Sentence at 0x1122fc550>,
#  <IO.Sentence at 0x1122fcca0>,
#  <IO.Sentence at 0x1123081c0>,
#  <IO.Sentence at 0x112308a60>,
#  <IO.Sentence at 0x112308f10>,
#  <IO.Sentence at 0x112312610>,
#  <IO.Sentence at 0x112312850>,
#  <IO.Sentence at 0x112312d30>,
#  <IO.Sentence at 0x11231e160>,
#  <IO.Sentence at 0x11231e6a0>,
#  <IO.Sentence at 0x11231ea30>,
#  <IO.Sentence at 0x112328220>,
#  <IO.Sentence at 0x112328670>,
#  <IO.Sentence at 0x112328b20>,
#  <IO.Sentence at 0x112328d60>,
#  <IO.Sentence at 0x112333100>,
#  <IO.Sentence at 0x112333850>,
#  <IO.Sentence at 0x11233f0d0>,
#  <IO.Sentence at 0x11233f400>,
#  <IO.Sentence at 0x11233f9d0>,
#  <IO.Sentence at 0x112349310>,
#  <IO.Sentence at 0x112349ac0>,
#  <IO.Sentence at 0x112355460>,
#  <IO.Sentence at 0x112355cd0>,
#  <IO.Sentence at 0x1123603a0>,
#  <IO.Sentence at 0x112360700>,
#  <IO.Sentence at 0x112360ac0>,
#  <IO.Sentence at 0x112360f10>,
#  <IO.Sentence at 0x11236b850>,
#  <IO.Sentence at 0x11236ba90>,
#  <IO.Sentence at 0x11236beb0>,
#  <IO.Sentence at 0x1123764f0>,
#  <IO.Sentence at 0x1123766d0>,
#  <IO.Sentence at 0x112376c70>,
#  <IO.Sentence at 0x112382070>,
#  <IO.Sentence at 0x1123827c0>,
#  <IO.Sentence at 0x1123829a0>,
#  <IO.Sentence at 0x11238d0d0>,
#  <IO.Sentence at 0x11238d430>,
#  <IO.Sentence at 0x11238da00>,
#  <IO.Sentence at 0x11238dfd0>,
#  <IO.Sentence at 0x112397700>,
#  <IO.Sentence at 0x112397d90>,
#  <IO.Sentence at 0x1123a3370>,
#  <IO.Sentence at 0x1123a3730>,
#  <IO.Sentence at 0x1123a3d90>,
#  <IO.Sentence at 0x1123ad1c0>,
#  <IO.Sentence at 0x1123ad640>,
#  <IO.Sentence at 0x1123adb80>,
#  <IO.Sentence at 0x1123adfa0>,
#  <IO.Sentence at 0x1123b7430>,
#  <IO.Sentence at 0x1123b78e0>,
#  <IO.Sentence at 0x1123b7be0>,
#  <IO.Sentence at 0x1123c1340>,
#  <IO.Sentence at 0x1123c16a0>,
#  <IO.Sentence at 0x1123c1b80>,
#  <IO.Sentence at 0x1123cd0a0>,
#  <IO.Sentence at 0x1123cd4f0>,
#  <IO.Sentence at 0x1123cd8b0>,
#  <IO.Sentence at 0x1123cdf10>,
#  <IO.Sentence at 0x1123d72e0>,
#  <IO.Sentence at 0x1123d7ac0>,
#  <IO.Sentence at 0x1123d7e80>,
#  <IO.Sentence at 0x1123e2550>,
#  <IO.Sentence at 0x1123e2d00>,
#  <IO.Sentence at 0x1123ef100>,
#  <IO.Sentence at 0x1123ef4c0>,
#  <IO.Sentence at 0x1123ef9d0>,
#  <IO.Sentence at 0x1123f90a0>,
#  <IO.Sentence at 0x1123f94c0>,
#  <IO.Sentence at 0x1123f97c0>,
#  <IO.Sentence at 0x1123f9e20>,
#  <IO.Sentence at 0x112403820>,
#  <IO.Sentence at 0x11240f160>,
#  <IO.Sentence at 0x11240f8b0>,
#  <IO.Sentence at 0x11240fe20>,
#  <IO.Sentence at 0x11241a220>,
#  <IO.Sentence at 0x11241a910>,
#  <IO.Sentence at 0x11241adc0>,
#  <IO.Sentence at 0x112424190>,
#  <IO.Sentence at 0x112424610>,
#  <IO.Sentence at 0x112424d60>,
#  <IO.Sentence at 0x11242f460>,
#  <IO.Sentence at 0x11242fa30>,
#  <IO.Sentence at 0x11243b3a0>,
#  <IO.Sentence at 0x11243bbb0>,
#  <IO.Sentence at 0x112445070>,
#  <IO.Sentence at 0x1124455e0>,
#  <IO.Sentence at 0x112445a90>,
#  <IO.Sentence at 0x112445b80>,
#  <IO.Sentence at 0x112445c70>,
#  <IO.Sentence at 0x112445d60>,
#  <IO.Sentence at 0x112445e20>,
#  <IO.Sentence at 0x11244f580>,
#  <IO.Sentence at 0x11244fbe0>,
#  <IO.Sentence at 0x11245a040>,
#  <IO.Sentence at 0x11245a7c0>,
#  <IO.Sentence at 0x11245ae20>,
#  <IO.Sentence at 0x1124656d0>,
#  <IO.Sentence at 0x112465eb0>,
#  <IO.Sentence at 0x1124705e0>,
#  <IO.Sentence at 0x112470df0>,
#  <IO.Sentence at 0x11247c4c0>,
#  <IO.Sentence at 0x11247cc10>,
#  <IO.Sentence at 0x11247cf40>,
#  <IO.Sentence at 0x1124872b0>,
#  <IO.Sentence at 0x112492070>,
#  <IO.Sentence at 0x1124926a0>,
#  <IO.Sentence at 0x1124928e0>,
#  <IO.Sentence at 0x112492b50>,
#  <IO.Sentence at 0x11249c2b0>,
#  <IO.Sentence at 0x11249cac0>,
#  <IO.Sentence at 0x1124a83a0>,
#  <IO.Sentence at 0x1124a8af0>,
#  <IO.Sentence at 0x1124a8d00>,
#  <IO.Sentence at 0x1124b34f0>,
#  <IO.Sentence at 0x1124b38b0>,
#  <IO.Sentence at 0x1124ca2e0>,
#  <IO.Sentence at 0x1124caac0>,
#  <IO.Sentence at 0x1124caf40>,
#  <IO.Sentence at 0x1124d54c0>,
#  <IO.Sentence at 0x1124d57c0>,
#  <IO.Sentence at 0x1124d5f10>,
#  <IO.Sentence at 0x1124e03a0>,
#  <IO.Sentence at 0x1124e0910>,
#  <IO.Sentence at 0x1124e0ee0>,
#  <IO.Sentence at 0x1124eb5b0>,
#  <IO.Sentence at 0x1124eba00>,
#  <IO.Sentence at 0x1124f61f0>,
#  <IO.Sentence at 0x1124f6880>,
#  <IO.Sentence at 0x1124f6fd0>,
#  <IO.Sentence at 0x112501310>,
#  <IO.Sentence at 0x112501850>,
#  <IO.Sentence at 0x112501a60>,
#  <IO.Sentence at 0x11250c0d0>,
#  <IO.Sentence at 0x11250c4c0>,
#  <IO.Sentence at 0x11250caf0>,
#  <IO.Sentence at 0x112516220>,
#  <IO.Sentence at 0x112516460>,
#  <IO.Sentence at 0x112516c40>,
#  <IO.Sentence at 0x1125220a0>,
#  <IO.Sentence at 0x112522340>,
#  <IO.Sentence at 0x112522730>,
#  <IO.Sentence at 0x112522c10>,
#  <IO.Sentence at 0x112522fd0>,
#  <IO.Sentence at 0x11252d490>,
#  <IO.Sentence at 0x11252d820>,
#  <IO.Sentence at 0x11252deb0>,
#  <IO.Sentence at 0x112538520>,
#  <IO.Sentence at 0x112538730>,
#  <IO.Sentence at 0x112538e80>,
#  <IO.Sentence at 0x1125430d0>,
#  <IO.Sentence at 0x112543340>,
#  <IO.Sentence at 0x1125439d0>,
#  <IO.Sentence at 0x112543be0>,
#  <IO.Sentence at 0x112543e50>,
#  <IO.Sentence at 0x11254d220>,
#  <IO.Sentence at 0x11254d6d0>,
#  <IO.Sentence at 0x11254d850>,
#  <IO.Sentence at 0x11254dd30>,
#  <IO.Sentence at 0x112556220>,
#  <IO.Sentence at 0x1125566d0>,
#  <IO.Sentence at 0x112556dc0>,
#  <IO.Sentence at 0x112561550>,
#  <IO.Sentence at 0x112561d00>,
#  <IO.Sentence at 0x11256c5b0>,
#  <IO.Sentence at 0x11256c7f0>,
#  <IO.Sentence at 0x11256cd30>,
#  <IO.Sentence at 0x1125783d0>,
#  <IO.Sentence at 0x1125789d0>,
#  <IO.Sentence at 0x112578ee0>,
#  <IO.Sentence at 0x112583670>,
#  <IO.Sentence at 0x112583d90>,
#  <IO.Sentence at 0x11258e1c0>,
#  <IO.Sentence at 0x11258e7f0>,
#  <IO.Sentence at 0x11258ea30>,
#  <IO.Sentence at 0x1125990a0>,
#  <IO.Sentence at 0x1125998e0>,
#  <IO.Sentence at 0x112599af0>,
#  <IO.Sentence at 0x112599d30>,
#  <IO.Sentence at 0x1125a3460>,
#  <IO.Sentence at 0x1125a37c0>,
#  <IO.Sentence at 0x1125a3dc0>,
#  <IO.Sentence at 0x1125ae4f0>,
#  <IO.Sentence at 0x1125aea00>,
#  <IO.Sentence at 0x1125aeca0>,
#  <IO.Sentence at 0x1125b9280>,
#  <IO.Sentence at 0x1125b9430>,
#  <IO.Sentence at 0x1125b9640>,
#  <IO.Sentence at 0x1125b9be0>,
#  <IO.Sentence at 0x1125b9eb0>,
#  <IO.Sentence at 0x1125c43a0>,
#  <IO.Sentence at 0x1125c4700>,
#  <IO.Sentence at 0x1125c4b80>,
#  <IO.Sentence at 0x1125c4d30>,
#  <IO.Sentence at 0x1125cd2b0>,
#  <IO.Sentence at 0x1125cd550>,
#  <IO.Sentence at 0x1125cd790>,
#  <IO.Sentence at 0x1125cde20>,
#  <IO.Sentence at 0x1125d84c0>,
#  <IO.Sentence at 0x1125d88b0>,
#  <IO.Sentence at 0x1125d8dc0>,
#  <IO.Sentence at 0x1125e2130>,
#  <IO.Sentence at 0x1125e2670>,
#  <IO.Sentence at 0x1125e2c70>,
#  <IO.Sentence at 0x1125ed220>,
#  <IO.Sentence at 0x1125ed880>,
#  <IO.Sentence at 0x1125eddc0>,
#  <IO.Sentence at 0x1125f8850>,
#  <IO.Sentence at 0x1125f8b20>,
#  <IO.Sentence at 0x112603250>,
#  <IO.Sentence at 0x112603760>,
#  <IO.Sentence at 0x112603a30>,
#  <IO.Sentence at 0x112603f70>,
#  <IO.Sentence at 0x11260e760>,
#  <IO.Sentence at 0x11260eeb0>,
#  <IO.Sentence at 0x11261a190>,
#  <IO.Sentence at 0x11261a790>,
#  <IO.Sentence at 0x11261af40>,
#  <IO.Sentence at 0x1126253a0>,
#  <IO.Sentence at 0x112625760>,
#  <IO.Sentence at 0x112625bb0>,
#  <IO.Sentence at 0x112625f10>,
#  <IO.Sentence at 0x11262e2b0>,
#  <IO.Sentence at 0x11262ee20>,
#  <IO.Sentence at 0x11263a430>,
#  <IO.Sentence at 0x11263aa60>,
#  <IO.Sentence at 0x11263ae80>,
#  <IO.Sentence at 0x112645340>,
#  <IO.Sentence at 0x112645730>,
#  <IO.Sentence at 0x112645c70>,
#  <IO.Sentence at 0x112650370>,
#  <IO.Sentence at 0x112650c40>,
#  <IO.Sentence at 0x11265c070>,
#  <IO.Sentence at 0x11265c670>,
#  <IO.Sentence at 0x11265cb80>,
#  <IO.Sentence at 0x11265cf40>,
#  <IO.Sentence at 0x1126679d0>,
#  <IO.Sentence at 0x112667d00>,
#  <IO.Sentence at 0x1126733d0>,
#  <IO.Sentence at 0x112673d00>,
#  <IO.Sentence at 0x11267d4f0>,
#  <IO.Sentence at 0x11267d970>,
#  <IO.Sentence at 0x11267dc10>,
#  <IO.Sentence at 0x112688250>,
#  <IO.Sentence at 0x112688640>,
#  <IO.Sentence at 0x112688a90>,
#  <IO.Sentence at 0x112694100>,
#  <IO.Sentence at 0x112694a00>,
#  <IO.Sentence at 0x11269e4c0>,
#  <IO.Sentence at 0x11269e910>,
#  <IO.Sentence at 0x11269ef70>,
#  <IO.Sentence at 0x1126aa2b0>,
#  <IO.Sentence at 0x1126aa7f0>,
#  <IO.Sentence at 0x1126aaa90>,
#  <IO.Sentence at 0x1126aaf70>,
#  <IO.Sentence at 0x1126b34f0>,
#  <IO.Sentence at 0x1126b3910>,
#  <IO.Sentence at 0x1126b3e20>,
#  <IO.Sentence at 0x1126be280>,
#  <IO.Sentence at 0x1126be7c0>,
#  <IO.Sentence at 0x1126bec70>,
#  <IO.Sentence at 0x1126c81f0>,
#  <IO.Sentence at 0x1126c8490>,
#  <IO.Sentence at 0x1126c8bb0>,
#  <IO.Sentence at 0x1126d3130>,
#  <IO.Sentence at 0x1126d38b0>,
#  <IO.Sentence at 0x1126df100>,
#  <IO.Sentence at 0x1126df9d0>,
#  <IO.Sentence at 0x1126dfeb0>,
#  <IO.Sentence at 0x1126e9640>,
#  <IO.Sentence at 0x1126e9a90>,
#  <IO.Sentence at 0x1126f4190>,
#  <IO.Sentence at 0x1126f4820>,
#  <IO.Sentence at 0x1126f4d90>,
#  <IO.Sentence at 0x1126ff700>,
#  <IO.Sentence at 0x1126ffaf0>,
#  <IO.Sentence at 0x11270b340>,
#  <IO.Sentence at 0x11270b5b0>,
#  <IO.Sentence at 0x11270b820>,
#  <IO.Sentence at 0x11270bcd0>,
#  <IO.Sentence at 0x112714250>,
#  <IO.Sentence at 0x112714670>,
#  <IO.Sentence at 0x1127200d0>,
#  <IO.Sentence at 0x1127204c0>,
#  <IO.Sentence at 0x112720d90>,
#  <IO.Sentence at 0x11272cdc0>,
#  <IO.Sentence at 0x112738580>,
#  <IO.Sentence at 0x112738dc0>,
#  <IO.Sentence at 0x1127433d0>,
#  <IO.Sentence at 0x1127435e0>,
#  <IO.Sentence at 0x112743c70>,
#  <IO.Sentence at 0x11274e0a0>,
#  <IO.Sentence at 0x11274e820>,
#  <IO.Sentence at 0x11274efa0>,
#  <IO.Sentence at 0x11275a3d0>,
#  <IO.Sentence at 0x11275a940>,
#  <IO.Sentence at 0x11275af10>,
#  <IO.Sentence at 0x112765460>,
#  <IO.Sentence at 0x112765b80>,
#  <IO.Sentence at 0x112771520>,
#  <IO.Sentence at 0x112771a90>,
#  <IO.Sentence at 0x11277c220>,
#  <IO.Sentence at 0x11277c940>,
#  <IO.Sentence at 0x11277cd90>,
#  <IO.Sentence at 0x112787190>,
#  <IO.Sentence at 0x1127877c0>,
#  <IO.Sentence at 0x112787a60>,
#  <IO.Sentence at 0x112793070>,
#  <IO.Sentence at 0x112793580>,
#  <IO.Sentence at 0x112793970>,
#  <IO.Sentence at 0x11279d070>,
#  <IO.Sentence at 0x11279d9a0>,
#  <IO.Sentence at 0x11279dbb0>,
#  <IO.Sentence at 0x11279deb0>,
#  <IO.Sentence at 0x1127a8220>,
#  <IO.Sentence at 0x1127a8b50>,
#  <IO.Sentence at 0x1127b2160>,
#  <IO.Sentence at 0x1127b27f0>,
#  <IO.Sentence at 0x1127b2d00>,
#  <IO.Sentence at 0x1127b2f40>,
#  <IO.Sentence at 0x1127bd100>,
#  <IO.Sentence at 0x1127bd6d0>,
#  <IO.Sentence at 0x1127bda90>,
#  <IO.Sentence at 0x1127bdf40>,
#  <IO.Sentence at 0x1127c8610>,
#  <IO.Sentence at 0x1127c8c40>,
#  <IO.Sentence at 0x1127c8f10>,
#  <IO.Sentence at 0x1127d3460>,
#  <IO.Sentence at 0x1127d37c0>,
#  <IO.Sentence at 0x1127d3d30>,
#  <IO.Sentence at 0x1127de130>,
#  <IO.Sentence at 0x1127de670>,
#  <IO.Sentence at 0x1127dea90>,
#  <IO.Sentence at 0x1127dee50>,
#  <IO.Sentence at 0x1127e75b0>,
#  <IO.Sentence at 0x1127e7e50>,
#  <IO.Sentence at 0x1127f37c0>,
#  <IO.Sentence at 0x1127f3b20>,
#  <IO.Sentence at 0x1127fe280>,
#  <IO.Sentence at 0x1127fe5b0>,
#  <IO.Sentence at 0x1127feca0>,
#  <IO.Sentence at 0x1128092e0>,
#  <IO.Sentence at 0x1128097c0>,
#  <IO.Sentence at 0x112809c40>,
#  <IO.Sentence at 0x1128131f0>,
#  <IO.Sentence at 0x112813400>,
#  <IO.Sentence at 0x112813760>,
#  <IO.Sentence at 0x112813fa0>,
#  <IO.Sentence at 0x11281f520>,
#  <IO.Sentence at 0x11281f850>,
#  <IO.Sentence at 0x11281ff40>,
#  <IO.Sentence at 0x11282a1c0>,
#  <IO.Sentence at 0x11282a730>,
#  <IO.Sentence at 0x11282a8b0>,
#  <IO.Sentence at 0x1128341c0>,
#  <IO.Sentence at 0x112834790>,
#  <IO.Sentence at 0x112834d90>,
#  <IO.Sentence at 0x112834ee0>,
#  <IO.Sentence at 0x1128407f0>,
#  <IO.Sentence at 0x112840bb0>,
#  <IO.Sentence at 0x11284b160>,
#  <IO.Sentence at 0x11284b490>,
#  <IO.Sentence at 0x11284ba00>,
#  <IO.Sentence at 0x11284be80>,
#  <IO.Sentence at 0x1128551f0>,
#  <IO.Sentence at 0x1128555e0>,
#  <IO.Sentence at 0x112855a60>,
#  <IO.Sentence at 0x112855d90>,
#  <IO.Sentence at 0x11285f370>,
#  <IO.Sentence at 0x11285f640>,
#  <IO.Sentence at 0x11285fc70>,
#  <IO.Sentence at 0x1128695b0>,
#  <IO.Sentence at 0x112869760>,
#  <IO.Sentence at 0x112869880>,
#  <IO.Sentence at 0x112874280>,
#  <IO.Sentence at 0x112874640>,
#  <IO.Sentence at 0x112874f70>,
#  <IO.Sentence at 0x11287f730>,
#  <IO.Sentence at 0x11287f850>,
#  <IO.Sentence at 0x11288c280>,
#  <IO.Sentence at 0x11288c640>,
#  <IO.Sentence at 0x11288c7c0>,
#  <IO.Sentence at 0x11288cee0>,
#  <IO.Sentence at 0x1128962b0>,
#  <IO.Sentence at 0x112896b50>,
#  <IO.Sentence at 0x1128a20d0>,
#  <IO.Sentence at 0x1128a26d0>,
#  <IO.Sentence at 0x1128a2c40>,
#  <IO.Sentence at 0x1128ab100>,
#  <IO.Sentence at 0x1128ab430>,
#  <IO.Sentence at 0x1128ab910>,
#  <IO.Sentence at 0x1128abeb0>,
#  <IO.Sentence at 0x1128b6940>,
#  <IO.Sentence at 0x1128b6d00>,
#  <IO.Sentence at 0x1128c1430>,
#  <IO.Sentence at 0x1128c17f0>,
#  <IO.Sentence at 0x1128c1d00>,
#  <IO.Sentence at 0x1128cc070>,
#  <IO.Sentence at 0x1128cc970>,
#  <IO.Sentence at 0x1128ccdc0>,
#  <IO.Sentence at 0x1128d7700>,
#  <IO.Sentence at 0x1128d7b80>,
#  <IO.Sentence at 0x1128d7ee0>,
#  <IO.Sentence at 0x1128e1220>,
#  <IO.Sentence at 0x1128e1550>,
#  <IO.Sentence at 0x1128e1c10>,
#  <IO.Sentence at 0x1128ed430>,
#  <IO.Sentence at 0x1128eda60>,
#  <IO.Sentence at 0x1128f70a0>,
#  <IO.Sentence at 0x1128f7b20>,
#  <IO.Sentence at 0x1128f7e80>,
#  <IO.Sentence at 0x1129053a0>,
#  <IO.Sentence at 0x112905640>,
#  <IO.Sentence at 0x112905d00>,
#  <IO.Sentence at 0x11290f550>,
#  <IO.Sentence at 0x11290fc70>,
#  <IO.Sentence at 0x11291a310>,
#  <IO.Sentence at 0x11291a6a0>,
#  <IO.Sentence at 0x11291aa90>,
#  <IO.Sentence at 0x11291af40>,
#  <IO.Sentence at 0x1129253d0>,
#  <IO.Sentence at 0x112925670>,
#  <IO.Sentence at 0x112925820>,
#  <IO.Sentence at 0x112925f10>,
#  <IO.Sentence at 0x1129303d0>,
#  <IO.Sentence at 0x112930580>,
#  <IO.Sentence at 0x112930b50>,
#  <IO.Sentence at 0x112930d30>,
#  <IO.Sentence at 0x1129391f0>,
#  <IO.Sentence at 0x112939700>,
#  <IO.Sentence at 0x112939ca0>,
#  <IO.Sentence at 0x112944310>,
#  <IO.Sentence at 0x112944880>,
#  <IO.Sentence at 0x112944b50>,
#  <IO.Sentence at 0x112950070>,
#  <IO.Sentence at 0x112950580>,
#  <IO.Sentence at 0x112950880>,
#  <IO.Sentence at 0x112950b20>,
#  <IO.Sentence at 0x112959280>,
#  <IO.Sentence at 0x112959940>,
#  <IO.Sentence at 0x1129650d0>,
#  <IO.Sentence at 0x112965700>,
#  <IO.Sentence at 0x112965c40>,
#  <IO.Sentence at 0x11296f130>,
#  <IO.Sentence at 0x11296fb50>,
#  <IO.Sentence at 0x11297c100>,
#  <IO.Sentence at 0x11297c880>,
#  <IO.Sentence at 0x11297ceb0>,
#  <IO.Sentence at 0x112987550>,
#  <IO.Sentence at 0x112987bb0>,
#  <IO.Sentence at 0x112987f40>,
#  <IO.Sentence at 0x112992460>,
#  <IO.Sentence at 0x112992940>,
#  <IO.Sentence at 0x112992e50>,
#  <IO.Sentence at 0x11299d250>,
#  <IO.Sentence at 0x11299d640>,
#  <IO.Sentence at 0x11299da60>,
#  <IO.Sentence at 0x11299dd60>,
#  <IO.Sentence at 0x1129a7340>,
#  <IO.Sentence at 0x1129a7ca0>,
#  <IO.Sentence at 0x1129b4310>,
#  <IO.Sentence at 0x1129b4880>,
#  <IO.Sentence at 0x1129b4d30>,
#  <IO.Sentence at 0x1129be3d0>,
#  <IO.Sentence at 0x1129be760>,
#  <IO.Sentence at 0x1129ca1c0>,
#  <IO.Sentence at 0x1129ca760>,
#  <IO.Sentence at 0x1129cac40>,
#  <IO.Sentence at 0x1129cafd0>,
#  <IO.Sentence at 0x1129d45e0>,
#  <IO.Sentence at 0x1129d4a30>,
#  <IO.Sentence at 0x1129d4ca0>,
#  <IO.Sentence at 0x1129df220>,
#  <IO.Sentence at 0x1129df490>,
#  <IO.Sentence at 0x1129df9d0>,
#  <IO.Sentence at 0x1129dffa0>,
#  <IO.Sentence at 0x1129e83a0>,
#  <IO.Sentence at 0x1129e8670>,
#  <IO.Sentence at 0x1129e8910>,
#  <IO.Sentence at 0x1129e8c10>,
#  <IO.Sentence at 0x1129e8f40>,
#  <IO.Sentence at 0x1129f3190>,
#  <IO.Sentence at 0x1129f3a30>,
#  <IO.Sentence at 0x1129f3e20>,
#  <IO.Sentence at 0x1129fe640>,
#  <IO.Sentence at 0x1129febb0>,
#  <IO.Sentence at 0x112a0a1f0>,
#  <IO.Sentence at 0x112a0a4c0>,
#  <IO.Sentence at 0x112a0aa60>,
#  <IO.Sentence at 0x112a15040>,
#  <IO.Sentence at 0x112a154c0>,
#  <IO.Sentence at 0x112a157c0>,
#  <IO.Sentence at 0x112a15d00>,
#  <IO.Sentence at 0x112a20940>,
#  <IO.Sentence at 0x112a2c0a0>,
#  <IO.Sentence at 0x112a2c610>,
#  <IO.Sentence at 0x112a2caf0>,
#  <IO.Sentence at 0x112a37400>,
#  <IO.Sentence at 0x112a37820>,
#  <IO.Sentence at 0x112a37d60>,
#  <IO.Sentence at 0x112a433a0>,
#  <IO.Sentence at 0x112a43820>,
#  <IO.Sentence at 0x112a43f70>,
#  <IO.Sentence at 0x112a4e4c0>,
#  <IO.Sentence at 0x112a4e820>,
#  <IO.Sentence at 0x112a4ef10>,
#  <IO.Sentence at 0x112a58910>,
#  <IO.Sentence at 0x112a58ee0>,
#  <IO.Sentence at 0x112a644c0>,
#  <IO.Sentence at 0x112a64fd0>,
#  <IO.Sentence at 0x112a6f370>,
#  <IO.Sentence at 0x112a6fb20>,
#  <IO.Sentence at 0x112a7b280>,
#  <IO.Sentence at 0x112a7b7f0>,
#  <IO.Sentence at 0x112a7bdf0>,
#  <IO.Sentence at 0x112a853a0>,
#  <IO.Sentence at 0x112a855b0>,
#  <IO.Sentence at 0x112a85970>,
#  <IO.Sentence at 0x112a85fa0>,
#  <IO.Sentence at 0x112a90310>,
#  <IO.Sentence at 0x112a90610>,
#  <IO.Sentence at 0x112a90d00>,
#  <IO.Sentence at 0x112a9a2e0>,
#  <IO.Sentence at 0x112a9a9a0>,
#  <IO.Sentence at 0x112aa5340>,
#  <IO.Sentence at 0x112aa5dc0>,
#  <IO.Sentence at 0x112ab11c0>,
#  <IO.Sentence at 0x112ab1670>,
#  <IO.Sentence at 0x112ab1cd0>,
#  <IO.Sentence at 0x112abb2b0>,
#  <IO.Sentence at 0x112abbb20>,
#  <IO.Sentence at 0x112ac7460>,
#  <IO.Sentence at 0x112ac77c0>,
#  <IO.Sentence at 0x112ac7c40>,
#  <IO.Sentence at 0x112ad2280>,
#  <IO.Sentence at 0x112ad27c0>,
#  <IO.Sentence at 0x112ad2b80>,
#  <IO.Sentence at 0x112add550>,
#  <IO.Sentence at 0x112addb50>,
#  <IO.Sentence at 0x112ae9220>,
#  <IO.Sentence at 0x112ae9b20>,
#  <IO.Sentence at 0x112af4760>,
#  <IO.Sentence at 0x112af4dc0>,
#  <IO.Sentence at 0x112b014f0>,
#  <IO.Sentence at 0x112b01f70>,
#  <IO.Sentence at 0x112b0c5e0>,
#  <IO.Sentence at 0x112b0ce50>,
#  <IO.Sentence at 0x112b183a0>,
#  <IO.Sentence at 0x112b18a60>,
#  <IO.Sentence at 0x112b241f0>,
#  <IO.Sentence at 0x112b24700>,
#  <IO.Sentence at 0x112b24d30>,
#  <IO.Sentence at 0x112b2e580>,
#  <IO.Sentence at 0x112b2e8b0>,
#  <IO.Sentence at 0x112b2eaf0>,
#  <IO.Sentence at 0x112b39100>,
#  <IO.Sentence at 0x112b39760>,
#  <IO.Sentence at 0x112b39a00>,
#  <IO.Sentence at 0x112b39eb0>,
#  <IO.Sentence at 0x112b43490>,
#  <IO.Sentence at 0x112b438e0>,
#  <IO.Sentence at 0x112b43d00>,
#  ...]

# %%
#train_path_de = "Treebanks/german/train/tiger-2.2.train.only-projective.first-5k.conll06"
#reader = Reader(train_path_de)
#test_data = Data(reader.read_file())
#test_data.sentences

# %%
mapping_en_1k = FeatureMapping(train_data_en_1k.sentences)
mapping_en_1k.create_map()

# %%
len(mapping_en_1k.map)

# %%
train_data_en_1k.sentences[0].tokens[2].form

# %%
model_en_1k = Model(train_data_en_1k, mapping_en_1k)

# %%
model_en_1k.train(3)

# %%
vars(model_en_1k)

# %%
mapping_en_5k = FeatureMapping(train_data_en_5k.sentences)
mapping_en_5k.create_map()
# Out:
# Start time: 8.652391416
# 1000 sentences took 17.914218459 to map
# 2000 sentences took 39.267353459 to map
# 3000 sentences took 63.96708420900001 to map
# 4000 sentences took 98.810717709 to map
# 5000 sentences took 138.117167792 to map

# %%
model_en_5k = Model(train_data_en_5k, mapping_en_5k)

# %%
model_en_5k.train(5)
# Out:
# Start time: 2428.020590875
# Epoch: 1
# Time taken for past 100 sentences: 4.576695833000031

# %%
dev_gold_path_en = "Treebanks/english/dev/wsj_dev.conll06.gold"
reader_en_dev = Reader(dev_gold_path_en)
dev_gold_data = Data(reader_en_dev.read_file())
dev_gold_data.sentences

# %%
model_en_5k.make_predictions(dev_gold_data)

# %%
dev_gold_data.sentences[0].tokens[5].x

# %%
dev_gold_data.evaluate()

# %%
train_data_en_5k

# %%
mapping_en_5k = FeatureMapping(train_data_en_5k.sentences)
mapping_en_5k.create_map()

# %%
model_en_5k = Model(train_data_en_5k, mapping_en_5k)

# %%
model_en_5k.train(5)

# %%
model_en_5k.make_predictions(dev_gold_data)

# %%
dev_gold_data.evaluate()

# %%
test_gold_path_en = "Treebanks/english/test/wsj_test.conll06.blind"
reader_en_test = Reader(test_gold_path_en)
test_gold_data = Data(reader_en_test.read_file())
test_gold_data.sentences

# %%
model_en_5k.make_predictions(test_gold_data)

# %%
test_gold_data.sentences[0].tokens[1].x

# %%
for gold_sentence in test_gold_data.sentences:
    for token in gold_sentence.tokens:
        token.head = token.x
        token.x = "_"

# %%
test_gold_data.sentences[0].tokens[1].head

# %%
test_gold_writer = Writer(test_gold_path_en.split('/')[-1], test_gold_data.sentences)
test_gold_writer.write_file()

# %% [markdown]
# # German

# %%
train_path_de_5k = "Treebanks/german/train/tiger-2.2.train.only-projective.first-5k.conll06"
reader_de_train_5k = Reader(train_path_de_5k)
train_data_de_5k = Data(reader_de_train_5k.read_file())
train_data_de_5k.sentences

# %%
mapping_de_5k = FeatureMapping(train_data_de_5k.sentences)
mapping_de_5k.create_map()

# %%
model_de_5k = Model(train_data_de_5k, mapping_de_5k)

# %%
model_de_5k.train(10)

# %%
train_path_de_full = "Treebanks/german/train/tiger-2.2.train.only-projective.conll06"
reader_de_train_full = Reader(train_path_de_full)
train_data_de_full = Data(reader_de_train_full.read_file())
train_data_de_full.sentences

# %%
len(train_data_de_full.sentences)

# %%
mapping_de_full = FeatureMapping(train_data_de_full.sentences)
mapping_de_full.create_map()

# %%
len(train_data_de_full.sentences)

# %%
model_de_full = Model(train_data_de_full, mapping_de_full)

# %%
model_de_full.train(3)

# %%
model_de_full.make_predictions(dev_data_de_5k)

# %%
# test on dev data
dev_path_de_5k = "Treebanks/german/dev/tiger-2.2.dev.conll06.gold"
reader_de_dev_5k = Reader(dev_path_de_5k)
dev_data_de_5k = Data(reader_de_dev_5k.read_file())
len(dev_data_de_5k.sentences)

# %%
model_de_5k.make_predictions(dev_data_de_5k)

# %%
dev_data_de_5k.evaluate()

# %%
for dev_sentence in dev_data_de_5k.sentences:
    for token in dev_sentence.tokens:
        token.head = token.x
        token.x = "_"

# %%
dev_writer_de = Writer(dev_path_de_5k.split('/')[-1], dev_data_de_5k.sentences)
dev_writer_de.write_file()

# %%
test_path_de = "Treebanks/german/test/tiger-2.2.test.conll06.blind"
reader_de_test = Reader(test_path_de)
test_data_de = Data(reader_de_test.read_file())
len(test_data_de.sentences)

# %%
model_de_5k.make_predictions(test_data_de)

# %%
test_data_de.sentences[0].tokens[1].x

# %%
for gold_sentence in test_data_de.sentences:
    for token in gold_sentence.tokens:
        token.head = token.x
        token.x = "_"

# %%
test_data_de.sentences[0].tokens[1].head

# %%
test_writer_de = Writer(test_path_de.split('/')[-1], test_data_de.sentences)
test_writer_de.write_file()

# %%
from difflib import Differ
 
with open(train_path_en) as file_1, open(train_path_en.split('/')[-1]+'.pred') as file_2:
    differ = Differ()
 
    for line in differ.compare(file_1.readlines(), file_2.readlines()):
        print(line)
